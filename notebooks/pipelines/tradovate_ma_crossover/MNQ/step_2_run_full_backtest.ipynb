# %% [markdown]
# # MNQ (Micro E-mini Nasdaq-100) — MA crossover, Tradovate exchange
#
# Mirrors `MES/step_2_run_full_backtest.ipynb`'s MA-crossover setup, applied to **Micro E-mini Nasdaq-100 futures** (MNQ) instead of MES: real 1h OHLC pulled from this repo's Mongo/Timescale store (via the shared `data_aggregator.mongo_timescale_aggregator` module), whole-contract position sizing, tick-based slippage + per-contract fees, and a Tradeify-style EOD-trailing drawdown risk middleware.
#
# **Strategy**: a single crossover -- the winner of the four-way indicator-family comparison (KAMA, EMA, HMA, DEMA, each fast-line paired against a plain SMA slow line) run in `MNQ/step_1_find_best_indicators_and_parameters.ipynb`, selected by a trade-level Sharpe lower bound rather than raw return (see that notebook's "Methodology" and "Final pick" cells for the full reasoning + honest caveats about how much confidence that pick actually supports). Only 2 indicators feed a single strategy here, run through the full event-driven engine: real order fills, margin, whole-contract sizing, and the drawdown middleware, none of which the vectorized notebook models. Same `DATE_FROM`/`DATE_TO` window as that notebook so the two are comparable. Results here will still differ from the vectorized numbers -- that's expected, not a bug, since whole-contract sizing/margin are modeled for real here instead of as a frictionless percentage-return approximation.
#
# **Costs, now researched** (`PROP_FIRM_PLAN.md`, `OPTIMIZATION_RESEARCH_PLAN.md`): MNQ tick_size=0.25 index points ($0.50/tick, CME spec) and a $0.91/side commission are set directly on `TRADOVATE_FUTURES["MNQ"]` in `exchange_config.py`. MNQ commission: Tradeify charges $1.82 round-turn -> $0.91/side, explicitly confirmed for MNQ (not just inferred by analogy with MES). The drawdown middleware below uses Tradeify's real $50k-Growth-account number (4%, not this middleware's generic 5% default) and models the real lock-once-reached trail-freeze mechanic.

# %%
import json
import os

import pandas as pd
from IPython.display import HTML, display

from backtester.backtest_runner import Backtester
from backtester.exchange import Exchange, MarginAllocationType, MarketType, TradovateSymbolConfigProvider
from backtester.exchange_config import TRADOVATE_FUTURES
from backtester.indicators import Indicators
from backtester.market import Market
from backtester.middleware import MaxDailyLossMiddleware, TradeifyDrawdownMiddleware
from backtester.performance import PerformanceAnalyzer
from backtester.portfolio import Portfolio, WeightedStrategy
from backtester.strategies import MaCrossoverStrategy, StrategyDirection
from data_aggregator.mongo_timescale_aggregator import fetch_market_data

cwd = os.getcwd()
print(cwd)
# Out:
# /Users/nick/Documents/www/alphakit/notebooks/pipelines/tradovate_ma_crossover/MNQ

# %%
# Instantiate markets class
market = Market()

# ALL INTERVALS SHOULD BE THE SAME!!
INTERVAL = 1
UNIT_OF_TIME = "hour"

DISPLAY_SYMBOL = "MNQ"       # bare symbol, as registered in Mongo `instruments`
SYMBOL = "MNQ/USD"           # backtester-internal symbol (asset/quote)
SOURCE = "ib"                # Interactive Brokers continuous futures contract
RESOLUTION = "1_hour"

# Same window as notebooks/vectorized_backtest_mes_tradovate.ipynb, for comparability.
DATE_FROM = "2019-10-01"
DATE_TO = "2026-06-01"

# Winner of the 4-indicator-family comparison in step_1 (unlike MES/KAMA or M2K/EMA):
# DEMA(fast)/SMA(slow), long_len=32, short_len=10; see step_1's "Final pick" cell for
# the full reasoning + caveats.
DEMA_FAST_LEN = 10
DEMA_SMA_SLOW = 32

ohlc = fetch_market_data(source=SOURCE, display_symbol=DISPLAY_SYMBOL, resolution=RESOLUTION)
ohlc = ohlc.loc[DATE_FROM:DATE_TO]

market.add_market(
    symbol=SYMBOL,
    df=ohlc
    )

# --- DEMA(fast)/SMA(slow) crossover indicators -- only 2, one per side of the crossover.
DEMA_INDICATOR_NAME = 'dema'
SMA_INDICATOR_NAME = 'sma'
market.add_indicator(
    symbol=SYMBOL,
    interval=INTERVAL,
    unit_of_time=UNIT_OF_TIME,
    indicator_name=f"{DEMA_INDICATOR_NAME}_{DEMA_FAST_LEN}",
    df=Indicators.dema(ohlc, length=DEMA_FAST_LEN)
)
market.add_indicator(
    symbol=SYMBOL,
    interval=INTERVAL,
    unit_of_time=UNIT_OF_TIME,
    indicator_name=f"{SMA_INDICATOR_NAME}_{DEMA_SMA_SLOW}",
    df=Indicators.sma(ohlc, DEMA_SMA_SLOW)
)

market.compile()
# Out:
# {Timestamp('2025-07-08 14:45:17.999000'): {'num': 0,
#   'time_open': Timestamp('2025-07-08 13:45:18'),
#   'time_close': Timestamp('2025-07-08 14:45:17.999000'),
#   'MNQ/USD': {'open': 23809.0,
#    'high': 23822.25,
#    'low': 23775.25,
#    'close': 23776.75,
#    'volume': 48797.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 14:59:59.999000'): {'num': 1,
#   'time_open': Timestamp('2025-07-08 14:00:00'),
#   'time_close': Timestamp('2025-07-08 14:59:59.999000'),
#   'MNQ/USD': {'open': 23777.25,
#    'high': 23840.5,
#    'low': 23734.75,
#    'close': 23790.25,
#    'volume': 236908.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 15:59:59.999000'): {'num': 2,
#   'time_open': Timestamp('2025-07-08 15:00:00'),
#   'time_close': Timestamp('2025-07-08 15:59:59.999000'),
#   'MNQ/USD': {'open': 23790.0,
#    'high': 23811.75,
#    'low': 23749.25,
#    'close': 23802.75,
#    'volume': 118705.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 16:59:59.999000'): {'num': 3,
#   'time_open': Timestamp('2025-07-08 16:00:00'),
#   'time_close': Timestamp('2025-07-08 16:59:59.999000'),
#   'MNQ/USD': {'open': 23802.25,
#    'high': 23861.25,
#    'low': 23783.75,
#    'close': 23813.25,
#    'volume': 125954.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 17:59:59.999000'): {'num': 4,
#   'time_open': Timestamp('2025-07-08 17:00:00'),
#   'time_close': Timestamp('2025-07-08 17:59:59.999000'),
#   'MNQ/USD': {'open': 23813.5,
#    'high': 23836.5,
#    'low': 23771.0,
#    'close': 23831.5,
#    'volume': 91855.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 18:59:59.999000'): {'num': 5,
#   'time_open': Timestamp('2025-07-08 18:00:00'),
#   'time_close': Timestamp('2025-07-08 18:59:59.999000'),
#   'MNQ/USD': {'open': 23831.5,
#    'high': 23840.25,
#    'low': 23786.75,
#    'close': 23795.0,
#    'volume': 65738.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 19:59:59.999000'): {'num': 6,
#   'time_open': Timestamp('2025-07-08 19:00:00'),
#   'time_close': Timestamp('2025-07-08 19:59:59.999000'),
#   'MNQ/USD': {'open': 23795.5,
#    'high': 23803.0,
#    'low': 23765.0,
#    'close': 23787.75,
#    'volume': 83627.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 20:59:59.999000'): {'num': 7,
#   'time_open': Timestamp('2025-07-08 20:00:00'),
#   'time_close': Timestamp('2025-07-08 20:59:59.999000'),
#   'MNQ/USD': {'open': 23787.5,
#    'high': 23805.0,
#    'low': 23780.25,
#    'close': 23799.75,
#    'volume': 18089.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 22:59:59.999000'): {'num': 8,
#   'time_open': Timestamp('2025-07-08 22:00:00'),
#   'time_close': Timestamp('2025-07-08 22:59:59.999000'),
#   'MNQ/USD': {'open': 23805.5,
#    'high': 23819.0,
#    'low': 23797.25,
#    'close': 23809.75,
#    'volume': 10115.0,
#    'indicators': {'dema_10': nan, 'sma_32': nan}}},
#  Timestamp('2025-07-08 23:59:59.999000'): {'num': 9,
#   'time_open': Timestamp('2025-07-08 23:00:00'),
#   'time_close': Timestamp('2025-07-08 23:59:59.999000'),
#   'MNQ/USD': {'open': 23810.75,
#    'high': 23821.0,
#    'low': 23790.5,
#    'close': 23797.5,
#    'volume': 10902.0,
#    'indicators': {'dema_10': 23800.425, 'sma_32': nan}}},
#  Timestamp('2025-07-09 00:59:59.999000'): {'num': 10,
#   'time_open': Timestamp('2025-07-09 00:00:00'),
#   'time_close': Timestamp('2025-07-09 00:59:59.999000'),
#   'MNQ/USD': {'open': 23797.25,
#    'high': 23797.25,
#    'low': 23759.0,
#    'close': 23770.25,
#    'volume': 14752.0,
#    'indicators': {'dema_10': 23790.449793388427, 'sma_32': nan}}},
#  Timestamp('2025-07-09 01:59:59.999000'): {'num': 11,
#   'time_open': Timestamp('2025-07-09 01:00:00'),
#   'time_close': Timestamp('2025-07-09 01:59:59.999000'),
#   'MNQ/USD': {'open': 23770.25,
#    'high': 23789.25,
#    'low': 23747.25,
#    'close': 23785.5,
#    'volume': 16399.0,
#    'indicators': {'dema_10': 23788.145736288505, 'sma_32': nan}}},
#  Timestamp('2025-07-09 02:59:59.999000'): {'num': 12,
#   'time_open': Timestamp('2025-07-09 02:00:00'),
#   'time_close': Timestamp('2025-07-09 02:59:59.999000'),
#   'MNQ/USD': {'open': 23786.25,
#    'high': 23797.0,
#    'low': 23774.25,
#    'close': 23776.0,
#    'volume': 9974.0,
#    'indicators': {'dema_10': 23783.375392732734, 'sma_32': nan}}},
#  Timestamp('2025-07-09 03:59:59.999000'): {'num': 13,
#   'time_open': Timestamp('2025-07-09 03:00:00'),
#   'time_close': Timestamp('2025-07-09 03:59:59.999000'),
#   'MNQ/USD': {'open': 23776.5,
#    'high': 23781.25,
#    'low': 23763.25,
#    'close': 23769.5,
#    'volume': 7681.0,
#    'indicators': {'dema_10': 23777.78944728688, 'sma_32': nan}}},
#  Timestamp('2025-07-09 04:59:59.999000'): {'num': 14,
#   'time_open': Timestamp('2025-07-09 04:00:00'),
#   'time_close': Timestamp('2025-07-09 04:59:59.999000'),
#   'MNQ/USD': {'open': 23769.75,
#    'high': 23791.25,
#    'low': 23765.0,
#    'close': 23787.25,
#    'volume': 6835.0,
#    'indicators': {'dema_10': 23779.643832656617, 'sma_32': nan}}},
#  Timestamp('2025-07-09 05:59:59.999000'): {'num': 15,
#   'time_open': Timestamp('2025-07-09 05:00:00'),
#   'time_close': Timestamp('2025-07-09 05:59:59.999000'),
#   'MNQ/USD': {'open': 23788.25,
#    'high': 23792.0,
#    'low': 23764.5,
#    'close': 23769.25,
#    'volume': 7874.0,
#    'indicators': {'dema_10': 23775.18622839482, 'sma_32': nan}}},
#  Timestamp('2025-07-09 06:59:59.999000'): {'num': 16,
#   'time_open': Timestamp('2025-07-09 06:00:00'),
#   'time_close': Timestamp('2025-07-09 06:59:59.999000'),
#   'MNQ/USD': {'open': 23769.5,
#    'high': 23794.5,
#    'low': 23737.25,
#    'close': 23792.0,
#    'volume': 17699.0,
#    'indicators': {'dema_10': 23779.526634520567, 'sma_32': nan}}},
#  Timestamp('2025-07-09 07:59:59.999000'): {'num': 17,
#   'time_open': Timestamp('2025-07-09 07:00:00'),
#   'time_close': Timestamp('2025-07-09 07:59:59.999000'),
#   'MNQ/USD': {'open': 23792.25,
#    'high': 23799.25,
#    'low': 23769.75,
#    'close': 23789.0,
#    'volume': 14064.0,
#    'indicators': {'dema_10': 23781.85280276935, 'sma_32': nan}}},
#  Timestamp('2025-07-09 08:59:59.999000'): {'num': 18,
#   'time_open': Timestamp('2025-07-09 08:00:00'),
#   'time_close': Timestamp('2025-07-09 08:59:59.999000'),
#   'MNQ/USD': {'open': 23788.25,
#    'high': 23797.0,
#    'low': 23773.25,
#    'close': 23785.75,
#    'volume': 11077.0,
#    'indicators': {'dema_10': 23782.57188059641, 'sma_32': nan}}},
#  Timestamp('2025-07-09 09:59:59.999000'): {'num': 19,
#   'time_open': Timestamp('2025-07-09 09:00:00'),
#   'time_close': Timestamp('2025-07-09 09:59:59.999000'),
#   'MNQ/USD': {'open': 23786.5,
#    'high': 23840.25,
#    'low': 23786.0,
#    'close': 23821.0,
#    'volume': 17837.0,
#    'indicators': {'dema_10': 23794.81120110555, 'sma_32': nan}}},
#  Timestamp('2025-07-09 10:59:59.999000'): {'num': 20,
#   'time_open': Timestamp('2025-07-09 10:00:00'),
#   'time_close': Timestamp('2025-07-09 10:59:59.999000'),
#   'MNQ/USD': {'open': 23821.5,
#    'high': 23832.0,
#    'low': 23806.5,
#    'close': 23820.0,
#    'volume': 14219.0,
#    'indicators': {'dema_10': 23803.539632153632, 'sma_32': nan}}},
#  Timestamp('2025-07-09 11:59:59.999000'): {'num': 21,
#   'time_open': Timestamp('2025-07-09 11:00:00'),
#   'time_close': Timestamp('2025-07-09 11:59:59.999000'),
#   'MNQ/USD': {'open': 23820.5,
#    'high': 23849.5,
#    'low': 23816.0,
#    'close': 23836.5,
#    'volume': 15344.0,
#    'indicators': {'dema_10': 23815.381321296445, 'sma_32': nan}}},
#  Timestamp('2025-07-09 12:59:59.999000'): {'num': 22,
#   'time_open': Timestamp('2025-07-09 12:00:00'),
#   'time_close': Timestamp('2025-07-09 12:59:59.999000'),
#   'MNQ/USD': {'open': 23836.0,
#    'high': 23853.75,
#    'low': 23823.75,
#    'close': 23833.5,
#    'volume': 23999.0,
#    'indicators': {'dema_10': 23823.01480505993, 'sma_32': nan}}},
#  Timestamp('2025-07-09 13:59:59.999000'): {'num': 23,
#   'time_open': Timestamp('2025-07-09 13:00:00'),
#   'time_close': Timestamp('2025-07-09 13:59:59.999000'),
#   'MNQ/USD': {'open': 23833.25,
#    'high': 24000.75,
#    'low': 23827.75,
#    'close': 23989.0,
#    'volume': 150948.0,
#    'indicators': {'dema_10': 23879.87639980872, 'sma_32': nan}}},
#  Timestamp('2025-07-09 14:59:59.999000'): {'num': 24,
#   'time_open': Timestamp('2025-07-09 14:00:00'),
#   'time_close': Timestamp('2025-07-09 14:59:59.999000'),
#   'MNQ/USD': {'open': 23989.25,
#    'high': 24015.75,
#    'low': 23825.0,
#    'close': 23845.25,
#    'volume': 265340.0,
#    'indicators': {'dema_10': 23874.02750373778, 'sma_32': nan}}},
#  Timestamp('2025-07-09 15:59:59.999000'): {'num': 25,
#   'time_open': Timestamp('2025-07-09 15:00:00'),
#   'time_close': Timestamp('2025-07-09 15:59:59.999000'),
#   'MNQ/USD': {'open': 23845.5,
#    'high': 23888.75,
#    'low': 23813.75,
#    'close': 23846.25,
#    'volume': 151496.0,
#    'indicators': {'dema_10': 23869.49138310392, 'sma_32': nan}}},
#  Timestamp('2025-07-09 16:59:59.999000'): {'num': 26,
#   'time_open': Timestamp('2025-07-09 16:00:00'),
#   'time_close': Timestamp('2025-07-09 16:59:59.999000'),
#   'MNQ/USD': {'open': 23846.5,
#    'high': 23909.0,
#    'low': 23835.0,
#    'close': 23882.25,
#    'volume': 84494.0,
#    'indicators': {'dema_10': 23877.587322742278, 'sma_32': nan}}},
#  Timestamp('2025-07-09 17:59:59.999000'): {'num': 27,
#   'time_open': Timestamp('2025-07-09 17:00:00'),
#   'time_close': Timestamp('2025-07-09 17:59:59.999000'),
#   'MNQ/USD': {'open': 23882.0,
#    'high': 23900.25,
#    'low': 23859.75,
#    'close': 23883.0,
#    'volume': 93402.0,
#    'indicators': {'dema_10': 23883.408990673997, 'sma_32': nan}}},
#  Timestamp('2025-07-09 18:59:59.999000'): {'num': 28,
#   'time_open': Timestamp('2025-07-09 18:00:00'),
#   'time_close': Timestamp('2025-07-09 18:59:59.999000'),
#   'MNQ/USD': {'open': 23883.0,
#    'high': 23941.75,
#    'low': 23881.0,
#    'close': 23933.25,
#    'volume': 75543.0,
#    'indicators': {'dema_10': 23903.904190176258, 'sma_32': nan}}},
#  Timestamp('2025-07-09 19:59:59.999000'): {'num': 29,
#   'time_open': Timestamp('2025-07-09 19:00:00'),
#   'time_close': Timestamp('2025-07-09 19:59:59.999000'),
#   'MNQ/USD': {'open': 23933.75,
#    'high': 23959.75,
#    'low': 23923.75,
#    'close': 23953.25,
#    'volume': 79537.0,
#    'indicators': {'dema_10': 23925.20579677938, 'sma_32': nan}}},
#  Timestamp('2025-07-09 20:59:59.999000'): {'num': 30,
#   'time_open': Timestamp('2025-07-09 20:00:00'),
#   'time_close': Timestamp('2025-07-09 20:59:59.999000'),
#   'MNQ/USD': {'open': 23953.0,
#    'high': 23963.0,
#    'low': 23932.5,
#    'close': 23945.0,
#    'volume': 24843.0,
#    'indicators': {'dema_10': 23937.665358330916, 'sma_32': nan}}},
#  Timestamp('2025-07-09 22:59:59.999000'): {'num': 31,
#   'time_open': Timestamp('2025-07-09 22:00:00'),
#   'time_close': Timestamp('2025-07-09 22:59:59.999000'),
#   'MNQ/USD': {'open': 23945.0,
#    'high': 23968.75,
#    'low': 23933.75,
#    'close': 23959.5,
#    'volume': 11104.0,
#    'indicators': {'dema_10': 23951.041912482575, 'sma_32': 23830.515625}}},
#  Timestamp('2025-07-09 23:59:59.999000'): {'num': 32,
#   'time_open': Timestamp('2025-07-09 23:00:00'),
#   'time_close': Timestamp('2025-07-09 23:59:59.999000'),
#   'MNQ/USD': {'open': 23959.75,
#    'high': 23961.75,
#    'low': 23931.25,
#    'close': 23936.5,
#    'volume': 10655.0,
#    'indicators': {'dema_10': 23952.672765675583, 'sma_32': 23835.5078125}}},
#  Timestamp('2025-07-10 00:59:59.999000'): {'num': 33,
#   'time_open': Timestamp('2025-07-10 00:00:00'),
#   'time_close': Timestamp('2025-07-10 00:59:59.999000'),
#   'MNQ/USD': {'open': 23936.0,
#    'high': 23936.5,
#    'low': 23903.75,
#    'close': 23905.25,
#    'volume': 16138.0,
#    'indicators': {'dema_10': 23942.899278451878, 'sma_32': 23839.1015625}}},
#  Timestamp('2025-07-10 01:59:59.999000'): {'num': 34,
#   'time_open': Timestamp('2025-07-10 01:00:00'),
#   'time_close': Timestamp('2025-07-10 01:59:59.999000'),
#   'MNQ/USD': {'open': 23905.75,
#    'high': 23913.5,
#    'low': 23887.75,
#    'close': 23890.5,
#    'volume': 15444.0,
#    'indicators': {'dema_10': 23930.236058791317, 'sma_32': 23841.84375}}},
#  Timestamp('2025-07-10 02:59:59.999000'): {'num': 35,
#   'time_open': Timestamp('2025-07-10 02:00:00'),
#   'time_close': Timestamp('2025-07-10 02:59:59.999000'),
#   'MNQ/USD': {'open': 23890.0,
#    'high': 23922.5,
#    'low': 23889.5,
#    'close': 23919.5,
#    'volume': 11177.0,
#    'indicators': {'dema_10': 23930.032215587427, 'sma_32': 23845.1640625}}},
#  Timestamp('2025-07-10 03:59:59.999000'): {'num': 36,
#   'time_open': Timestamp('2025-07-10 03:00:00'),
#   'time_close': Timestamp('2025-07-10 03:59:59.999000'),
#   'MNQ/USD': {'open': 23919.0,
#    'high': 23919.0,
#    'low': 23892.0,
#    'close': 23897.0,
#    'volume': 9658.0,
#    'indicators': {'dema_10': 23922.109569621603, 'sma_32': 23847.2109375}}},
#  Timestamp('2025-07-10 04:59:59.999000'): {'num': 37,
#   'time_open': Timestamp('2025-07-10 04:00:00'),
#   'time_close': Timestamp('2025-07-10 04:59:59.999000'),
#   'MNQ/USD': {'open': 23896.75,
#    'high': 23897.5,
#    'low': 23882.75,
#    'close': 23894.75,
#    'volume': 7355.0,
#    'indicators': {'dema_10': 23915.232110103272, 'sma_32': 23850.328125}}},
#  Timestamp('2025-07-10 05:59:59.999000'): {'num': 38,
#   'time_open': Timestamp('2025-07-10 05:00:00'),
#   'time_close': Timestamp('2025-07-10 05:59:59.999000'),
#   'MNQ/USD': {'open': 23894.5,
#    'high': 23902.5,
#    'low': 23877.25,
#    'close': 23892.25,
#    'volume': 9767.0,
#    'indicators': {'dema_10': 23909.124650091715, 'sma_32': 23853.59375}}},
#  Timestamp('2025-07-10 06:59:59.999000'): {'num': 39,
#   'time_open': Timestamp('2025-07-10 06:00:00'),
#   'time_close': Timestamp('2025-07-10 06:59:59.999000'),
#   'MNQ/USD': {'open': 23891.75,
#    'high': 23896.5,
#    'low': 23879.75,
#    'close': 23892.0,
#    'volume': 9353.0,
#    'indicators': {'dema_10': 23904.39570082475, 'sma_32': 23856.4765625}}},
#  Timestamp('2025-07-10 07:59:59.999000'): {'num': 40,
#   'time_open': Timestamp('2025-07-10 07:00:00'),
#   'time_close': Timestamp('2025-07-10 07:59:59.999000'),
#   'MNQ/USD': {'open': 23892.25,
#    'high': 23923.0,
#    'low': 23882.5,
#    'close': 23920.75,
#    'volume': 18051.0,
#    'indicators': {'dema_10': 23910.324397569188, 'sma_32': 23859.9453125}}},
#  Timestamp('2025-07-10 08:59:59.999000'): {'num': 41,
#   'time_open': Timestamp('2025-07-10 08:00:00'),
#   'time_close': Timestamp('2025-07-10 08:59:59.999000'),
#   'MNQ/USD': {'open': 23920.75,
#    'high': 23948.75,
#    'low': 23916.75,
#    'close': 23947.0,
#    'volume': 14598.0,
#    'indicators': {'dema_10': 23923.315528528048, 'sma_32': 23864.6171875}}},
#  Timestamp('2025-07-10 09:59:59.999000'): {'num': 42,
#   'time_open': Timestamp('2025-07-10 09:00:00'),
#   'time_close': Timestamp('2025-07-10 09:59:59.999000'),
#   'MNQ/USD': {'open': 23947.75,
#    'high': 23952.0,
#    'low': 23912.5,
#    'close': 23925.5,
#    'volume': 13896.0,
#    'indicators': {'dema_10': 23925.68759045826, 'sma_32': 23869.46875}}},
#  Timestamp('2025-07-10 10:59:59.999000'): {'num': 43,
#   'time_open': Timestamp('2025-07-10 10:00:00'),
#   'time_close': Timestamp('2025-07-10 10:59:59.999000'),
#   'MNQ/USD': {'open': 23925.5,
#    'high': 23955.0,
#    'low': 23922.5,
#    'close': 23945.5,
#    'volume': 10604.0,
#    'indicators': {'dema_10': 23933.880868594744, 'sma_32': 23874.46875}}},
#  Timestamp('2025-07-10 11:59:59.999000'): {'num': 44,
#   'time_open': Timestamp('2025-07-10 11:00:00'),
#   'time_close': Timestamp('2025-07-10 11:59:59.999000'),
#   'MNQ/USD': {'open': 23945.5,
#    'high': 23979.5,
#    'low': 23939.75,
#    'close': 23973.75,
#    'volume': 17281.0,
#    'indicators': {'dema_10': 23949.08857152595, 'sma_32': 23880.6484375}}},
#  Timestamp('2025-07-10 12:59:59.999000'): {'num': 45,
#   'time_open': Timestamp('2025-07-10 12:00:00'),
#   'time_close': Timestamp('2025-07-10 12:59:59.999000'),
#   'MNQ/USD': {'open': 23973.75,
#    'high': 23975.25,
#    'low': 23936.5,
#    'close': 23951.25,
#    'volume': 30052.0,
#    'indicators': {'dema_10': 23952.646171950117, 'sma_32': 23886.328125}}},
#  Timestamp('2025-07-10 13:59:59.999000'): {'num': 46,
#   'time_open': Timestamp('2025-07-10 13:00:00'),
#   'time_close': Timestamp('2025-07-10 13:59:59.999000'),
#   'MNQ/USD': {'open': 23951.25,
#    'high': 23993.25,
#    'low': 23836.75,
#    'close': 23858.5,
#    'volume': 174796.0,
#    'indicators': {'dema_10': 23924.32039464893, 'sma_32': 23888.5546875}}},
#  Timestamp('2025-07-10 14:59:59.999000'): {'num': 47,
#   'time_open': Timestamp('2025-07-10 14:00:00'),
#   'time_close': Timestamp('2025-07-10 14:59:59.999000'),
#   'MNQ/USD': {'open': 23858.5,
#    'high': 23886.25,
#    'low': 23797.25,
#    'close': 23862.0,
#    'volume': 224844.0,
#    'indicators': {'dema_10': 23904.339654648997, 'sma_32': 23891.453125}}},
#  Timestamp('2025-07-10 15:59:59.999000'): {'num': 48,
#   'time_open': Timestamp('2025-07-10 15:00:00'),
#   'time_close': Timestamp('2025-07-10 15:59:59.999000'),
#   'MNQ/USD': {'open': 23862.0,
#    'high': 23926.25,
#    'low': 23838.0,
#    'close': 23925.5,
#    'volume': 113519.0,
#    'indicators': {'dema_10': 23910.55619548709, 'sma_32': 23895.625}}},
#  Timestamp('2025-07-10 16:59:59.999000'): {'num': 49,
#   'time_open': Timestamp('2025-07-10 16:00:00'),
#   'time_close': Timestamp('2025-07-10 16:59:59.999000'),
#   'MNQ/USD': {'open': 23925.5,
#    'high': 23925.75,
#    'low': 23861.25,
#    'close': 23892.0,
#    'volume': 96539.0,
#    'indicators': {'dema_10': 23904.13731140393, 'sma_32': 23898.84375}}},
#  Timestamp('2025-07-10 17:59:59.999000'): {'num': 50,
#   'time_open': Timestamp('2025-07-10 17:00:00'),
#   'time_close': Timestamp('2025-07-10 17:59:59.999000'),
#   'MNQ/USD': {'open': 23891.5,
#    'high': 23942.75,
#    'low': 23886.75,
#    'close': 23938.5,
#    'volume': 70690.0,
#    'indicators': {'dema_10': 23914.811039863835, 'sma_32': 23903.6171875}}},
#  Timestamp('2025-07-10 18:59:59.999000'): {'num': 51,
#   'time_open': Timestamp('2025-07-10 18:00:00'),
#   'time_close': Timestamp('2025-07-10 18:59:59.999000'),
#   'MNQ/USD': {'open': 23938.0,
#    'high': 23952.0,
#    'low': 23925.0,
#    'close': 23939.25,
#    'volume': 59204.0,
#    'indicators': {'dema_10': 23922.98730305224, 'sma_32': 23907.3125}}},
#  Timestamp('2025-07-10 19:59:59.999000'): {'num': 52,
#   'time_open': Timestamp('2025-07-10 19:00:00'),
#   'time_close': Timestamp('2025-07-10 19:59:59.999000'),
#   'MNQ/USD': {'open': 23939.0,
#    'high': 23946.25,
#    'low': 23890.25,
#    'close': 23916.25,
#    'volume': 76533.0,
#    'indicators': {'dema_10': 23921.39497335019, 'sma_32': 23910.3203125}}},
#  Timestamp('2025-07-10 20:59:59.999000'): {'num': 53,
#   'time_open': Timestamp('2025-07-10 20:00:00'),
#   'time_close': Timestamp('2025-07-10 20:59:59.999000'),
#   'MNQ/USD': {'open': 23915.75,
#    'high': 23925.75,
#    'low': 23897.5,
#    'close': 23910.25,
#    'volume': 21942.0,
#    'indicators': {'dema_10': 23918.175480794263, 'sma_32': 23912.625}}},
#  Timestamp('2025-07-10 22:59:59.999000'): {'num': 54,
#   'time_open': Timestamp('2025-07-10 22:00:00'),
#   'time_close': Timestamp('2025-07-10 22:59:59.999000'),
#   'MNQ/USD': {'open': 23911.25,
#    'high': 23941.75,
#    'low': 23904.0,
#    'close': 23939.5,
#    'volume': 12408.0,
#    'indicators': {'dema_10': 23925.42770542065, 'sma_32': 23915.9375}}},
#  Timestamp('2025-07-10 23:59:59.999000'): {'num': 55,
#   'time_open': Timestamp('2025-07-10 23:00:00'),
#   'time_close': Timestamp('2025-07-10 23:59:59.999000'),
#   'MNQ/USD': {'open': 23940.0,
#    'high': 23950.75,
#    'low': 23931.25,
#    'close': 23946.25,
#    'volume': 9658.0,
#    'indicators': {'dema_10': 23932.979105197966, 'sma_32': 23914.6015625}}},
#  Timestamp('2025-07-11 00:59:59.999000'): {'num': 56,
#   'time_open': Timestamp('2025-07-11 00:00:00'),
#   'time_close': Timestamp('2025-07-11 00:59:59.999000'),
#   'MNQ/USD': {'open': 23946.25,
#    'high': 23948.25,
#    'low': 23724.25,
#    'close': 23778.25,
#    'volume': 95317.0,
#    'indicators': {'dema_10': 23882.935691653922, 'sma_32': 23912.5078125}}},
#  Timestamp('2025-07-11 01:59:59.999000'): {'num': 57,
#   'time_open': Timestamp('2025-07-11 01:00:00'),
#   'time_close': Timestamp('2025-07-11 01:59:59.999000'),
#   'MNQ/USD': {'open': 23778.0,
#    'high': 23838.75,
#    'low': 23760.75,
#    'close': 23823.75,
#    'volume': 30666.0,
#    'indicators': {'dema_10': 23861.016193606953, 'sma_32': 23911.8046875}}},
#  Timestamp('2025-07-11 02:59:59.999000'): {'num': 58,
#   'time_open': Timestamp('2025-07-11 02:00:00'),
#   'time_close': Timestamp('2025-07-11 02:59:59.999000'),
#   'MNQ/USD': {'open': 23824.25,
#    'high': 23846.75,
#    'low': 23815.0,
#    'close': 23844.5,
#    'volume': 14698.0,
#    'indicators': {'dema_10': 23851.970374464534, 'sma_32': 23910.625}}},
#  Timestamp('2025-07-11 03:59:59.999000'): {'num': 59,
#   'time_open': Timestamp('2025-07-11 03:00:00'),
#   'time_close': Timestamp('2025-07-11 03:59:59.999000'),
#   'MNQ/USD': {'open': 23843.75,
#    'high': 23869.25,
#    'low': 23842.25,
#    'close': 23866.5,
#    'volume': 10959.0,
#    'indicators': {'dema_10': 23852.940681502598, 'sma_32': 23910.109375}}},
#  Timestamp('2025-07-11 04:59:59.999000'): {'num': 60,
#   'time_open': Timestamp('2025-07-11 04:00:00'),
#   'time_close': Timestamp('2025-07-11 04:59:59.999000'),
#   'MNQ/USD': {'open': 23867.0,
#    'high': 23874.0,
#    'low': 23859.25,
#    'close': 23865.0,
#    'volume': 7167.0,
#    'indicators': {'dema_10': 23853.542600048655, 'sma_32': 23907.9765625}}},
#  Timestamp('2025-07-11 05:59:59.999000'): {'num': 61,
#   'time_open': Timestamp('2025-07-11 05:00:00'),
#   'time_close': Timestamp('2025-07-11 05:59:59.999000'),
#   'MNQ/USD': {'open': 23864.75,
#    'high': 23877.25,
#    'low': 23835.0,
#    'close': 23839.75,
#    'volume': 9782.0,
#    'indicators': {'dema_10': 23845.97718684234, 'sma_32': 23904.4296875}}},
#  Timestamp('2025-07-11 06:59:59.999000'): {'num': 62,
#   'time_open': Timestamp('2025-07-11 06:00:00'),
#   'time_close': Timestamp('2025-07-11 06:59:59.999000'),
#   'MNQ/USD': {'open': 23840.0,
#    'high': 23868.75,
#    'low': 23839.0,
#    'close': 23855.5,
#    'volume': 13300.0,
#    'indicators': {'dema_10': 23845.913490833413, 'sma_32': 23901.6328125}}},
#  Timestamp('2025-07-11 07:59:59.999000'): {'num': 63,
#   'time_open': Timestamp('2025-07-11 07:00:00'),
#   'time_close': Timestamp('2025-07-11 07:59:59.999000'),
#   'MNQ/USD': {'open': 23855.75,
#    'high': 23867.25,
#    'low': 23793.25,
#    'close': 23797.75,
#    'volume': 29797.0,
#    'indicators': {'dema_10': 23827.096851659382, 'sma_32': 23896.578125}}},
#  Timestamp('2025-07-11 08:59:59.999000'): {'num': 64,
#   'time_open': Timestamp('2025-07-11 08:00:00'),
#   'time_close': Timestamp('2025-07-11 08:59:59.999000'),
#   'MNQ/USD': {'open': 23797.5,
#    'high': 23812.5,
#    'low': 23765.25,
#    'close': 23800.5,
#    'volume': 24582.0,
#    'indicators': {'dema_10': 23814.439536124395, 'sma_32': 23892.328125}}},
#  Timestamp('2025-07-11 09:59:59.999000'): {'num': 65,
#   'time_open': Timestamp('2025-07-11 09:00:00'),
#   'time_close': Timestamp('2025-07-11 09:59:59.999000'),
#   'MNQ/USD': {'open': 23799.75,
#    'high': 23812.0,
#    'low': 23753.25,
#    'close': 23759.5,
#    'volume': 19152.0,
#    'indicators': {'dema_10': 23791.951927010086, 'sma_32': 23887.7734375}}},
#  Timestamp('2025-07-11 10:59:59.999000'): {'num': 66,
#   'time_open': Timestamp('2025-07-11 10:00:00'),
#   'time_close': Timestamp('2025-07-11 10:59:59.999000'),
#   'MNQ/USD': {'open': 23759.0,
#    'high': 23788.0,
#    'low': 23747.0,
#    'close': 23766.75,
#    'volume': 22004.0,
#    'indicators': {'dema_10': 23778.222141503476, 'sma_32': 23883.90625}}},
#  Timestamp('2025-07-11 11:59:59.999000'): {'num': 67,
#   'time_open': Timestamp('2025-07-11 11:00:00'),
#   'time_close': Timestamp('2025-07-11 11:59:59.999000'),
#   'MNQ/USD': {'open': 23767.75,
#    'high': 23821.0,
#    'low': 23763.5,
#    'close': 23805.25,
#    'volume': 22581.0,
#    'indicators': {'dema_10': 23781.37915644522, 'sma_32': 23880.3359375}}},
#  Timestamp('2025-07-11 12:59:59.999000'): {'num': 68,
#   'time_open': Timestamp('2025-07-11 12:00:00'),
#   'time_close': Timestamp('2025-07-11 12:59:59.999000'),
#   'MNQ/USD': {'open': 23804.75,
#    'high': 23817.5,
#    'low': 23777.0,
#    'close': 23800.5,
#    'volume': 28496.0,
#    'indicators': {'dema_10': 23782.711400945223, 'sma_32': 23877.3203125}}},
#  Timestamp('2025-07-11 13:59:59.999000'): {'num': 69,
#   'time_open': Timestamp('2025-07-11 13:00:00'),
#   'time_close': Timestamp('2025-07-11 13:59:59.999000'),
#   'MNQ/USD': {'open': 23800.25,
#    'high': 23866.5,
#    'low': 23757.75,
#    'close': 23862.75,
#    'volume': 167492.0,
#    'indicators': {'dema_10': 23804.769799298276, 'sma_32': 23876.3203125}}},
#  Timestamp('2025-07-11 14:59:59.999000'): {'num': 70,
#   'time_open': Timestamp('2025-07-11 14:00:00'),
#   'time_close': Timestamp('2025-07-11 14:59:59.999000'),
#   'MNQ/USD': {'open': 23862.5,
#    'high': 23907.75,
#    'low': 23836.75,
#    'close': 23868.75,
#    'volume': 167230.0,
#    'indicators': {'dema_10': 23823.436337061947, 'sma_32': 23875.5859375}}},
#  Timestamp('2025-07-11 15:59:59.999000'): {'num': 71,
#   'time_open': Timestamp('2025-07-11 15:00:00'),
#   'time_close': Timestamp('2025-07-11 15:59:59.999000'),
#   'MNQ/USD': {'open': 23869.0,
#    'high': 23910.5,
#    'low': 23805.25,
#    'close': 23875.5,
#    'volume': 145888.0,
#    'indicators': {'dema_10': 23839.661495827313, 'sma_32': 23875.0703125}}},
#  Timestamp('2025-07-11 16:59:59.999000'): {'num': 72,
#   'time_open': Timestamp('2025-07-11 16:00:00'),
#   'time_close': Timestamp('2025-07-11 16:59:59.999000'),
#   'MNQ/USD': {'open': 23875.75,
#    'high': 23909.0,
#    'low': 23857.0,
#    'close': 23903.5,
#    'volume': 90576.0,
#    'indicators': {'dema_10': 23860.963908031325, 'sma_32': 23874.53125}}},
#  Timestamp('2025-07-11 17:59:59.999000'): {'num': 73,
#   'time_open': Timestamp('2025-07-11 17:00:00'),
#   'time_close': Timestamp('2025-07-11 17:59:59.999000'),
#   'MNQ/USD': {'open': 23904.0,
#    'high': 23922.75,
#    'low': 23859.5,
#    'close': 23898.5,
#    'volume': 81463.0,
#    'indicators': {'dema_10': 23874.977459737107, 'sma_32': 23873.015625}}},
#  Timestamp('2025-07-11 18:59:59.999000'): {'num': 74,
#   'time_open': Timestamp('2025-07-11 18:00:00'),
#   'time_close': Timestamp('2025-07-11 18:59:59.999000'),
#   'MNQ/USD': {'open': 23898.25,
#    'high': 23919.25,
#    'low': 23868.5,
#    'close': 23876.0,
#    'volume': 63158.0,
#    'indicators': {'dema_10': 23877.69802047446, 'sma_32': 23871.46875}}},
#  Timestamp('2025-07-11 19:59:59.999000'): {'num': 75,
#   'time_open': Timestamp('2025-07-11 19:00:00'),
#   'time_close': Timestamp('2025-07-11 19:59:59.999000'),
#   'MNQ/USD': {'open': 23875.75,
#    'high': 23897.25,
#    'low': 23821.25,
#    'close': 23854.25,
#    'volume': 110047.0,
#    'indicators': {'dema_10': 23872.2730067375, 'sma_32': 23868.6171875}}},
#  Timestamp('2025-07-11 20:59:59.999000'): {'num': 76,
#   'time_open': Timestamp('2025-07-11 20:00:00'),
#   'time_close': Timestamp('2025-07-11 20:59:59.999000'),
#   'MNQ/USD': {'open': 23853.75,
#    'high': 23856.25,
#    'low': 23827.25,
#    'close': 23834.75,
#    'volume': 25059.0,
#    'indicators': {'dema_10': 23861.59930310408, 'sma_32': 23864.2734375}}},
#  Timestamp('2025-07-13 22:59:59.999000'): {'num': 77,
#   'time_open': Timestamp('2025-07-13 22:00:00'),
#   'time_close': Timestamp('2025-07-13 22:59:59.999000'),
#   'MNQ/USD': {'open': 23759.25,
#    'high': 23785.0,
#    'low': 23694.5,
#    'close': 23777.5,
#    'volume': 39668.0,
#    'indicators': {'dema_10': 23834.64089643695, 'sma_32': 23858.84375}}},
#  Timestamp('2025-07-13 23:59:59.999000'): {'num': 78,
#   'time_open': Timestamp('2025-07-13 23:00:00'),
#   'time_close': Timestamp('2025-07-13 23:59:59.999000'),
#   'MNQ/USD': {'open': 23777.25,
#    'high': 23781.5,
#    'low': 23730.75,
#    'close': 23761.25,
#    'volume': 26708.0,
#    'indicators': {'dema_10': 23809.333503661863, 'sma_32': 23855.8046875}}},
#  Timestamp('2025-07-14 00:59:59.999000'): {'num': 79,
#   'time_open': Timestamp('2025-07-14 00:00:00'),
#   'time_close': Timestamp('2025-07-14 00:59:59.999000'),
#   'MNQ/USD': {'open': 23761.75,
#    'high': 23773.0,
#    'low': 23743.25,
#    'close': 23745.5,
#    'volume': 18650.0,
#    'indicators': {'dema_10': 23785.59604226162, 'sma_32': 23852.1640625}}},
#  Timestamp('2025-07-14 01:59:59.999000'): {'num': 80,
#   'time_open': Timestamp('2025-07-14 01:00:00'),
#   'time_close': Timestamp('2025-07-14 01:59:59.999000'),
#   'MNQ/USD': {'open': 23745.0,
#    'high': 23759.75,
#    'low': 23735.0,
#    'close': 23751.75,
#    'volume': 15920.0,
#    'indicators': {'dema_10': 23770.446302241235, 'sma_32': 23846.734375}}},
#  Timestamp('2025-07-14 02:59:59.999000'): {'num': 81,
#   'time_open': Timestamp('2025-07-14 02:00:00'),
#   'time_close': Timestamp('2025-07-14 02:59:59.999000'),
#   'MNQ/USD': {'open': 23751.25,
#    'high': 23767.5,
#    'low': 23749.75,
#    'close': 23752.0,
#    'volume': 10057.0,
#    'indicators': {'dema_10': 23759.769325789865, 'sma_32': 23842.359375}}},
#  Timestamp('2025-07-14 03:59:59.999000'): {'num': 82,
#   'time_open': Timestamp('2025-07-14 03:00:00'),
#   'time_close': Timestamp('2025-07-14 03:59:59.999000'),
#   'MNQ/USD': {'open': 23752.0,
#    'high': 23771.75,
#    'low': 23744.5,
#    'close': 23769.5,
#    'volume': 8979.0,
#    'indicators': {'dema_10': 23758.150215081434, 'sma_32': 23837.078125}}},
#  Timestamp('2025-07-14 04:59:59.999000'): {'num': 83,
#   'time_open': Timestamp('2025-07-14 04:00:00'),
#   'time_close': Timestamp('2025-07-14 04:59:59.999000'),
#   'MNQ/USD': {'open': 23769.25,
#    'high': 23774.75,
#    'low': 23755.75,
#    'close': 23757.25,
#    'volume': 6961.0,
#    'indicators': {'dema_10': 23753.39196030698, 'sma_32': 23831.390625}}},
#  Timestamp('2025-07-14 05:59:59.999000'): {'num': 84,
#   'time_open': Timestamp('2025-07-14 05:00:00'),
#   'time_close': Timestamp('2025-07-14 05:59:59.999000'),
#   'MNQ/USD': {'open': 23757.0,
#    'high': 23765.25,
#    'low': 23720.25,
#    'close': 23724.75,
#    'volume': 11301.0,
#    'indicators': {'dema_10': 23739.590419166823, 'sma_32': 23825.40625}}},
#  Timestamp('2025-07-14 06:59:59.999000'): {'num': 85,
#   'time_open': Timestamp('2025-07-14 06:00:00'),
#   'time_close': Timestamp('2025-07-14 06:59:59.999000'),
#   'MNQ/USD': {'open': 23723.75,
#    'high': 23740.75,
#    'low': 23707.75,
#    'close': 23735.75,
#    'volume': 15820.0,
#    'indicators': {'dema_10': 23733.497142232776, 'sma_32': 23819.953125}}},
#  Timestamp('2025-07-14 07:59:59.999000'): {'num': 86,
#   'time_open': Timestamp('2025-07-14 07:00:00'),
#   'time_close': Timestamp('2025-07-14 07:59:59.999000'),
#   'MNQ/USD': {'open': 23736.25,
#    'high': 23779.25,
#    'low': 23697.5,
#    'close': 23777.75,
#    'volume': 28893.0,
#    'indicators': {'dema_10': 23743.3769438808, 'sma_32': 23814.8984375}}},
#  Timestamp('2025-07-14 08:59:59.999000'): {'num': 87,
#   'time_open': Timestamp('2025-07-14 08:00:00'),
#   'time_close': Timestamp('2025-07-14 08:59:59.999000'),
#   'MNQ/USD': {'open': 23777.25,
#    'high': 23794.5,
#    'low': 23760.5,
#    'close': 23782.75,
#    'volume': 17793.0,
#    'indicators': {'dema_10': 23752.779887335073, 'sma_32': 23809.7890625}}},
#  Timestamp('2025-07-14 09:59:59.999000'): {'num': 88,
#   'time_open': Timestamp('2025-07-14 09:00:00'),
#   'time_close': Timestamp('2025-07-14 09:59:59.999000'),
#   'MNQ/USD': {'open': 23782.75,
#    'high': 23799.75,
#    'low': 23774.0,
#    'close': 23795.75,
#    'volume': 10792.0,
#    'indicators': {'dema_10': 23764.362687917346, 'sma_32': 23810.3359375}}},
#  Timestamp('2025-07-14 10:59:59.999000'): {'num': 89,
#   'time_open': Timestamp('2025-07-14 10:00:00'),
#   'time_close': Timestamp('2025-07-14 10:59:59.999000'),
#   'MNQ/USD': {'open': 23795.0,
#    'high': 23796.75,
#    'low': 23765.25,
#    'close': 23772.75,
#    'volume': 13198.0,
#    'indicators': {'dema_10': 23765.550754822267, 'sma_32': 23808.7421875}}},
#  Timestamp('2025-07-14 11:59:59.999000'): {'num': 90,
#   'time_open': Timestamp('2025-07-14 11:00:00'),
#   'time_close': Timestamp('2025-07-14 11:59:59.999000'),
#   'MNQ/USD': {'open': 23773.0,
#    'high': 23795.75,
#    'low': 23757.25,
#    'close': 23782.75,
#    'volume': 22140.0,
#    'indicators': {'dema_10': 23769.88984903722, 'sma_32': 23806.8125}}},
#  Timestamp('2025-07-14 12:59:59.999000'): {'num': 91,
#   'time_open': Timestamp('2025-07-14 12:00:00'),
#   'time_close': Timestamp('2025-07-14 12:59:59.999000'),
#   'MNQ/USD': {'open': 23782.75,
#    'high': 23805.75,
#    'low': 23774.25,
#    'close': 23795.5,
#    'volume': 21289.0,
#    'indicators': {'dema_10': 23777.43453693195, 'sma_32': 23804.59375}}},
#  Timestamp('2025-07-14 13:59:59.999000'): {'num': 92,
#   'time_open': Timestamp('2025-07-14 13:00:00'),
#   'time_close': Timestamp('2025-07-14 13:59:59.999000'),
#   'MNQ/USD': {'open': 23795.5,
#    'high': 23878.25,
#    'low': 23736.5,
#    'close': 23808.25,
#    'volume': 186920.0,
#    'indicators': {'dema_10': 23787.29719454968, 'sma_32': 23802.8203125}}},
#  Timestamp('2025-07-14 14:59:59.999000'): {'num': 93,
#   'time_open': Timestamp('2025-07-14 14:00:00'),
#   'time_close': Timestamp('2025-07-14 14:59:59.999000'),
#   'MNQ/USD': {'open': 23808.5,
#    'high': 23893.0,
#    'low': 23801.75,
#    'close': 23891.75,
#    'volume': 171791.0,
#    'indicators': {'dema_10': 23822.195429994616, 'sma_32': 23804.4453125}}},
#  Timestamp('2025-07-14 15:59:59.999000'): {'num': 94,
#   'time_open': Timestamp('2025-07-14 15:00:00'),
#   'time_close': Timestamp('2025-07-14 15:59:59.999000'),
#   'MNQ/USD': {'open': 23891.25,
#    'high': 23923.75,
#    'low': 23884.25,
#    'close': 23909.25,
#    'volume': 105160.0,
#    'indicators': {'dema_10': 23853.64150727612, 'sma_32': 23806.125}}},
#  Timestamp('2025-07-14 16:59:59.999000'): {'num': 95,
#   'time_open': Timestamp('2025-07-14 16:00:00'),
#   'time_close': Timestamp('2025-07-14 16:59:59.999000'),
#   'MNQ/USD': {'open': 23909.0,
#    'high': 23942.75,
#    'low': 23899.5,
#    'close': 23935.0,
#    'volume': 67941.0,
#    'indicators': {'dema_10': 23885.042881083533, 'sma_32': 23810.4140625}}},
#  Timestamp('2025-07-14 17:59:59.999000'): {'num': 96,
#   'time_open': Timestamp('2025-07-14 17:00:00'),
#   'time_close': Timestamp('2025-07-14 17:59:59.999000'),
#   'MNQ/USD': {'open': 23935.75,
#    'high': 23970.5,
#    'low': 23935.0,
#    'close': 23946.5,
#    'volume': 71345.0,
#    'indicators': {'dema_10': 23911.516763348547, 'sma_32': 23814.9765625}}},
#  Timestamp('2025-07-14 18:59:59.999000'): {'num': 97,
#   'time_open': Timestamp('2025-07-14 18:00:00'),
#   'time_close': Timestamp('2025-07-14 18:59:59.999000'),
#   'MNQ/USD': {'open': 23946.75,
#    'high': 23962.5,
#    'low': 23937.0,
#    'close': 23953.5,
#    'volume': 42435.0,
#    'indicators': {'dema_10': 23932.70946921691, 'sma_32': 23821.0390625}}},
#  Timestamp('2025-07-14 19:59:59.999000'): {'num': 98,
#   'time_open': Timestamp('2025-07-14 19:00:00'),
#   'time_close': Timestamp('2025-07-14 19:59:59.999000'),
#   'MNQ/USD': {'open': 23953.5,
#    'high': 23962.0,
#    'low': 23916.75,
#    'close': 23935.25,
#    'volume': 81637.0,
#    'indicators': {'dema_10': 23941.550554328223, 'sma_32': 23826.3046875}}},
#  Timestamp('2025-07-14 20:59:59.999000'): {'num': 99,
#   'time_open': Timestamp('2025-07-14 20:00:00'),
#   'time_close': Timestamp('2025-07-14 20:59:59.999000'),
#   'MNQ/USD': {'open': 23935.5,
#    'high': 23941.0,
#    'low': 23923.0,
#    'close': 23937.75,
#    'volume': 20743.0,
#    'indicators': {'dema_10': 23948.087130168755, 'sma_32': 23830.4453125}}},
#  Timestamp('2025-07-14 22:59:59.999000'): {'num': 100,
#   'time_open': Timestamp('2025-07-14 22:00:00'),
#   'time_close': Timestamp('2025-07-14 22:59:59.999000'),
#   'MNQ/USD': {'open': 23938.0,
#    'high': 23939.5,
#    'low': 23899.75,
#    'close': 23902.25,
#    'volume': 14285.0,
#    'indicators': {'dema_10': 23940.385593990304, 'sma_32': 23833.625}}},
#  Timestamp('2025-07-14 23:59:59.999000'): {'num': 101,
#   'time_open': Timestamp('2025-07-14 23:00:00'),
#   'time_close': Timestamp('2025-07-14 23:59:59.999000'),
#   'MNQ/USD': {'open': 23902.25,
#    'high': 23916.75,
#    'low': 23897.0,
#    'close': 23912.0,
#    'volume': 8270.0,
#    'indicators': {'dema_10': 23937.192479887697, 'sma_32': 23835.1640625}}},
#  Timestamp('2025-07-15 00:59:59.999000'): {'num': 102,
#   'time_open': Timestamp('2025-07-15 00:00:00'),
#   'time_close': Timestamp('2025-07-15 00:59:59.999000'),
#   'MNQ/USD': {'open': 23912.5,
#    'high': 23920.75,
#    'low': 23897.25,
#    'close': 23905.75,
#    'volume': 10870.0,
#    'indicators': {'dema_10': 23932.156015740078, 'sma_32': 23836.3203125}}},
#  Timestamp('2025-07-15 01:59:59.999000'): {'num': 103,
#   'time_open': Timestamp('2025-07-15 01:00:00'),
#   'time_close': Timestamp('2025-07-15 01:59:59.999000'),
#   'MNQ/USD': {'open': 23906.25,
#    'high': 24080.5,
#    'low': 23896.25,
#    'close': 24048.75,
#    'volume': 47374.0,
#    'indicators': {'dema_10': 23975.184299550678, 'sma_32': 23841.734375}}},
#  Timestamp('2025-07-15 02:59:59.999000'): {'num': 104,
#   'time_open': Timestamp('2025-07-15 02:00:00'),
#   'time_close': Timestamp('2025-07-15 02:59:59.999000'),
#   'MNQ/USD': {'open': 24048.75,
#    'high': 24070.5,
#    'low': 23940.75,
#    'close': 23958.0,
#    'volume': 50670.0,
#    'indicators': {'dema_10': 23976.420281289982, 'sma_32': 23843.4375}}},
#  Timestamp('2025-07-15 03:59:59.999000'): {'num': 105,
#   'time_open': Timestamp('2025-07-15 03:00:00'),
#   'time_close': Timestamp('2025-07-15 03:59:59.999000'),
#   'MNQ/USD': {'open': 23957.75,
#    'high': 24005.0,
#    'low': 23949.0,
#    'close': 23998.0,
#    'volume': 19288.0,
#    'indicators': {'dema_10': 23989.861879601744, 'sma_32': 23846.546875}}},
#  Timestamp('2025-07-15 04:59:59.999000'): {'num': 106,
#   'time_open': Timestamp('2025-07-15 04:00:00'),
#   'time_close': Timestamp('2025-07-15 04:59:59.999000'),
#   'MNQ/USD': {'open': 23997.5,
#    'high': 24025.75,
#    'low': 23993.5,
#    'close': 24020.5,
#    'volume': 10992.0,
#    'indicators': {'dema_10': 24006.567019641796, 'sma_32': 23851.0625}}},
#  Timestamp('2025-07-15 05:59:59.999000'): {'num': 107,
#   'time_open': Timestamp('2025-07-15 05:00:00'),
#   'time_close': Timestamp('2025-07-15 05:59:59.999000'),
#   'MNQ/USD': {'open': 24020.5,
#    'high': 24076.75,
#    'low': 24018.0,
#    'close': 24052.75,
#    'volume': 20887.0,
#    'indicators': {'dema_10': 24028.87155075483, 'sma_32': 23857.265625}}},
#  Timestamp('2025-07-15 06:59:59.999000'): {'num': 108,
#   'time_open': Timestamp('2025-07-15 06:00:00'),
#   'time_close': Timestamp('2025-07-15 06:59:59.999000'),
#   'MNQ/USD': {'open': 24053.0,
#    'high': 24062.5,
#    'low': 24037.25,
#    'close': 24049.25,
#    'volume': 12490.0,
#    'indicators': {'dema_10': 24043.4350285824, 'sma_32': 23863.96875}}},
#  Timestamp('2025-07-15 07:59:59.999000'): {'num': 109,
#   'time_open': Timestamp('2025-07-15 07:00:00'),
#   'time_close': Timestamp('2025-07-15 07:59:59.999000'),
#   'MNQ/USD': {'open': 24049.5,
#    'high': 24077.0,
#    'low': 24037.5,
#    'close': 24067.0,
#    'volume': 16764.0,
#    'indicators': {'dema_10': 24059.24413262954, 'sma_32': 23873.015625}}},
#  Timestamp('2025-07-15 08:59:59.999000'): {'num': 110,
#   'time_open': Timestamp('2025-07-15 08:00:00'),
#   'time_close': Timestamp('2025-07-15 08:59:59.999000'),
#   'MNQ/USD': {'open': 24066.75,
#    'high': 24086.25,
#    'low': 24049.25,
#    'close': 24061.75,
#    'volume': 19806.0,
#    'indicators': {'dema_10': 24068.34794169814, 'sma_32': 23882.40625}}},
#  Timestamp('2025-07-15 09:59:59.999000'): {'num': 111,
#   'time_open': Timestamp('2025-07-15 09:00:00'),
#   'time_close': Timestamp('2025-07-15 09:59:59.999000'),
#   'MNQ/USD': {'open': 24061.75,
#    'high': 24088.25,
#    'low': 24055.75,
#    'close': 24081.0,
#    'volume': 11852.0,
#    'indicators': {'dema_10': 24080.587749696184, 'sma_32': 23892.890625}}},
#  Timestamp('2025-07-15 10:59:59.999000'): {'num': 112,
#   'time_open': Timestamp('2025-07-15 10:00:00'),
#   'time_close': Timestamp('2025-07-15 10:59:59.999000'),
#   'MNQ/USD': {'open': 24081.0,
#    'high': 24097.0,
#    'low': 24069.25,
#    'close': 24077.0,
#    'volume': 14649.0,
#    'indicators': {'dema_10': 24087.472654233847, 'sma_32': 23903.0546875}}},
#  Timestamp('2025-07-15 11:59:59.999000'): {'num': 113,
#   'time_open': Timestamp('2025-07-15 11:00:00'),
#   'time_close': Timestamp('2025-07-15 11:59:59.999000'),
#   'MNQ/USD': {'open': 24077.25,
#    'high': 24099.75,
#    'low': 24060.0,
#    'close': 24073.5,
#    'volume': 20218.0,
#    'indicators': {'dema_10': 24090.578329032316, 'sma_32': 23913.1015625}}},
#  Timestamp('2025-07-15 12:59:59.999000'): {'num': 114,
#   'time_open': Timestamp('2025-07-15 12:00:00'),
#   'time_close': Timestamp('2025-07-15 12:59:59.999000'),
#   'MNQ/USD': {'open': 24074.0,
#    'high': 24116.25,
#    'low': 24040.75,
#    'close': 24103.25,
#    'volume': 60073.0,
#    'indicators': {'dema_10': 24101.92747235915, 'sma_32': 23923.53125}}},
#  Timestamp('2025-07-15 13:59:59.999000'): {'num': 115,
#   'time_open': Timestamp('2025-07-15 13:00:00'),
#   'time_close': Timestamp('2025-07-15 13:59:59.999000'),
#   'MNQ/USD': {'open': 24103.75,
#    'high': 24131.5,
#    'low': 24027.5,
#    'close': 24043.5,
#    'volume': 185608.0,
#    'indicators': {'dema_10': 24089.816486574335, 'sma_32': 23932.4765625}}},
#  Timestamp('2025-07-15 14:59:59.999000'): {'num': 116,
#   'time_open': Timestamp('2025-07-15 14:00:00'),
#   'time_close': Timestamp('2025-07-15 14:59:59.999000'),
#   'MNQ/USD': {'open': 24044.25,
#    'high': 24106.0,
#    'low': 23999.25,
#    'close': 24003.5,
#    'volume': 231428.0,
#    'indicators': {'dema_10': 24066.954868434932, 'sma_32': 23941.1875}}},
#  Timestamp('2025-07-15 15:59:59.999000'): {'num': 117,
#   'time_open': Timestamp('2025-07-15 15:00:00'),
#   'time_close': Timestamp('2025-07-15 15:59:59.999000'),
#   'MNQ/USD': {'open': 24003.5,
#    'high': 24088.25,
#    'low': 24003.25,
#    'close': 24063.5,
#    'volume': 142216.0,
#    'indicators': {'dema_10': 24069.38783915368, 'sma_32': 23951.4296875}}},
#  Timestamp('2025-07-15 16:59:59.999000'): {'num': 118,
#   'time_open': Timestamp('2025-07-15 16:00:00'),
#   'time_close': Timestamp('2025-07-15 16:59:59.999000'),
#   'MNQ/USD': {'open': 24063.75,
#    'high': 24074.75,
#    'low': 23985.75,
#    'close': 24002.75,
#    'volume': 106441.0,
#    'indicators': {'dema_10': 24050.739238092556, 'sma_32': 23958.4609375}}},
#  Timestamp('2025-07-15 17:59:59.999000'): {'num': 119,
#   'time_open': Timestamp('2025-07-15 17:00:00'),
#   'time_close': Timestamp('2025-07-15 17:59:59.999000'),
#   'MNQ/USD': {'open': 24002.5,
#    'high': 24077.75,
#    'low': 23990.0,
#    'close': 24076.75,
#    'volume': 97640.0,
#    'indicators': {'dema_10': 24061.131852651884, 'sma_32': 23967.6484375}}},
#  Timestamp('2025-07-15 18:59:59.999000'): {'num': 120,
#   'time_open': Timestamp('2025-07-15 18:00:00'),
#   'time_close': Timestamp('2025-07-15 18:59:59.999000'),
#   'MNQ/USD': {'open': 24076.5,
#    'high': 24087.0,
#    'low': 23998.0,
#    'close': 23998.0,
#    'volume': 89984.0,
#    'indicators': {'dema_10': 24042.572136690713, 'sma_32': 23973.96875}}},
#  Timestamp('2025-07-15 19:59:59.999000'): {'num': 121,
#   'time_open': Timestamp('2025-07-15 19:00:00'),
#   'time_close': Timestamp('2025-07-15 19:59:59.999000'),
#   'MNQ/USD': {'open': 23998.25,
#    'high': 24027.25,
#    'low': 23952.0,
#    'close': 23954.5,
#    'volume': 124986.0,
#    'indicators': {'dema_10': 24014.294239669078, 'sma_32': 23979.6484375}}},
#  Timestamp('2025-07-15 20:59:59.999000'): {'num': 122,
#   'time_open': Timestamp('2025-07-15 20:00:00'),
#   'time_close': Timestamp('2025-07-15 20:59:59.999000'),
#   'MNQ/USD': {'open': 23954.5,
#    'high': 23962.0,
#    'low': 23911.0,
#    'close': 23918.75,
#    'volume': 42703.0,
#    'indicators': {'dema_10': 23981.569556880408, 'sma_32': 23983.8984375}}},
#  Timestamp('2025-07-15 22:59:59.999000'): {'num': 123,
#   'time_open': Timestamp('2025-07-15 22:00:00'),
#   'time_close': Timestamp('2025-07-15 22:59:59.999000'),
#   'MNQ/USD': {'open': 23919.5,
#    'high': 23935.0,
#    'low': 23872.75,
#    'close': 23909.75,
#    'volume': 24951.0,
#    'indicators': {'dema_10': 23954.611064868808, 'sma_32': 23987.46875}}},
#  Timestamp('2025-07-15 23:59:59.999000'): {'num': 124,
#   'time_open': Timestamp('2025-07-15 23:00:00'),
#   'time_close': Timestamp('2025-07-15 23:59:59.999000'),
#   'MNQ/USD': {'open': 23910.25,
#    'high': 23921.25,
#    'low': 23880.25,
#    'close': 23915.0,
#    'volume': 16300.0,
#    'indicators': {'dema_10': 23936.816997824055, 'sma_32': 23990.8046875}}},
#  Timestamp('2025-07-16 00:59:59.999000'): {'num': 125,
#   'time_open': Timestamp('2025-07-16 00:00:00'),
#   'time_close': Timestamp('2025-07-16 00:59:59.999000'),
#   'MNQ/USD': {'open': 23915.0,
#    'high': 23920.25,
#    'low': 23876.75,
#    'close': 23899.75,
#    'volume': 19124.0,
#    'indicators': {'dema_10': 23919.14272160983, 'sma_32': 23991.0546875}}},
#  Timestamp('2025-07-16 01:59:59.999000'): {'num': 126,
#   'time_open': Timestamp('2025-07-16 01:00:00'),
#   'time_close': Timestamp('2025-07-16 01:59:59.999000'),
#   'MNQ/USD': {'open': 23899.25,
#    'high': 23933.0,
#    'low': 23897.0,
#    'close': 23931.75,
#    'volume': 16881.0,
#    'indicators': {'dema_10': 23917.24861202478, 'sma_32': 23991.7578125}}},
#  Timestamp('2025-07-16 02:59:59.999000'): {'num': 127,
#   'time_open': Timestamp('2025-07-16 02:00:00'),
#   'time_close': Timestamp('2025-07-16 02:59:59.999000'),
#   'MNQ/USD': {'open': 23931.75,
#    'high': 23935.75,
#    'low': 23907.0,
#    'close': 23913.0,
#    'volume': 9893.0,
#    'indicators': {'dema_10': 23910.261691987685, 'sma_32': 23991.0703125}}},
#  Timestamp('2025-07-16 03:59:59.999000'): {'num': 128,
#   'time_open': Timestamp('2025-07-16 03:00:00'),
#   'time_close': Timestamp('2025-07-16 03:59:59.999000'),
#   'MNQ/USD': {'open': 23912.5,
#    'high': 23929.25,
#    'low': 23912.0,
#    'close': 23916.25,
#    'volume': 7164.0,
#    'indicators': {'dema_10': 23906.7494003269, 'sma_32': 23990.125}}},
#  Timestamp('2025-07-16 04:59:59.999000'): {'num': 129,
#   'time_open': Timestamp('2025-07-16 04:00:00'),
#   'time_close': Timestamp('2025-07-16 04:59:59.999000'),
#   'MNQ/USD': {'open': 23916.25,
#    'high': 23933.25,
#    'low': 23916.0,
#    'close': 23921.0,
#    'volume': 5978.0,
#    'indicators': {'dema_10': 23906.282514163, 'sma_32': 23989.109375}}},
#  Timestamp('2025-07-16 05:59:59.999000'): {'num': 130,
#   'time_open': Timestamp('2025-07-16 05:00:00'),
#   'time_close': Timestamp('2025-07-16 05:59:59.999000'),
#   'MNQ/USD': {'open': 23922.0,
#    'high': 23947.5,
#    'low': 23893.5,
#    'close': 23907.25,
#    'volume': 18706.0,
#    'indicators': {'dema_10': 23901.91104444459, 'sma_32': 23988.234375}}},
#  Timestamp('2025-07-16 06:59:59.999000'): {'num': 131,
#   'time_open': Timestamp('2025-07-16 06:00:00'),
#   'time_close': Timestamp('2025-07-16 06:59:59.999000'),
#   'MNQ/USD': {'open': 23906.75,
#    'high': 23909.75,
#    'low': 23864.0,
#    'close': 23870.5,
#    'volume': 16134.0,
#    'indicators': {'dema_10': 23887.012422750628, 'sma_32': 23986.1328125}}},
#  Timestamp('2025-07-16 07:59:59.999000'): {'num': 132,
#   'time_open': Timestamp('2025-07-16 07:00:00'),
#   'time_close': Timestamp('2025-07-16 07:59:59.999000'),
#   'MNQ/USD': {'open': 23870.0,
#    'high': 23890.25,
#    'low': 23825.75,
#    'close': 23881.5,
#    'volume': 25645.0,
#    'indicators': {'dema_10': 23880.129463674486, 'sma_32': 23985.484375}}},
#  Timestamp('2025-07-16 08:59:59.999000'): {'num': 133,
#   'time_open': Timestamp('2025-07-16 08:00:00'),
#   'time_close': Timestamp('2025-07-16 08:59:59.999000'),
#   'MNQ/USD': {'open': 23881.5,
#    'high': 23915.25,
#    'low': 23867.75,
#    'close': 23902.5,
#    'volume': 17287.0,
#    'indicators': {'dema_10': 23882.509318716915, 'sma_32': 23985.1875}}},
#  Timestamp('2025-07-16 09:59:59.999000'): {'num': 134,
#   'time_open': Timestamp('2025-07-16 09:00:00'),
#   'time_close': Timestamp('2025-07-16 09:59:59.999000'),
#   'MNQ/USD': {'open': 23902.5,
#    'high': 23905.0,
#    'low': 23878.25,
#    'close': 23900.75,
#    'volume': 12650.0,
#    'indicators': {'dema_10': 23884.18478139104, 'sma_32': 23985.03125}}},
#  Timestamp('2025-07-16 10:59:59.999000'): {'num': 135,
#   'time_open': Timestamp('2025-07-16 10:00:00'),
#   'time_close': Timestamp('2025-07-16 10:59:59.999000'),
#   'MNQ/USD': {'open': 23901.0,
#    'high': 23920.75,
#    'low': 23892.5,
#    'close': 23913.75,
#    'volume': 11797.0,
#    'indicators': {'dema_10': 23890.151503300465, 'sma_32': 23980.8125}}},
#  Timestamp('2025-07-16 11:59:59.999000'): {'num': 136,
#   'time_open': Timestamp('2025-07-16 11:00:00'),
#   'time_close': Timestamp('2025-07-16 11:59:59.999000'),
#   'MNQ/USD': {'open': 23914.25,
#    'high': 23925.0,
#    'low': 23894.75,
#    'close': 23921.25,
#    'volume': 15716.0,
#    'indicators': {'dema_10': 23897.405209593537, 'sma_32': 23979.6640625}}},
#  Timestamp('2025-07-16 12:59:59.999000'): {'num': 137,
#   'time_open': Timestamp('2025-07-16 12:00:00'),
#   'time_close': Timestamp('2025-07-16 12:59:59.999000'),
#   'MNQ/USD': {'open': 23921.25,
#    'high': 23987.5,
#    'low': 23910.25,
#    'close': 23976.75,
#    'volume': 47897.0,
# ...
#    'high': 24422.5,
#    'low': 24378.0,
#    'close': 24387.0,
#    'volume': 12569.0,
#    'indicators': {'dema_10': 24406.34811258505, 'sma_32': 24321.9375}}},
#  Timestamp('2025-09-04 06:59:59.999000'): {'num': 955,
#   'time_open': Timestamp('2025-09-04 06:00:00'),
#   'time_close': Timestamp('2025-09-04 06:59:59.999000'),
#   'MNQ/USD': {'open': 24387.0,
#    'high': 24403.0,
#    'low': 24369.75,
#    'close': 24372.0,
#    'volume': 15263.0,
#    'indicators': {'dema_10': 24398.68134899758, 'sma_32': 24324.3671875}}},
#  Timestamp('2025-09-04 07:59:59.999000'): {'num': 956,
#   'time_open': Timestamp('2025-09-04 07:00:00'),
#   'time_close': Timestamp('2025-09-04 07:59:59.999000'),
#   'MNQ/USD': {'open': 24371.5,
#    'high': 24425.75,
#    'low': 24368.25,
#    'close': 24407.5,
#    'volume': 20840.0,
#    'indicators': {'dema_10': 24404.402561835803, 'sma_32': 24329.125}}},
#  Timestamp('2025-09-04 08:59:59.999000'): {'num': 957,
#   'time_open': Timestamp('2025-09-04 08:00:00'),
#   'time_close': Timestamp('2025-09-04 08:59:59.999000'),
#   'MNQ/USD': {'open': 24407.25,
#    'high': 24429.75,
#    'low': 24395.5,
#    'close': 24416.25,
#    'volume': 14435.0,
#    'indicators': {'dema_10': 24411.22742127839, 'sma_32': 24334.390625}}},
#  Timestamp('2025-09-04 09:59:59.999000'): {'num': 958,
#   'time_open': Timestamp('2025-09-04 09:00:00'),
#   'time_close': Timestamp('2025-09-04 09:59:59.999000'),
#   'MNQ/USD': {'open': 24417.0,
#    'high': 24438.25,
#    'low': 24411.25,
#    'close': 24436.5,
#    'volume': 8999.0,
#    'indicators': {'dema_10': 24422.65637937538, 'sma_32': 24340.4140625}}},
#  Timestamp('2025-09-04 10:59:59.999000'): {'num': 959,
#   'time_open': Timestamp('2025-09-04 10:00:00'),
#   'time_close': Timestamp('2025-09-04 10:59:59.999000'),
#   'MNQ/USD': {'open': 24436.25,
#    'high': 24456.75,
#    'low': 24422.75,
#    'close': 24429.25,
#    'volume': 17685.0,
#    'indicators': {'dema_10': 24428.368115642774, 'sma_32': 24346.015625}}},
#  Timestamp('2025-09-04 11:59:59.999000'): {'num': 960,
#   'time_open': Timestamp('2025-09-04 11:00:00'),
#   'time_close': Timestamp('2025-09-04 11:59:59.999000'),
#   'MNQ/USD': {'open': 24428.75,
#    'high': 24441.75,
#    'low': 24399.25,
#    'close': 24416.5,
#    'volume': 20720.0,
#    'indicators': {'dema_10': 24428.005951800526, 'sma_32': 24351.6953125}}},
#  Timestamp('2025-09-04 12:59:59.999000'): {'num': 961,
#   'time_open': Timestamp('2025-09-04 12:00:00'),
#   'time_close': Timestamp('2025-09-04 12:59:59.999000'),
#   'MNQ/USD': {'open': 24416.25,
#    'high': 24449.75,
#    'low': 24387.75,
#    'close': 24404.0,
#    'volume': 37442.0,
#    'indicators': {'dema_10': 24423.250918094538, 'sma_32': 24356.90625}}},
#  Timestamp('2025-09-04 13:59:59.999000'): {'num': 962,
#   'time_open': Timestamp('2025-09-04 13:00:00'),
#   'time_close': Timestamp('2025-09-04 13:59:59.999000'),
#   'MNQ/USD': {'open': 24403.75,
#    'high': 24469.75,
#    'low': 24375.25,
#    'close': 24396.75,
#    'volume': 197532.0,
#    'indicators': {'dema_10': 24417.034708156003, 'sma_32': 24361.671875}}},
#  Timestamp('2025-09-04 14:59:59.999000'): {'num': 963,
#   'time_open': Timestamp('2025-09-04 14:00:00'),
#   'time_close': Timestamp('2025-09-04 14:59:59.999000'),
#   'MNQ/USD': {'open': 24398.0,
#    'high': 24451.0,
#    'low': 24326.0,
#    'close': 24442.0,
#    'volume': 278131.0,
#    'indicators': {'dema_10': 24427.16155247298, 'sma_32': 24368.3046875}}},
#  Timestamp('2025-09-04 15:59:59.999000'): {'num': 964,
#   'time_open': Timestamp('2025-09-04 15:00:00'),
#   'time_close': Timestamp('2025-09-04 15:59:59.999000'),
#   'MNQ/USD': {'open': 24442.75,
#    'high': 24477.75,
#    'low': 24411.25,
#    'close': 24459.5,
#    'volume': 150154.0,
#    'indicators': {'dema_10': 24440.216330818293, 'sma_32': 24374.5703125}}},
#  Timestamp('2025-09-04 16:59:59.999000'): {'num': 965,
#   'time_open': Timestamp('2025-09-04 16:00:00'),
#   'time_close': Timestamp('2025-09-04 16:59:59.999000'),
#   'MNQ/USD': {'open': 24459.75,
#    'high': 24487.5,
#    'low': 24433.0,
#    'close': 24459.0,
#    'volume': 97501.0,
#    'indicators': {'dema_10': 24449.427667369513, 'sma_32': 24379.8125}}},
#  Timestamp('2025-09-04 17:59:59.999000'): {'num': 966,
#   'time_open': Timestamp('2025-09-04 17:00:00'),
#   'time_close': Timestamp('2025-09-04 17:59:59.999000'),
#   'MNQ/USD': {'open': 24459.75,
#    'high': 24528.0,
#    'low': 24457.5,
#    'close': 24506.25,
#    'volume': 93774.0,
#    'indicators': {'dema_10': 24471.5302094453, 'sma_32': 24385.140625}}},
#  Timestamp('2025-09-04 18:59:59.999000'): {'num': 967,
#   'time_open': Timestamp('2025-09-04 18:00:00'),
#   'time_close': Timestamp('2025-09-04 18:59:59.999000'),
#   'MNQ/USD': {'open': 24506.5,
#    'high': 24549.0,
#    'low': 24505.25,
#    'close': 24544.25,
#    'volume': 68573.0,
#    'indicators': {'dema_10': 24500.035871183794, 'sma_32': 24391.0390625}}},
#  Timestamp('2025-09-04 19:59:59.999000'): {'num': 968,
#   'time_open': Timestamp('2025-09-04 19:00:00'),
#   'time_close': Timestamp('2025-09-04 19:59:59.999000'),
#   'MNQ/USD': {'open': 24544.25,
#    'high': 24607.25,
#    'low': 24540.75,
#    'close': 24592.25,
#    'volume': 105591.0,
#    'indicators': {'dema_10': 24536.447566358034, 'sma_32': 24398.3515625}}},
#  Timestamp('2025-09-04 20:59:59.999000'): {'num': 969,
#   'time_open': Timestamp('2025-09-04 20:00:00'),
#   'time_close': Timestamp('2025-09-04 20:59:59.999000'),
#   'MNQ/USD': {'open': 24592.5,
#    'high': 24636.75,
#    'low': 24584.25,
#    'close': 24610.5,
#    'volume': 45883.0,
#    'indicators': {'dema_10': 24568.700103909116, 'sma_32': 24407.0625}}},
#  Timestamp('2025-09-04 22:59:59.999000'): {'num': 970,
#   'time_open': Timestamp('2025-09-04 22:00:00'),
#   'time_close': Timestamp('2025-09-04 22:59:59.999000'),
#   'MNQ/USD': {'open': 24621.25,
#    'high': 24642.0,
#    'low': 24619.0,
#    'close': 24635.25,
#    'volume': 15176.0,
#    'indicators': {'dema_10': 24599.854278504168, 'sma_32': 24416.2890625}}},
#  Timestamp('2025-09-04 23:59:59.999000'): {'num': 971,
#   'time_open': Timestamp('2025-09-04 23:00:00'),
#   'time_close': Timestamp('2025-09-04 23:59:59.999000'),
#   'MNQ/USD': {'open': 24634.75,
#    'high': 24650.25,
#    'low': 24632.25,
#    'close': 24634.0,
#    'volume': 10390.0,
#    'indicators': {'dema_10': 24621.46643576188, 'sma_32': 24426.828125}}},
#  Timestamp('2025-09-05 00:59:59.999000'): {'num': 972,
#   'time_open': Timestamp('2025-09-05 00:00:00'),
#   'time_close': Timestamp('2025-09-05 00:59:59.999000'),
#   'MNQ/USD': {'open': 24634.0,
#    'high': 24660.5,
#    'low': 24629.25,
#    'close': 24658.5,
#    'volume': 12872.0,
#    'indicators': {'dema_10': 24644.447584479454, 'sma_32': 24434.0}}},
#  Timestamp('2025-09-05 01:59:59.999000'): {'num': 973,
#   'time_open': Timestamp('2025-09-05 01:00:00'),
#   'time_close': Timestamp('2025-09-05 01:59:59.999000'),
#   'MNQ/USD': {'open': 24657.75,
#    'high': 24668.5,
#    'low': 24653.0,
#    'close': 24663.75,
#    'volume': 9187.0,
#    'indicators': {'dema_10': 24662.031739092727, 'sma_32': 24444.390625}}},
#  Timestamp('2025-09-05 02:59:59.999000'): {'num': 974,
#   'time_open': Timestamp('2025-09-05 02:00:00'),
#   'time_close': Timestamp('2025-09-05 02:59:59.999000'),
#   'MNQ/USD': {'open': 24663.5,
#    'high': 24671.25,
#    'low': 24646.25,
#    'close': 24665.25,
#    'volume': 9701.0,
#    'indicators': {'dema_10': 24674.35561981425, 'sma_32': 24454.953125}}},
#  Timestamp('2025-09-05 03:59:59.999000'): {'num': 975,
#   'time_open': Timestamp('2025-09-05 03:00:00'),
#   'time_close': Timestamp('2025-09-05 03:59:59.999000'),
#   'MNQ/USD': {'open': 24665.5,
#    'high': 24672.5,
#    'low': 24658.0,
#    'close': 24670.25,
#    'volume': 6083.0,
#    'indicators': {'dema_10': 24683.957370716613, 'sma_32': 24467.1640625}}},
#  Timestamp('2025-09-05 04:59:59.999000'): {'num': 976,
#   'time_open': Timestamp('2025-09-05 04:00:00'),
#   'time_close': Timestamp('2025-09-05 04:59:59.999000'),
#   'MNQ/USD': {'open': 24670.5,
#    'high': 24680.5,
#    'low': 24668.75,
#    'close': 24674.0,
#    'volume': 6421.0,
#    'indicators': {'dema_10': 24691.171522288725, 'sma_32': 24480.25}}},
#  Timestamp('2025-09-05 05:59:59.999000'): {'num': 977,
#   'time_open': Timestamp('2025-09-05 05:00:00'),
#   'time_close': Timestamp('2025-09-05 05:59:59.999000'),
#   'MNQ/USD': {'open': 24674.25,
#    'high': 24700.5,
#    'low': 24669.75,
#    'close': 24691.0,
#    'volume': 10954.0,
#    'indicators': {'dema_10': 24701.053011447286, 'sma_32': 24490.2890625}}},
#  Timestamp('2025-09-05 06:59:59.999000'): {'num': 978,
#   'time_open': Timestamp('2025-09-05 06:00:00'),
#   'time_close': Timestamp('2025-09-05 06:59:59.999000'),
#   'MNQ/USD': {'open': 24691.25,
#    'high': 24719.0,
#    'low': 24688.75,
#    'close': 24702.75,
#    'volume': 13919.0,
#    'indicators': {'dema_10': 24711.21985918327, 'sma_32': 24500.578125}}},
#  Timestamp('2025-09-05 07:59:59.999000'): {'num': 979,
#   'time_open': Timestamp('2025-09-05 07:00:00'),
#   'time_close': Timestamp('2025-09-05 07:59:59.999000'),
#   'MNQ/USD': {'open': 24702.5,
#    'high': 24706.5,
#    'low': 24672.75,
#    'close': 24685.75,
#    'volume': 18761.0,
#    'indicators': {'dema_10': 24712.12593546329, 'sma_32': 24511.0234375}}},
#  Timestamp('2025-09-05 08:59:59.999000'): {'num': 980,
#   'time_open': Timestamp('2025-09-05 08:00:00'),
#   'time_close': Timestamp('2025-09-05 08:59:59.999000'),
#   'MNQ/USD': {'open': 24685.75,
#    'high': 24718.5,
#    'low': 24677.75,
#    'close': 24717.5,
#    'volume': 14526.0,
#    'indicators': {'dema_10': 24722.356418412277, 'sma_32': 24522.34375}}},
#  Timestamp('2025-09-05 09:59:59.999000'): {'num': 981,
#   'time_open': Timestamp('2025-09-05 09:00:00'),
#   'time_close': Timestamp('2025-09-05 09:59:59.999000'),
#   'MNQ/USD': {'open': 24717.5,
#    'high': 24723.0,
#    'low': 24707.75,
#    'close': 24714.5,
#    'volume': 10191.0,
#    'indicators': {'dema_10': 24728.052645232274, 'sma_32': 24531.4296875}}},
#  Timestamp('2025-09-05 10:59:59.999000'): {'num': 982,
#   'time_open': Timestamp('2025-09-05 10:00:00'),
#   'time_close': Timestamp('2025-09-05 10:59:59.999000'),
#   'MNQ/USD': {'open': 24714.5,
#    'high': 24720.75,
#    'low': 24704.5,
#    'close': 24707.0,
#    'volume': 8885.0,
#    'indicators': {'dema_10': 24728.93846169087, 'sma_32': 24540.4921875}}},
#  Timestamp('2025-09-05 11:59:59.999000'): {'num': 983,
#   'time_open': Timestamp('2025-09-05 11:00:00'),
#   'time_close': Timestamp('2025-09-05 11:59:59.999000'),
#   'MNQ/USD': {'open': 24706.75,
#    'high': 24731.5,
#    'low': 24698.0,
#    'close': 24699.5,
#    'volume': 17930.0,
#    'indicators': {'dema_10': 24726.326869016346, 'sma_32': 24549.875}}},
#  Timestamp('2025-09-05 12:59:59.999000'): {'num': 984,
#   'time_open': Timestamp('2025-09-05 12:00:00'),
#   'time_close': Timestamp('2025-09-05 12:59:59.999000'),
#   'MNQ/USD': {'open': 24699.75,
#    'high': 24811.5,
#    'low': 24653.5,
#    'close': 24808.5,
#    'volume': 102777.0,
#    'indicators': {'dema_10': 24759.724831969223, 'sma_32': 24563.0390625}}},
#  Timestamp('2025-09-05 13:59:59.999000'): {'num': 985,
#   'time_open': Timestamp('2025-09-05 13:00:00'),
#   'time_close': Timestamp('2025-09-05 13:59:59.999000'),
#   'MNQ/USD': {'open': 24808.5,
#    'high': 24838.0,
#    'low': 24753.75,
#    'close': 24786.25,
#    'volume': 268878.0,
#    'indicators': {'dema_10': 24776.339176360183, 'sma_32': 24574.7890625}}},
#  Timestamp('2025-09-05 14:59:59.999000'): {'num': 986,
#   'time_open': Timestamp('2025-09-05 14:00:00'),
#   'time_close': Timestamp('2025-09-05 14:59:59.999000'),
#   'MNQ/USD': {'open': 24786.25,
#    'high': 24787.5,
#    'low': 24466.25,
#    'close': 24469.0,
#    'volume': 463518.0,
#    'indicators': {'dema_10': 24682.91277297363, 'sma_32': 24577.3515625}}},
#  Timestamp('2025-09-05 15:59:59.999000'): {'num': 987,
#   'time_open': Timestamp('2025-09-05 15:00:00'),
#   'time_close': Timestamp('2025-09-05 15:59:59.999000'),
#   'MNQ/USD': {'open': 24469.25,
#    'high': 24595.25,
#    'low': 24424.75,
#    'close': 24542.75,
#    'volume': 279190.0,
#    'indicators': {'dema_10': 24637.679799699203, 'sma_32': 24582.6875}}},
#  Timestamp('2025-09-05 16:59:59.999000'): {'num': 988,
#   'time_open': Timestamp('2025-09-05 16:00:00'),
#   'time_close': Timestamp('2025-09-05 16:59:59.999000'),
#   'MNQ/USD': {'open': 24542.5,
#    'high': 24584.25,
#    'low': 24517.5,
#    'close': 24580.0,
#    'volume': 158368.0,
#    'indicators': {'dema_10': 24616.575749831227, 'sma_32': 24588.078125}}},
#  Timestamp('2025-09-05 17:59:59.999000'): {'num': 989,
#   'time_open': Timestamp('2025-09-05 17:00:00'),
#   'time_close': Timestamp('2025-09-05 17:59:59.999000'),
#   'MNQ/USD': {'open': 24579.75,
#    'high': 24587.75,
#    'low': 24509.0,
#    'close': 24538.0,
#    'volume': 130207.0,
#    'indicators': {'dema_10': 24587.354832156594, 'sma_32': 24591.8828125}}},
#  Timestamp('2025-09-05 18:59:59.999000'): {'num': 990,
#   'time_open': Timestamp('2025-09-05 18:00:00'),
#   'time_close': Timestamp('2025-09-05 18:59:59.999000'),
#   'MNQ/USD': {'open': 24538.0,
#    'high': 24589.5,
#    'low': 24526.5,
#    'close': 24583.25,
#    'volume': 91906.0,
#    'indicators': {'dema_10': 24581.120834964266, 'sma_32': 24596.46875}}},
#  Timestamp('2025-09-05 19:59:59.999000'): {'num': 991,
#   'time_open': Timestamp('2025-09-05 19:00:00'),
#   'time_close': Timestamp('2025-09-05 19:59:59.999000'),
#   'MNQ/USD': {'open': 24582.75,
#    'high': 24621.0,
#    'low': 24566.5,
#    'close': 24617.5,
#    'volume': 137508.0,
#    'indicators': {'dema_10': 24588.340362960662, 'sma_32': 24602.3515625}}},
#  Timestamp('2025-09-05 20:59:59.999000'): {'num': 992,
#   'time_open': Timestamp('2025-09-05 20:00:00'),
#   'time_close': Timestamp('2025-09-05 20:59:59.999000'),
#   'MNQ/USD': {'open': 24617.5,
#    'high': 24623.5,
#    'low': 24593.0,
#    'close': 24599.5,
#    'volume': 25028.0,
#    'indicators': {'dema_10': 24588.186811852116, 'sma_32': 24608.0703125}}},
#  Timestamp('2025-09-07 22:59:59.999000'): {'num': 993,
#   'time_open': Timestamp('2025-09-07 22:00:00'),
#   'time_close': Timestamp('2025-09-07 22:59:59.999000'),
#   'MNQ/USD': {'open': 24603.0,
#    'high': 24678.5,
#    'low': 24576.0,
#    'close': 24669.5,
#    'volume': 32374.0,
#    'indicators': {'dema_10': 24611.59850699922, 'sma_32': 24616.3671875}}},
#  Timestamp('2025-09-07 23:59:59.999000'): {'num': 994,
#   'time_open': Timestamp('2025-09-07 23:00:00'),
#   'time_close': Timestamp('2025-09-07 23:59:59.999000'),
#   'MNQ/USD': {'open': 24669.75,
#    'high': 24715.25,
#    'low': 24669.25,
#    'close': 24708.25,
#    'volume': 24255.0,
#    'indicators': {'dema_10': 24641.994815089456, 'sma_32': 24626.1015625}}},
#  Timestamp('2025-09-08 00:59:59.999000'): {'num': 995,
#   'time_open': Timestamp('2025-09-08 00:00:00'),
#   'time_close': Timestamp('2025-09-08 00:59:59.999000'),
#   'MNQ/USD': {'open': 24708.5,
#    'high': 24723.0,
#    'low': 24693.75,
#    'close': 24694.25,
#    'volume': 20476.0,
#    'indicators': {'dema_10': 24659.90491174194, 'sma_32': 24633.984375}}},
#  Timestamp('2025-09-08 01:59:59.999000'): {'num': 996,
#   'time_open': Timestamp('2025-09-08 01:00:00'),
#   'time_close': Timestamp('2025-09-08 01:59:59.999000'),
#   'MNQ/USD': {'open': 24694.5,
#    'high': 24710.0,
#    'low': 24687.0,
#    'close': 24698.0,
#    'volume': 15028.0,
#    'indicators': {'dema_10': 24674.269359526104, 'sma_32': 24641.4375}}},
#  Timestamp('2025-09-08 02:59:59.999000'): {'num': 997,
#   'time_open': Timestamp('2025-09-08 02:00:00'),
#   'time_close': Timestamp('2025-09-08 02:59:59.999000'),
#   'MNQ/USD': {'open': 24699.0,
#    'high': 24701.5,
#    'low': 24664.5,
#    'close': 24670.0,
#    'volume': 13927.0,
#    'indicators': {'dema_10': 24675.413515165885, 'sma_32': 24648.03125}}},
#  Timestamp('2025-09-08 03:59:59.999000'): {'num': 998,
#   'time_open': Timestamp('2025-09-08 03:00:00'),
#   'time_close': Timestamp('2025-09-08 03:59:59.999000'),
#   'MNQ/USD': {'open': 24670.5,
#    'high': 24693.0,
#    'low': 24669.75,
#    'close': 24684.0,
#    'volume': 10825.0,
#    'indicators': {'dema_10': 24680.628577530828, 'sma_32': 24653.5859375}}},
#  Timestamp('2025-09-08 04:59:59.999000'): {'num': 999,
#   'time_open': Timestamp('2025-09-08 04:00:00'),
#   'time_close': Timestamp('2025-09-08 04:59:59.999000'),
#   'MNQ/USD': {'open': 24683.5,
#    'high': 24685.5,
#    'low': 24654.75,
#    'close': 24662.5,
#    'volume': 10301.0,
#    'indicators': {'dema_10': 24677.123666303036, 'sma_32': 24657.28125}}},
#  ...}

# %%
# single DEMA(fast)/SMA(slow) crossover strategy, full weight -- see
# MNQ/step_1_find_best_indicators_and_parameters.ipynb for how these parameters were picked.
portfolio = Portfolio(weighted_strategies=[
    WeightedStrategy(
        weight=1.0,
        strategy=MaCrossoverStrategy(
            key=f"DEMA_{DEMA_FAST_LEN}_SMA_{DEMA_SMA_SLOW}_MNQ",
            market=market,
            symbol=SYMBOL,
            direction=StrategyDirection.long,
            fast_indicator_key=f"{DEMA_INDICATOR_NAME}_{DEMA_FAST_LEN}",
            slow_indicator_key=f"{SMA_INDICATOR_NAME}_{DEMA_SMA_SLOW}",
            sl_percent=0.3,
            tp_percent=0.6,
            sl_enabled=True,
            tp_enabled=True,
        ),
    ),
], output_scale=1)

print("Portfolio is ready!")
# Out:
# Portfolio is ready!

# %%
# Tradovate per-symbol config: point value / tick size / min size-step / fees.
# MNQ has a real tick_size and fee_per_contract_override set directly on
# TRADOVATE_FUTURES in exchange_config.py (see PROP_FIRM_PLAN.md for the research).
symbol_config_provider = TradovateSymbolConfigProvider(symbols=TRADOVATE_FUTURES, default_fee_per_contract=0.0)

# instantiate exchange -- futures, point-value/tick-based math via symbol_config_provider
# (slippage/maker_fee/taker_fee below are unused once symbol_config_provider is set, but
# still required constructor args).
exchange = Exchange(
            market=market,
            slippage=0.0,
            maker_fee=0.0,
            taker_fee=0.0,
            market_type=MarketType.future,
            max_leverage=10,  # NOTE: this system doesn't model Tradovate's real per-symbol
                               # exchange-set margin schedule yet -- max_leverage is a stand-in.
            margin_allocation_type=MarginAllocationType.cross,
            symbol_config_provider=symbol_config_provider,
        )

# %%
# instantiate reporter
# periods_per_year=252: real trading-days/year convention for futures (not 365,
# which is only correct for a 24/7 crypto market -- see PerformanceAnalyzer's own
# docstring). Using the wrong constant here previously inflated every Sharpe/
# Sortino/annualized-volatility number in this pipeline by sqrt(365/252) =~ 1.20
# (~20%) versus the correct figure -- CAGR/Calmar/max_drawdown/net_return are
# unaffected since they don't depend on periods_per_year.
reporter = PerformanceAnalyzer(market=market,
                    exchange=exchange,
                    portfolio=portfolio,
                    benchmark_symbols=[SYMBOL],
                    periods_per_year=252)

# %%
# run only one next step
market.reset()

# Tradeify Growth $50k account: $2,000 (4%) EOD-trailing drawdown, permanently halts
# trading (account_failed) once breached -- see middleware.py / PROP_FIRM_PLAN.md.
# Now also models Tradeify's real lock-once-reached mechanic: the trailing floor
# freezes permanently at initial_balance + $100 the first time EOD balance reaches
# initial_balance * (1 + drawdown_percent) + $100 (e.g. $52,100 for this account),
# rather than continuing to trail upward forever past that point.
drawdown_middleware = TradeifyDrawdownMiddleware(drawdown_percent=0.04)
# Tradeify's real $1,250/day soft daily-loss pause on a $50k account (2.5% of
# balance): flattens and halts for the rest of the trading day, then resumes
# normally the next day (unlike the drawdown middleware's permanent halt).
# Previously not modeled at all in this pipeline despite being a real,
# already-documented Tradeify rule (PROP_FIRM_PLAN.md).
daily_loss_middleware = MaxDailyLossMiddleware(max_loss_percent=0.025)

backtest = Backtester(
    market=market,
    portfolio=portfolio,
    exchange=exchange,
    reporter=reporter,
    middlewares=[daily_loss_middleware, drawdown_middleware],
)
# deposit prop-firm-sized funds so we can trade
backtest.exchange.transactions.add_deposit(asset="USD", volume=50000)
backtest.run_all()

# Print Report
print("Candles Processed: ", backtest.market.current['num'])
print("Account failed (drawdown breach): ", drawdown_middleware.account_failed)
print("Drawdown floor locked (reached profit buffer): ", drawdown_middleware.locked)
# formatted HTML table (description column + color-coded cells) instead of the raw
# numeric DataFrame -- see backtester.performance.report_html for the per-metric rules.
display(HTML(backtest.reporter.summary_html_table()))

if backtest.reporter.merged is not None:
    # Print a chart to compare the returns
    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__cumulative_returns",
        f"{SYMBOL}__cumulative_returns"
        ], figsize=(30,6))

    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__drawdown",
        f"{SYMBOL}__drawdown"
        ], figsize=(30,6))

    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__exchange_net_exposure",
        "algo__portfolio_net_exposure"
        ], figsize=(30,6))
# Out:
# Candles Processed:  5312
# Account failed (drawdown breach):  False
# Drawdown floor locked (reached profit buffer):  True
# <table style="border-collapse:collapse;font-family:sans-serif;font-size:13px;"><thead><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">metric</th><th style="border:1px solid #ddd;padding:4px 10px;">algo</th><th style="border:1px solid #ddd;padding:4px 10px;">MNQ/USD</th><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">description</th></tr></thead><tbody><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">sharpe_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">0.8201</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">1.3682</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Return per unit of total volatility. &lt;0 bad, ~1 decent, &gt;2 great, &gt;3 excellent.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">sortino_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">1.2972</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">2.0426</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Like Sharpe but only penalizes downside volatility (upside swings aren&#x27;t &quot;risk&quot;). &gt;2 good, &gt;3 excellent.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">annualized_volatility_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">8.8412</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">15.2870</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">How much the equity curve swings per year. Lower = smoother.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">cagr_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">10.4471</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">33.1033</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Compound annual growth rate, the smoothed annual growth rate. Higher is generally better, but always weigh against volatility/drawdown.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">calmar_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;">1.2171</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">2.3996</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">CAGR ÷ max drawdown. &gt;1 decent, &gt;3 excellent, &lt;0.5 weak.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">recovery_factor</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">1.0881</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">2.1240</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Total net profit ÷ max drawdown. &gt;2 solid.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">max_drawdown_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">-8.5838</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">-13.7952</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Largest peak-to-trough loss. Closer to 0 better; below -20% starts getting painful for most in ...

# %%
# market.merged
pd.DataFrame(backtest.exchange.get_logs())
# Out:
#                        time                                            message
# 0   2025-07-08 14:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 1   2025-07-11 17:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 2   2025-07-11 20:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 3   2025-07-14 14:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 4   2025-07-15 20:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# ..                      ...                                                ...
# 210 2026-05-26 13:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 211 2026-05-27 16:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 212 2026-05-28 14:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 213 2026-06-01 14:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 214 2026-06-01 15:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
#
# [215 rows x 2 columns]

# %%
# get dataframe with all the trades that were executed
def _trade_to_dict(trade):
    d = trade.__dict__.copy()
    for k, v in d.items():
        if hasattr(v, "value"):
            d[k] = v.value
    return d

pd.DataFrame([_trade_to_dict(t) for t in backtest.reporter.trades])
# Out:
#       symbol  side            time_open           time_close  open_price  \
# 0    MNQ/USD  long  1752256799999000000  1752267599999000000    23898.50
# 1    MNQ/USD  long  1752505199999000000  1752613199999000000    23891.75
# 2    MNQ/USD  long  1752695999999000000  1752857999999000000    23977.75
# 3    MNQ/USD  long  1753073999999000000  1753171199999000000    24180.25
# 4    MNQ/USD  long  1753264799999000000  1753279199999000000    24182.50
# ..       ...   ...                  ...                  ...         ...
# 102  MNQ/USD  long  1778648399999000000  1778817599999000000    29576.50
# 103  MNQ/USD  long  1779109199999000000  1779116399999000000    29699.00
# 104  MNQ/USD  long  1779263999999000000  1779764399999000000    29314.25
# 105  MNQ/USD  long  1779803999999000000  1779901199999000000    30302.50
# 106  MNQ/USD  long  1779980399999000000  1780325999999000000    30486.00
#
#      close_price close_reason       pnl  result   holding_period  risk_percent
# 0       23834.75       signal -0.002668   loser   10800000000000           0.3
# 1       23918.75       signal  0.001130  winner  108000000000000           0.3
# 2       24095.00       signal  0.004890  winner  162000000000000           0.3
# 3       24216.50       signal  0.001499  winner   97200000000000           0.3
# 4       24072.25       signal -0.004559   loser   14400000000000           0.3
# ..           ...          ...       ...     ...              ...           ...
# 102     29856.25       signal  0.009459  winner  169200000000000           0.3
# 103     29368.75       signal -0.011120   loser    7200000000000           0.3
# 104     30112.00       signal  0.027214  winner  500400000000000           0.3
# 105     30284.25       signal -0.000602   loser   97200000000000           0.3
# 106     30738.00       signal  0.008266  winner  345600000000000           0.3
#
# [107 rows x 11 columns]
