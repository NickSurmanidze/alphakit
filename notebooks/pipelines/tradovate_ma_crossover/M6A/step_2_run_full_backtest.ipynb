# %% [markdown]
# # M6A (Micro AUD/USD) — MA crossover, Tradovate exchange
#
# Mirrors `MES/step_2_run_full_backtest.ipynb`'s MA-crossover setup, applied to **Micro AUD/USD futures** (M6A) instead of MES: real 1h OHLC pulled from this repo's Mongo/Timescale store (via the shared `data_aggregator.mongo_timescale_aggregator` module), whole-contract position sizing, tick-based slippage + per-contract fees, and a Tradeify-style EOD-trailing drawdown risk middleware.
#
# **Strategy**: a single crossover -- the winner of the four-way indicator-family comparison (KAMA, EMA, HMA, DEMA, each fast-line paired against a plain SMA slow line) run in `M6A/step_1_find_best_indicators_and_parameters.ipynb`, selected by a trade-level Sharpe lower bound rather than raw return (see that notebook's "Methodology" and "Final pick" cells for the full reasoning + honest caveats about how much confidence that pick actually supports). Only 2 indicators feed a single strategy here, run through the full event-driven engine: real order fills, margin, whole-contract sizing, and the drawdown middleware, none of which the vectorized notebook models. Same `DATE_FROM`/`DATE_TO` window as that notebook so the two are comparable. Results here will still differ from the vectorized numbers -- that's expected, not a bug, since whole-contract sizing/margin are modeled for real here instead of as a frictionless percentage-return approximation.
#
# **Costs, now researched** (`PROP_FIRM_PLAN.md`, `OPTIMIZATION_RESEARCH_PLAN.md`): M6A tick_size=0.0001 ($1.00/tick, CME spec) and a commission are set directly on `TRADOVATE_FUTURES["M6A"]` in `exchange_config.py`. M6A commission: Tradeify's fee source confirms $1.82 round-turn for "micro contracts like MES and MNQ" but doesn't separately name M6A -- this assumes the same standard-micro rate (-> $0.91/side), not an M6A-specific citation (see `PROP_FIRM_PLAN.md`). The drawdown middleware below uses Tradeify's real $50k-Growth-account number (4%, not this middleware's generic 5% default) and models the real lock-once-reached trail-freeze mechanic.

# %%
import json
import os

import pandas as pd
from IPython.display import HTML, display

from backtester.backtest_runner import Backtester
from backtester.exchange import Exchange, MarginAllocationType, MarketType, TradovateSymbolConfigProvider
from backtester.exchange_config import TRADOVATE_FUTURES
from backtester.indicators import Indicators
from backtester.market import Market
from backtester.middleware import MaxDailyLossMiddleware, TradeifyDrawdownMiddleware
from backtester.performance import PerformanceAnalyzer
from backtester.portfolio import Portfolio, WeightedStrategy
from backtester.strategies import MaCrossoverStrategy, StrategyDirection
from data_aggregator.mongo_timescale_aggregator import fetch_market_data

cwd = os.getcwd()
print(cwd)
# Out:
# /Users/nick/Documents/www/alphakit/notebooks/pipelines/tradovate_ma_crossover/M6A

# %%
# Instantiate markets class
market = Market()

# ALL INTERVALS SHOULD BE THE SAME!!
INTERVAL = 1
UNIT_OF_TIME = "hour"

DISPLAY_SYMBOL = "M6A"       # bare symbol, as registered in Mongo `instruments`
SYMBOL = "M6A/USD"           # backtester-internal symbol (asset/quote)
SOURCE = "ib"                # Interactive Brokers continuous futures contract
RESOLUTION = "1_hour"

# Same window as notebooks/vectorized_backtest_mes_tradovate.ipynb, for comparability.
DATE_FROM = "2019-10-01"
DATE_TO = "2026-06-01"

# Winner of the 4-indicator-family comparison in step_1 (the strongest standalone
# result of all 6 instruments tested this session, see step_1's "Final pick" cell):
# KAMA(fast)/SMA(slow), long_len=102, short_len=58, EMA consts at Kaufman's defaults.
KAMA_FAST_LEN = 58
KAMA_EMA_FAST = 2
KAMA_EMA_SLOW = 30
KAMA_SMA_SLOW = 102

ohlc = fetch_market_data(source=SOURCE, display_symbol=DISPLAY_SYMBOL, resolution=RESOLUTION)
ohlc = ohlc.loc[DATE_FROM:DATE_TO]

market.add_market(
    symbol=SYMBOL,
    df=ohlc
    )

# --- KAMA(fast)/SMA(slow) crossover indicators -- only 2, one per side of the
# crossover, instead of also running a separate plain-SMA/SMA crossover alongside it.
KAMA_INDICATOR_NAME = 'kama'
SMA_INDICATOR_NAME = 'sma'
market.add_indicator(
    symbol=SYMBOL,
    interval=INTERVAL,
    unit_of_time=UNIT_OF_TIME,
    indicator_name=f"{KAMA_INDICATOR_NAME}_{KAMA_FAST_LEN}",
    df=Indicators.kama(ohlc, length=KAMA_FAST_LEN, fast=KAMA_EMA_FAST, slow=KAMA_EMA_SLOW)
)
market.add_indicator(
    symbol=SYMBOL,
    interval=INTERVAL,
    unit_of_time=UNIT_OF_TIME,
    indicator_name=f"{SMA_INDICATOR_NAME}_{KAMA_SMA_SLOW}",
    df=Indicators.sma(ohlc, KAMA_SMA_SLOW)
)

market.compile()
# Out:
# {Timestamp('2025-07-08 14:50:18.999000'): {'num': 0,
#   'time_open': Timestamp('2025-07-08 13:50:19'),
#   'time_close': Timestamp('2025-07-08 14:50:18.999000'),
#   'M6A/USD': {'open': 0.6569,
#    'high': 0.6572,
#    'low': 0.6569,
#    'close': 0.657,
#    'volume': 51.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 14:59:59.999000'): {'num': 1,
#   'time_open': Timestamp('2025-07-08 14:00:00'),
#   'time_close': Timestamp('2025-07-08 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6568,
#    'high': 0.6569,
#    'low': 0.6552,
#    'close': 0.656,
#    'volume': 1272.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 15:59:59.999000'): {'num': 2,
#   'time_open': Timestamp('2025-07-08 15:00:00'),
#   'time_close': Timestamp('2025-07-08 15:59:59.999000'),
#   'M6A/USD': {'open': 0.656,
#    'high': 0.6572,
#    'low': 0.6559,
#    'close': 0.6569,
#    'volume': 330.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 16:59:59.999000'): {'num': 3,
#   'time_open': Timestamp('2025-07-08 16:00:00'),
#   'time_close': Timestamp('2025-07-08 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6566,
#    'high': 0.6574,
#    'low': 0.6559,
#    'close': 0.6571,
#    'volume': 575.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 17:59:59.999000'): {'num': 4,
#   'time_open': Timestamp('2025-07-08 17:00:00'),
#   'time_close': Timestamp('2025-07-08 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6568,
#    'high': 0.6578,
#    'low': 0.6568,
#    'close': 0.6575,
#    'volume': 305.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 18:59:59.999000'): {'num': 5,
#   'time_open': Timestamp('2025-07-08 18:00:00'),
#   'time_close': Timestamp('2025-07-08 18:59:59.999000'),
#   'M6A/USD': {'open': 0.6576,
#    'high': 0.6576,
#    'low': 0.6569,
#    'close': 0.6573,
#    'volume': 256.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 19:59:59.999000'): {'num': 6,
#   'time_open': Timestamp('2025-07-08 19:00:00'),
#   'time_close': Timestamp('2025-07-08 19:59:59.999000'),
#   'M6A/USD': {'open': 0.6574,
#    'high': 0.6576,
#    'low': 0.6569,
#    'close': 0.657,
#    'volume': 236.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 20:59:59.999000'): {'num': 7,
#   'time_open': Timestamp('2025-07-08 20:00:00'),
#   'time_close': Timestamp('2025-07-08 20:59:59.999000'),
#   'M6A/USD': {'open': 0.657,
#    'high': 0.6576,
#    'low': 0.657,
#    'close': 0.6576,
#    'volume': 190.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 22:59:59.999000'): {'num': 8,
#   'time_open': Timestamp('2025-07-08 22:00:00'),
#   'time_close': Timestamp('2025-07-08 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6575,
#    'high': 0.6575,
#    'low': 0.6571,
#    'close': 0.6575,
#    'volume': 153.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-08 23:59:59.999000'): {'num': 9,
#   'time_open': Timestamp('2025-07-08 23:00:00'),
#   'time_close': Timestamp('2025-07-08 23:59:59.999000'),
#   'M6A/USD': {'open': 0.6574,
#    'high': 0.6575,
#    'low': 0.6568,
#    'close': 0.6568,
#    'volume': 139.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 00:59:59.999000'): {'num': 10,
#   'time_open': Timestamp('2025-07-09 00:00:00'),
#   'time_close': Timestamp('2025-07-09 00:59:59.999000'),
#   'M6A/USD': {'open': 0.6568,
#    'high': 0.6575,
#    'low': 0.6564,
#    'close': 0.657,
#    'volume': 331.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 01:59:59.999000'): {'num': 11,
#   'time_open': Timestamp('2025-07-09 01:00:00'),
#   'time_close': Timestamp('2025-07-09 01:59:59.999000'),
#   'M6A/USD': {'open': 0.6571,
#    'high': 0.658,
#    'low': 0.6566,
#    'close': 0.6575,
#    'volume': 467.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 02:59:59.999000'): {'num': 12,
#   'time_open': Timestamp('2025-07-09 02:00:00'),
#   'time_close': Timestamp('2025-07-09 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6576,
#    'high': 0.6581,
#    'low': 0.6557,
#    'close': 0.6563,
#    'volume': 807.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 03:59:59.999000'): {'num': 13,
#   'time_open': Timestamp('2025-07-09 03:00:00'),
#   'time_close': Timestamp('2025-07-09 03:59:59.999000'),
#   'M6A/USD': {'open': 0.6564,
#    'high': 0.6567,
#    'low': 0.6554,
#    'close': 0.6566,
#    'volume': 441.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 04:59:59.999000'): {'num': 14,
#   'time_open': Timestamp('2025-07-09 04:00:00'),
#   'time_close': Timestamp('2025-07-09 04:59:59.999000'),
#   'M6A/USD': {'open': 0.6566,
#    'high': 0.6583,
#    'low': 0.6566,
#    'close': 0.658,
#    'volume': 610.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 05:59:59.999000'): {'num': 15,
#   'time_open': Timestamp('2025-07-09 05:00:00'),
#   'time_close': Timestamp('2025-07-09 05:59:59.999000'),
#   'M6A/USD': {'open': 0.658,
#    'high': 0.6588,
#    'low': 0.6577,
#    'close': 0.6578,
#    'volume': 526.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 06:59:59.999000'): {'num': 16,
#   'time_open': Timestamp('2025-07-09 06:00:00'),
#   'time_close': Timestamp('2025-07-09 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6578,
#    'high': 0.6587,
#    'low': 0.6568,
#    'close': 0.6587,
#    'volume': 589.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 07:59:59.999000'): {'num': 17,
#   'time_open': Timestamp('2025-07-09 07:00:00'),
#   'time_close': Timestamp('2025-07-09 07:59:59.999000'),
#   'M6A/USD': {'open': 0.6586,
#    'high': 0.6588,
#    'low': 0.6565,
#    'close': 0.657,
#    'volume': 639.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 08:59:59.999000'): {'num': 18,
#   'time_open': Timestamp('2025-07-09 08:00:00'),
#   'time_close': Timestamp('2025-07-09 08:59:59.999000'),
#   'M6A/USD': {'open': 0.6569,
#    'high': 0.6579,
#    'low': 0.6565,
#    'close': 0.6574,
#    'volume': 308.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 09:59:59.999000'): {'num': 19,
#   'time_open': Timestamp('2025-07-09 09:00:00'),
#   'time_close': Timestamp('2025-07-09 09:59:59.999000'),
#   'M6A/USD': {'open': 0.6572,
#    'high': 0.6578,
#    'low': 0.6572,
#    'close': 0.6577,
#    'volume': 106.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 10:59:59.999000'): {'num': 20,
#   'time_open': Timestamp('2025-07-09 10:00:00'),
#   'time_close': Timestamp('2025-07-09 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6577,
#    'high': 0.6579,
#    'low': 0.6566,
#    'close': 0.6566,
#    'volume': 211.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 11:59:59.999000'): {'num': 21,
#   'time_open': Timestamp('2025-07-09 11:00:00'),
#   'time_close': Timestamp('2025-07-09 11:59:59.999000'),
#   'M6A/USD': {'open': 0.6566,
#    'high': 0.6569,
#    'low': 0.656,
#    'close': 0.656,
#    'volume': 169.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 12:59:59.999000'): {'num': 22,
#   'time_open': Timestamp('2025-07-09 12:00:00'),
#   'time_close': Timestamp('2025-07-09 12:59:59.999000'),
#   'M6A/USD': {'open': 0.656,
#    'high': 0.6579,
#    'low': 0.6558,
#    'close': 0.6576,
#    'volume': 315.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 13:59:59.999000'): {'num': 23,
#   'time_open': Timestamp('2025-07-09 13:00:00'),
#   'time_close': Timestamp('2025-07-09 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6576,
#    'high': 0.6587,
#    'low': 0.6575,
#    'close': 0.6582,
#    'volume': 691.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 14:59:59.999000'): {'num': 24,
#   'time_open': Timestamp('2025-07-09 14:00:00'),
#   'time_close': Timestamp('2025-07-09 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6583,
#    'high': 0.6591,
#    'low': 0.6574,
#    'close': 0.6576,
#    'volume': 701.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 15:59:59.999000'): {'num': 25,
#   'time_open': Timestamp('2025-07-09 15:00:00'),
#   'time_close': Timestamp('2025-07-09 15:59:59.999000'),
#   'M6A/USD': {'open': 0.6575,
#    'high': 0.6576,
#    'low': 0.6571,
#    'close': 0.6574,
#    'volume': 305.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 16:59:59.999000'): {'num': 26,
#   'time_open': Timestamp('2025-07-09 16:00:00'),
#   'time_close': Timestamp('2025-07-09 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6574,
#    'high': 0.6579,
#    'low': 0.6574,
#    'close': 0.6577,
#    'volume': 148.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 17:59:59.999000'): {'num': 27,
#   'time_open': Timestamp('2025-07-09 17:00:00'),
#   'time_close': Timestamp('2025-07-09 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6577,
#    'high': 0.6584,
#    'low': 0.6576,
#    'close': 0.658,
#    'volume': 179.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 18:59:59.999000'): {'num': 28,
#   'time_open': Timestamp('2025-07-09 18:00:00'),
#   'time_close': Timestamp('2025-07-09 18:59:59.999000'),
#   'M6A/USD': {'open': 0.6579,
#    'high': 0.6586,
#    'low': 0.6577,
#    'close': 0.658,
#    'volume': 190.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 19:59:59.999000'): {'num': 29,
#   'time_open': Timestamp('2025-07-09 19:00:00'),
#   'time_close': Timestamp('2025-07-09 19:59:59.999000'),
#   'M6A/USD': {'open': 0.6581,
#    'high': 0.6586,
#    'low': 0.6581,
#    'close': 0.6584,
#    'volume': 167.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 20:59:59.999000'): {'num': 30,
#   'time_open': Timestamp('2025-07-09 20:00:00'),
#   'time_close': Timestamp('2025-07-09 20:59:59.999000'),
#   'M6A/USD': {'open': 0.6584,
#    'high': 0.6584,
#    'low': 0.6576,
#    'close': 0.6578,
#    'volume': 117.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 22:59:59.999000'): {'num': 31,
#   'time_open': Timestamp('2025-07-09 22:00:00'),
#   'time_close': Timestamp('2025-07-09 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6581,
#    'high': 0.6582,
#    'low': 0.658,
#    'close': 0.6581,
#    'volume': 105.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-09 23:59:59.999000'): {'num': 32,
#   'time_open': Timestamp('2025-07-09 23:00:00'),
#   'time_close': Timestamp('2025-07-09 23:59:59.999000'),
#   'M6A/USD': {'open': 0.6581,
#    'high': 0.6581,
#    'low': 0.6579,
#    'close': 0.658,
#    'volume': 93.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 00:59:59.999000'): {'num': 33,
#   'time_open': Timestamp('2025-07-10 00:00:00'),
#   'time_close': Timestamp('2025-07-10 00:59:59.999000'),
#   'M6A/USD': {'open': 0.6578,
#    'high': 0.6593,
#    'low': 0.6576,
#    'close': 0.6587,
#    'volume': 604.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 01:59:59.999000'): {'num': 34,
#   'time_open': Timestamp('2025-07-10 01:00:00'),
#   'time_close': Timestamp('2025-07-10 01:59:59.999000'),
#   'M6A/USD': {'open': 0.6586,
#    'high': 0.6589,
#    'low': 0.6582,
#    'close': 0.6587,
#    'volume': 292.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 02:59:59.999000'): {'num': 35,
#   'time_open': Timestamp('2025-07-10 02:00:00'),
#   'time_close': Timestamp('2025-07-10 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6588,
#    'high': 0.6594,
#    'low': 0.6588,
#    'close': 0.6594,
#    'volume': 229.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 03:59:59.999000'): {'num': 36,
#   'time_open': Timestamp('2025-07-10 03:00:00'),
#   'time_close': Timestamp('2025-07-10 03:59:59.999000'),
#   'M6A/USD': {'open': 0.6594,
#    'high': 0.6595,
#    'low': 0.6588,
#    'close': 0.6588,
#    'volume': 166.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 04:59:59.999000'): {'num': 37,
#   'time_open': Timestamp('2025-07-10 04:00:00'),
#   'time_close': Timestamp('2025-07-10 04:59:59.999000'),
#   'M6A/USD': {'open': 0.6587,
#    'high': 0.6589,
#    'low': 0.6582,
#    'close': 0.6588,
#    'volume': 286.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 05:59:59.999000'): {'num': 38,
#   'time_open': Timestamp('2025-07-10 05:00:00'),
#   'time_close': Timestamp('2025-07-10 05:59:59.999000'),
#   'M6A/USD': {'open': 0.6589,
#    'high': 0.6593,
#    'low': 0.6586,
#    'close': 0.6591,
#    'volume': 352.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 06:59:59.999000'): {'num': 39,
#   'time_open': Timestamp('2025-07-10 06:00:00'),
#   'time_close': Timestamp('2025-07-10 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6592,
#    'high': 0.6601,
#    'low': 0.6591,
#    'close': 0.66,
#    'volume': 428.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 07:59:59.999000'): {'num': 40,
#   'time_open': Timestamp('2025-07-10 07:00:00'),
#   'time_close': Timestamp('2025-07-10 07:59:59.999000'),
#   'M6A/USD': {'open': 0.66,
#    'high': 0.6606,
#    'low': 0.6596,
#    'close': 0.6598,
#    'volume': 669.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 08:59:59.999000'): {'num': 41,
#   'time_open': Timestamp('2025-07-10 08:00:00'),
#   'time_close': Timestamp('2025-07-10 08:59:59.999000'),
#   'M6A/USD': {'open': 0.6598,
#    'high': 0.66,
#    'low': 0.6597,
#    'close': 0.66,
#    'volume': 190.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 09:59:59.999000'): {'num': 42,
#   'time_open': Timestamp('2025-07-10 09:00:00'),
#   'time_close': Timestamp('2025-07-10 09:59:59.999000'),
#   'M6A/USD': {'open': 0.66,
#    'high': 0.6608,
#    'low': 0.66,
#    'close': 0.6603,
#    'volume': 599.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 10:59:59.999000'): {'num': 43,
#   'time_open': Timestamp('2025-07-10 10:00:00'),
#   'time_close': Timestamp('2025-07-10 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6603,
#    'high': 0.661,
#    'low': 0.6601,
#    'close': 0.6608,
#    'volume': 237.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 11:59:59.999000'): {'num': 44,
#   'time_open': Timestamp('2025-07-10 11:00:00'),
#   'time_close': Timestamp('2025-07-10 11:59:59.999000'),
#   'M6A/USD': {'open': 0.6608,
#    'high': 0.6609,
#    'low': 0.6593,
#    'close': 0.6594,
#    'volume': 532.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 12:59:59.999000'): {'num': 45,
#   'time_open': Timestamp('2025-07-10 12:00:00'),
#   'time_close': Timestamp('2025-07-10 12:59:59.999000'),
#   'M6A/USD': {'open': 0.6594,
#    'high': 0.6598,
#    'low': 0.6588,
#    'close': 0.6595,
#    'volume': 370.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 13:59:59.999000'): {'num': 46,
#   'time_open': Timestamp('2025-07-10 13:00:00'),
#   'time_close': Timestamp('2025-07-10 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6595,
#    'high': 0.6599,
#    'low': 0.6585,
#    'close': 0.6588,
#    'volume': 448.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 14:59:59.999000'): {'num': 47,
#   'time_open': Timestamp('2025-07-10 14:00:00'),
#   'time_close': Timestamp('2025-07-10 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6589,
#    'high': 0.6602,
#    'low': 0.6586,
#    'close': 0.6602,
#    'volume': 753.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 15:59:59.999000'): {'num': 48,
#   'time_open': Timestamp('2025-07-10 15:00:00'),
#   'time_close': Timestamp('2025-07-10 15:59:59.999000'),
#   'M6A/USD': {'open': 0.6602,
#    'high': 0.6615,
#    'low': 0.6601,
#    'close': 0.6614,
#    'volume': 565.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 16:59:59.999000'): {'num': 49,
#   'time_open': Timestamp('2025-07-10 16:00:00'),
#   'time_close': Timestamp('2025-07-10 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6613,
#    'high': 0.6619,
#    'low': 0.6613,
#    'close': 0.6617,
#    'volume': 275.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 17:59:59.999000'): {'num': 50,
#   'time_open': Timestamp('2025-07-10 17:00:00'),
#   'time_close': Timestamp('2025-07-10 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6617,
#    'high': 0.6621,
#    'low': 0.6616,
#    'close': 0.662,
#    'volume': 123.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 18:59:59.999000'): {'num': 51,
#   'time_open': Timestamp('2025-07-10 18:00:00'),
#   'time_close': Timestamp('2025-07-10 18:59:59.999000'),
#   'M6A/USD': {'open': 0.662,
#    'high': 0.6627,
#    'low': 0.662,
#    'close': 0.6627,
#    'volume': 386.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 19:59:59.999000'): {'num': 52,
#   'time_open': Timestamp('2025-07-10 19:00:00'),
#   'time_close': Timestamp('2025-07-10 19:59:59.999000'),
#   'M6A/USD': {'open': 0.6628,
#    'high': 0.6633,
#    'low': 0.6626,
#    'close': 0.6632,
#    'volume': 348.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 20:59:59.999000'): {'num': 53,
#   'time_open': Timestamp('2025-07-10 20:00:00'),
#   'time_close': Timestamp('2025-07-10 20:59:59.999000'),
#   'M6A/USD': {'open': 0.6632,
#    'high': 0.6635,
#    'low': 0.663,
#    'close': 0.6632,
#    'volume': 279.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 22:59:59.999000'): {'num': 54,
#   'time_open': Timestamp('2025-07-10 22:00:00'),
#   'time_close': Timestamp('2025-07-10 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6627,
#    'high': 0.6638,
#    'low': 0.6625,
#    'close': 0.6637,
#    'volume': 253.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-10 23:59:59.999000'): {'num': 55,
#   'time_open': Timestamp('2025-07-10 23:00:00'),
#   'time_close': Timestamp('2025-07-10 23:59:59.999000'),
#   'M6A/USD': {'open': 0.6636,
#    'high': 0.6638,
#    'low': 0.6635,
#    'close': 0.6637,
#    'volume': 187.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-11 00:59:59.999000'): {'num': 56,
#   'time_open': Timestamp('2025-07-11 00:00:00'),
#   'time_close': Timestamp('2025-07-11 00:59:59.999000'),
#   'M6A/USD': {'open': 0.6637,
#    'high': 0.6637,
#    'low': 0.66,
#    'close': 0.6611,
#    'volume': 1972.0,
#    'indicators': {'kama_58': nan, 'sma_102': nan}}},
#  Timestamp('2025-07-11 01:59:59.999000'): {'num': 57,
#   'time_open': Timestamp('2025-07-11 01:00:00'),
#   'time_close': Timestamp('2025-07-11 01:59:59.999000'),
#   'M6A/USD': {'open': 0.661,
#    'high': 0.6637,
#    'low': 0.6604,
#    'close': 0.6628,
#    'volume': 1406.0,
#    'indicators': {'kama_58': 0.6588258620689655, 'sma_102': nan}}},
#  Timestamp('2025-07-11 02:59:59.999000'): {'num': 58,
#   'time_open': Timestamp('2025-07-11 02:00:00'),
#   'time_close': Timestamp('2025-07-11 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6628,
#    'high': 0.6631,
#    'low': 0.6621,
#    'close': 0.6621,
#    'volume': 398.0,
#    'indicators': {'kama_58': 0.6589025230364141, 'sma_102': nan}}},
#  Timestamp('2025-07-11 03:59:59.999000'): {'num': 59,
#   'time_open': Timestamp('2025-07-11 03:00:00'),
#   'time_close': Timestamp('2025-07-11 03:59:59.999000'),
#   'M6A/USD': {'open': 0.662,
#    'high': 0.6631,
#    'low': 0.662,
#    'close': 0.6629,
#    'volume': 323.0,
#    'indicators': {'kama_58': 0.6590392571773445, 'sma_102': nan}}},
#  Timestamp('2025-07-11 04:59:59.999000'): {'num': 60,
#   'time_open': Timestamp('2025-07-11 04:00:00'),
#   'time_close': Timestamp('2025-07-11 04:59:59.999000'),
#   'M6A/USD': {'open': 0.6629,
#    'high': 0.6629,
#    'low': 0.6616,
#    'close': 0.6619,
#    'volume': 224.0,
#    'indicators': {'kama_58': 0.659104945491509, 'sma_102': nan}}},
#  Timestamp('2025-07-11 05:59:59.999000'): {'num': 61,
#   'time_open': Timestamp('2025-07-11 05:00:00'),
#   'time_close': Timestamp('2025-07-11 05:59:59.999000'),
#   'M6A/USD': {'open': 0.6621,
#    'high': 0.6628,
#    'low': 0.6621,
#    'close': 0.6623,
#    'volume': 263.0,
#    'indicators': {'kama_58': 0.659181204981314, 'sma_102': nan}}},
#  Timestamp('2025-07-11 06:59:59.999000'): {'num': 62,
#   'time_open': Timestamp('2025-07-11 06:00:00'),
#   'time_close': Timestamp('2025-07-11 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6623,
#    'high': 0.6632,
#    'low': 0.6619,
#    'close': 0.6627,
#    'volume': 380.0,
#    'indicators': {'kama_58': 0.6592651915024018, 'sma_102': nan}}},
#  Timestamp('2025-07-11 07:59:59.999000'): {'num': 63,
#   'time_open': Timestamp('2025-07-11 07:00:00'),
#   'time_close': Timestamp('2025-07-11 07:59:59.999000'),
#   'M6A/USD': {'open': 0.6628,
#    'high': 0.6635,
#    'low': 0.6624,
#    'close': 0.6629,
#    'volume': 286.0,
#    'indicators': {'kama_58': 0.6593598944477623, 'sma_102': nan}}},
#  Timestamp('2025-07-11 08:59:59.999000'): {'num': 64,
#   'time_open': Timestamp('2025-07-11 08:00:00'),
#   'time_close': Timestamp('2025-07-11 08:59:59.999000'),
#   'M6A/USD': {'open': 0.6628,
#    'high': 0.6628,
#    'low': 0.6615,
#    'close': 0.6615,
#    'volume': 476.0,
#    'indicators': {'kama_58': 0.6594018372860101, 'sma_102': nan}}},
#  Timestamp('2025-07-11 09:59:59.999000'): {'num': 65,
#   'time_open': Timestamp('2025-07-11 09:00:00'),
#   'time_close': Timestamp('2025-07-11 09:59:59.999000'),
#   'M6A/USD': {'open': 0.6616,
#    'high': 0.6623,
#    'low': 0.6615,
#    'close': 0.6619,
#    'volume': 206.0,
#    'indicators': {'kama_58': 0.6594487554691391, 'sma_102': nan}}},
#  Timestamp('2025-07-11 10:59:59.999000'): {'num': 66,
#   'time_open': Timestamp('2025-07-11 10:00:00'),
#   'time_close': Timestamp('2025-07-11 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6621,
#    'high': 0.6632,
#    'low': 0.662,
#    'close': 0.6629,
#    'volume': 260.0,
#    'indicators': {'kama_58': 0.6595299241839384, 'sma_102': nan}}},
#  Timestamp('2025-07-11 11:59:59.999000'): {'num': 67,
#   'time_open': Timestamp('2025-07-11 11:00:00'),
#   'time_close': Timestamp('2025-07-11 11:59:59.999000'),
#   'M6A/USD': {'open': 0.6631,
#    'high': 0.6634,
#    'low': 0.6623,
#    'close': 0.6623,
#    'volume': 310.0,
#    'indicators': {'kama_58': 0.6595966910912875, 'sma_102': nan}}},
#  Timestamp('2025-07-11 12:59:59.999000'): {'num': 68,
#   'time_open': Timestamp('2025-07-11 12:00:00'),
#   'time_close': Timestamp('2025-07-11 12:59:59.999000'),
#   'M6A/USD': {'open': 0.6623,
#    'high': 0.663,
#    'low': 0.6614,
#    'close': 0.6623,
#    'volume': 704.0,
#    'indicators': {'kama_58': 0.6596595050395088, 'sma_102': nan}}},
#  Timestamp('2025-07-11 13:59:59.999000'): {'num': 69,
#   'time_open': Timestamp('2025-07-11 13:00:00'),
#   'time_close': Timestamp('2025-07-11 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6622,
#    'high': 0.6633,
#    'low': 0.6618,
#    'close': 0.6618,
#    'volume': 704.0,
#    'indicators': {'kama_58': 0.6596990055913795, 'sma_102': nan}}},
#  Timestamp('2025-07-11 14:59:59.999000'): {'num': 70,
#   'time_open': Timestamp('2025-07-11 14:00:00'),
#   'time_close': Timestamp('2025-07-11 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6618,
#    'high': 0.6626,
#    'low': 0.6615,
#    'close': 0.6617,
#    'volume': 590.0,
#    'indicators': {'kama_58': 0.6597482599514735, 'sma_102': nan}}},
#  Timestamp('2025-07-11 15:59:59.999000'): {'num': 71,
#   'time_open': Timestamp('2025-07-11 15:00:00'),
#   'time_close': Timestamp('2025-07-11 15:59:59.999000'),
#   'M6A/USD': {'open': 0.6617,
#    'high': 0.6624,
#    'low': 0.6616,
#    'close': 0.662,
#    'volume': 275.0,
#    'indicators': {'kama_58': 0.6598036864007979, 'sma_102': nan}}},
#  Timestamp('2025-07-11 16:59:59.999000'): {'num': 72,
#   'time_open': Timestamp('2025-07-11 16:00:00'),
#   'time_close': Timestamp('2025-07-11 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6621,
#    'high': 0.6624,
#    'low': 0.6613,
#    'close': 0.6623,
#    'volume': 214.0,
#    'indicators': {'kama_58': 0.6598529271795714, 'sma_102': nan}}},
#  Timestamp('2025-07-11 17:59:59.999000'): {'num': 73,
#   'time_open': Timestamp('2025-07-11 17:00:00'),
#   'time_close': Timestamp('2025-07-11 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6622,
#    'high': 0.6625,
#    'low': 0.6621,
#    'close': 0.6624,
#    'volume': 99.0,
#    'indicators': {'kama_58': 0.6599072083533957, 'sma_102': nan}}},
#  Timestamp('2025-07-11 18:59:59.999000'): {'num': 74,
#   'time_open': Timestamp('2025-07-11 18:00:00'),
#   'time_close': Timestamp('2025-07-11 18:59:59.999000'),
#   'M6A/USD': {'open': 0.6624,
#    'high': 0.6628,
#    'low': 0.6623,
#    'close': 0.6624,
#    'volume': 150.0,
#    'indicators': {'kama_58': 0.6599505283268076, 'sma_102': nan}}},
#  Timestamp('2025-07-11 19:59:59.999000'): {'num': 75,
#   'time_open': Timestamp('2025-07-11 19:00:00'),
#   'time_close': Timestamp('2025-07-11 19:59:59.999000'),
#   'M6A/USD': {'open': 0.6623,
#    'high': 0.6624,
#    'low': 0.6619,
#    'close': 0.662,
#    'volume': 239.0,
#    'indicators': {'kama_58': 0.6600024674592705, 'sma_102': nan}}},
#  Timestamp('2025-07-11 20:59:59.999000'): {'num': 76,
#   'time_open': Timestamp('2025-07-11 20:00:00'),
#   'time_close': Timestamp('2025-07-11 20:59:59.999000'),
#   'M6A/USD': {'open': 0.6619,
#    'high': 0.6622,
#    'low': 0.6615,
#    'close': 0.6619,
#    'volume': 449.0,
#    'indicators': {'kama_58': 0.6600454685435557, 'sma_102': nan}}},
#  Timestamp('2025-07-13 22:59:59.999000'): {'num': 77,
#   'time_open': Timestamp('2025-07-13 22:00:00'),
#   'time_close': Timestamp('2025-07-13 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6612,
#    'high': 0.6617,
#    'low': 0.6601,
#    'close': 0.6612,
#    'volume': 393.0,
#    'indicators': {'kama_58': 0.6600651554618914, 'sma_102': nan}}},
#  Timestamp('2025-07-13 23:59:59.999000'): {'num': 78,
#   'time_open': Timestamp('2025-07-13 23:00:00'),
#   'time_close': Timestamp('2025-07-13 23:59:59.999000'),
#   'M6A/USD': {'open': 0.661,
#    'high': 0.662,
#    'low': 0.661,
#    'close': 0.6619,
#    'volume': 220.0,
#    'indicators': {'kama_58': 0.6601156131432308, 'sma_102': nan}}},
#  Timestamp('2025-07-14 00:59:59.999000'): {'num': 79,
#   'time_open': Timestamp('2025-07-14 00:00:00'),
#   'time_close': Timestamp('2025-07-14 00:59:59.999000'),
#   'M6A/USD': {'open': 0.6618,
#    'high': 0.6631,
#    'low': 0.6618,
#    'close': 0.6623,
#    'volume': 417.0,
#    'indicators': {'kama_58': 0.6601909533946725, 'sma_102': nan}}},
#  Timestamp('2025-07-14 01:59:59.999000'): {'num': 80,
#   'time_open': Timestamp('2025-07-14 01:00:00'),
#   'time_close': Timestamp('2025-07-14 01:59:59.999000'),
#   'M6A/USD': {'open': 0.6625,
#    'high': 0.6626,
#    'low': 0.6603,
#    'close': 0.6609,
#    'volume': 645.0,
#    'indicators': {'kama_58': 0.6602026449396775, 'sma_102': nan}}},
#  Timestamp('2025-07-14 02:59:59.999000'): {'num': 81,
#   'time_open': Timestamp('2025-07-14 02:00:00'),
#   'time_close': Timestamp('2025-07-14 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6608,
#    'high': 0.6611,
#    'low': 0.6601,
#    'close': 0.6606,
#    'volume': 319.0,
#    'indicators': {'kama_58': 0.660207579371847, 'sma_102': nan}}},
#  Timestamp('2025-07-14 03:59:59.999000'): {'num': 82,
#   'time_open': Timestamp('2025-07-14 03:00:00'),
#   'time_close': Timestamp('2025-07-14 03:59:59.999000'),
#   'M6A/USD': {'open': 0.6605,
#    'high': 0.6614,
#    'low': 0.6605,
#    'close': 0.6612,
#    'volume': 248.0,
#    'indicators': {'kama_58': 0.6602256387456844, 'sma_102': nan}}},
#  Timestamp('2025-07-14 04:59:59.999000'): {'num': 83,
#   'time_open': Timestamp('2025-07-14 04:00:00'),
#   'time_close': Timestamp('2025-07-14 04:59:59.999000'),
#   'M6A/USD': {'open': 0.6611,
#    'high': 0.6611,
#    'low': 0.6604,
#    'close': 0.6605,
#    'volume': 133.0,
#    'indicators': {'kama_58': 0.6602298678120837, 'sma_102': nan}}},
#  Timestamp('2025-07-14 05:59:59.999000'): {'num': 84,
#   'time_open': Timestamp('2025-07-14 05:00:00'),
#   'time_close': Timestamp('2025-07-14 05:59:59.999000'),
#   'M6A/USD': {'open': 0.6604,
#    'high': 0.6612,
#    'low': 0.6601,
#    'close': 0.6605,
#    'volume': 153.0,
#    'indicators': {'kama_58': 0.6602336869793366, 'sma_102': nan}}},
#  Timestamp('2025-07-14 06:59:59.999000'): {'num': 85,
#   'time_open': Timestamp('2025-07-14 06:00:00'),
#   'time_close': Timestamp('2025-07-14 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6603,
#    'high': 0.6607,
#    'low': 0.66,
#    'close': 0.6603,
#    'volume': 286.0,
#    'indicators': {'kama_58': 0.660234479714854, 'sma_102': nan}}},
#  Timestamp('2025-07-14 07:59:59.999000'): {'num': 86,
#   'time_open': Timestamp('2025-07-14 07:00:00'),
#   'time_close': Timestamp('2025-07-14 07:59:59.999000'),
#   'M6A/USD': {'open': 0.6603,
#    'high': 0.6618,
#    'low': 0.6598,
#    'close': 0.6616,
#    'volume': 389.0,
#    'indicators': {'kama_58': 0.6602582139261052, 'sma_102': nan}}},
#  Timestamp('2025-07-14 08:59:59.999000'): {'num': 87,
#   'time_open': Timestamp('2025-07-14 08:00:00'),
#   'time_close': Timestamp('2025-07-14 08:59:59.999000'),
#   'M6A/USD': {'open': 0.6615,
#    'high': 0.6618,
#    'low': 0.6609,
#    'close': 0.6609,
#    'volume': 194.0,
#    'indicators': {'kama_58': 0.6602660979382411, 'sma_102': nan}}},
#  Timestamp('2025-07-14 09:59:59.999000'): {'num': 88,
#   'time_open': Timestamp('2025-07-14 09:00:00'),
#   'time_close': Timestamp('2025-07-14 09:59:59.999000'),
#   'M6A/USD': {'open': 0.6609,
#    'high': 0.6612,
#    'low': 0.6606,
#    'close': 0.6612,
#    'volume': 141.0,
#    'indicators': {'kama_58': 0.6602814222468937, 'sma_102': nan}}},
#  Timestamp('2025-07-14 10:59:59.999000'): {'num': 89,
#   'time_open': Timestamp('2025-07-14 10:00:00'),
#   'time_close': Timestamp('2025-07-14 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6612,
#    'high': 0.6617,
#    'low': 0.6609,
#    'close': 0.6609,
#    'volume': 196.0,
#    'indicators': {'kama_58': 0.6602898721697666, 'sma_102': nan}}},
#  Timestamp('2025-07-14 11:59:59.999000'): {'num': 90,
#   'time_open': Timestamp('2025-07-14 11:00:00'),
#   'time_close': Timestamp('2025-07-14 11:59:59.999000'),
#   'M6A/USD': {'open': 0.6612,
#    'high': 0.6614,
#    'low': 0.6609,
#    'close': 0.661,
#    'volume': 200.0,
#    'indicators': {'kama_58': 0.6603002034555697, 'sma_102': nan}}},
#  Timestamp('2025-07-14 12:59:59.999000'): {'num': 91,
#   'time_open': Timestamp('2025-07-14 12:00:00'),
#   'time_close': Timestamp('2025-07-14 12:59:59.999000'),
#   'M6A/USD': {'open': 0.6609,
#    'high': 0.6613,
#    'low': 0.6598,
#    'close': 0.66,
#    'volume': 358.0,
#    'indicators': {'kama_58': 0.6602978467560501, 'sma_102': nan}}},
#  Timestamp('2025-07-14 13:59:59.999000'): {'num': 92,
#   'time_open': Timestamp('2025-07-14 13:00:00'),
#   'time_close': Timestamp('2025-07-14 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6601,
#    'high': 0.6607,
#    'low': 0.6596,
#    'close': 0.6605,
#    'volume': 394.0,
#    'indicators': {'kama_58': 0.6602997629882085, 'sma_102': nan}}},
#  Timestamp('2025-07-14 14:59:59.999000'): {'num': 93,
#   'time_open': Timestamp('2025-07-14 14:00:00'),
#   'time_close': Timestamp('2025-07-14 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6605,
#    'high': 0.6605,
#    'low': 0.6597,
#    'close': 0.6598,
#    'volume': 427.0,
#    'indicators': {'kama_58': 0.6602971855189557, 'sma_102': nan}}},
#  Timestamp('2025-07-14 15:59:59.999000'): {'num': 94,
#   'time_open': Timestamp('2025-07-14 15:00:00'),
#   'time_close': Timestamp('2025-07-14 15:59:59.999000'),
#   'M6A/USD': {'open': 0.6599,
#    'high': 0.661,
#    'low': 0.6592,
#    'close': 0.6592,
#    'volume': 580.0,
#    'indicators': {'kama_58': 0.6602915269127633, 'sma_102': nan}}},
#  Timestamp('2025-07-14 16:59:59.999000'): {'num': 95,
#   'time_open': Timestamp('2025-07-14 16:00:00'),
#   'time_close': Timestamp('2025-07-14 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6591,
#    'high': 0.6594,
#    'low': 0.6588,
#    'close': 0.6591,
#    'volume': 673.0,
#    'indicators': {'kama_58': 0.6602856928194739, 'sma_102': nan}}},
#  Timestamp('2025-07-14 17:59:59.999000'): {'num': 96,
#   'time_open': Timestamp('2025-07-14 17:00:00'),
#   'time_close': Timestamp('2025-07-14 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6592,
#    'high': 0.6594,
#    'low': 0.6588,
#    'close': 0.6588,
#    'volume': 75.0,
#    'indicators': {'kama_58': 0.6602784183967015, 'sma_102': nan}}},
#  Timestamp('2025-07-14 18:59:59.999000'): {'num': 97,
#   'time_open': Timestamp('2025-07-14 18:00:00'),
#   'time_close': Timestamp('2025-07-14 18:59:59.999000'),
#   'M6A/USD': {'open': 0.659,
#    'high': 0.6593,
#    'low': 0.659,
#    'close': 0.6592,
#    'volume': 88.0,
#    'indicators': {'kama_58': 0.6602716379997915, 'sma_102': nan}}},
#  Timestamp('2025-07-14 19:59:59.999000'): {'num': 98,
#   'time_open': Timestamp('2025-07-14 19:00:00'),
#   'time_close': Timestamp('2025-07-14 19:59:59.999000'),
#   'M6A/USD': {'open': 0.6591,
#    'high': 0.6593,
#    'low': 0.6588,
#    'close': 0.6591,
#    'volume': 122.0,
#    'indicators': {'kama_58': 0.6602646034774847, 'sma_102': nan}}},
#  Timestamp('2025-07-14 20:59:59.999000'): {'num': 99,
#   'time_open': Timestamp('2025-07-14 20:00:00'),
#   'time_close': Timestamp('2025-07-14 20:59:59.999000'),
#   'M6A/USD': {'open': 0.6592,
#    'high': 0.6592,
#    'low': 0.6585,
#    'close': 0.6588,
#    'volume': 215.0,
#    'indicators': {'kama_58': 0.6602535989934292, 'sma_102': nan}}},
#  Timestamp('2025-07-14 22:59:59.999000'): {'num': 100,
#   'time_open': Timestamp('2025-07-14 22:00:00'),
#   'time_close': Timestamp('2025-07-14 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6588,
#    'high': 0.659,
#    'low': 0.6587,
#    'close': 0.6588,
#    'volume': 170.0,
#    'indicators': {'kama_58': 0.6602411670749224, 'sma_102': nan}}},
#  Timestamp('2025-07-14 23:59:59.999000'): {'num': 101,
#   'time_open': Timestamp('2025-07-14 23:00:00'),
#   'time_close': Timestamp('2025-07-14 23:59:59.999000'),
#   'M6A/USD': {'open': 0.6588,
#    'high': 0.6588,
#    'low': 0.6582,
#    'close': 0.6586,
#    'volume': 291.0,
#    'indicators': {'kama_58': 0.6602227568387649,
#     'sma_102': 0.6598137254901961}}},
#  Timestamp('2025-07-15 00:59:59.999000'): {'num': 102,
#   'time_open': Timestamp('2025-07-15 00:00:00'),
#   'time_close': Timestamp('2025-07-15 00:59:59.999000'),
#   'M6A/USD': {'open': 0.6586,
#    'high': 0.6596,
#    'low': 0.6586,
#    'close': 0.6592,
#    'volume': 260.0,
#    'indicators': {'kama_58': 0.6602179751572921,
#     'sma_102': 0.6598352941176471}}},
#  Timestamp('2025-07-15 01:59:59.999000'): {'num': 103,
#   'time_open': Timestamp('2025-07-15 01:00:00'),
#   'time_close': Timestamp('2025-07-15 01:59:59.999000'),
#   'M6A/USD': {'open': 0.6591,
#    'high': 0.6598,
#    'low': 0.6582,
#    'close': 0.6594,
#    'volume': 768.0,
#    'indicators': {'kama_58': 0.6602143643984684,
#     'sma_102': 0.6598686274509804}}},
#  Timestamp('2025-07-15 02:59:59.999000'): {'num': 104,
#   'time_open': Timestamp('2025-07-15 02:00:00'),
#   'time_close': Timestamp('2025-07-15 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6594,
#    'high': 0.6595,
#    'low': 0.6587,
#    'close': 0.6587,
#    'volume': 155.0,
#    'indicators': {'kama_58': 0.6602076795932327,
#     'sma_102': 0.659886274509804}}},
#  Timestamp('2025-07-15 03:59:59.999000'): {'num': 105,
#   'time_open': Timestamp('2025-07-15 03:00:00'),
#   'time_close': Timestamp('2025-07-15 03:59:59.999000'),
#   'M6A/USD': {'open': 0.6587,
#    'high': 0.6591,
#    'low': 0.6585,
#    'close': 0.659,
#    'volume': 106.0,
#    'indicators': {'kama_58': 0.6601982330018993,
#     'sma_102': 0.6599049019607843}}},
#  Timestamp('2025-07-15 04:59:59.999000'): {'num': 106,
#   'time_open': Timestamp('2025-07-15 04:00:00'),
#   'time_close': Timestamp('2025-07-15 04:59:59.999000'),
#   'M6A/USD': {'open': 0.659,
#    'high': 0.6591,
#    'low': 0.6585,
#    'close': 0.6585,
#    'volume': 55.0,
#    'indicators': {'kama_58': 0.6601722427180146,
#     'sma_102': 0.6599147058823529}}},
#  Timestamp('2025-07-15 05:59:59.999000'): {'num': 107,
#   'time_open': Timestamp('2025-07-15 05:00:00'),
#   'time_close': Timestamp('2025-07-15 05:59:59.999000'),
#   'M6A/USD': {'open': 0.6586,
#    'high': 0.66,
#    'low': 0.6586,
#    'close': 0.6597,
#    'volume': 342.0,
#    'indicators': {'kama_58': 0.6601671220358929,
#     'sma_102': 0.6599382352941177}}},
#  Timestamp('2025-07-15 06:59:59.999000'): {'num': 108,
#   'time_open': Timestamp('2025-07-15 06:00:00'),
#   'time_close': Timestamp('2025-07-15 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6597,
#    'high': 0.6599,
#    'low': 0.6593,
#    'close': 0.6595,
#    'volume': 269.0,
#    'indicators': {'kama_58': 0.6601584218964859,
#     'sma_102': 0.6599627450980392}}},
#  Timestamp('2025-07-15 07:59:59.999000'): {'num': 109,
#   'time_open': Timestamp('2025-07-15 07:00:00'),
#   'time_close': Timestamp('2025-07-15 07:59:59.999000'),
#   'M6A/USD': {'open': 0.6594,
#    'high': 0.661,
#    'low': 0.6591,
#    'close': 0.661,
#    'volume': 663.0,
#    'indicators': {'kama_58': 0.6601664108469758,
#     'sma_102': 0.6599960784313726}}},
#  Timestamp('2025-07-15 08:59:59.999000'): {'num': 110,
#   'time_open': Timestamp('2025-07-15 08:00:00'),
#   'time_close': Timestamp('2025-07-15 08:59:59.999000'),
#   'M6A/USD': {'open': 0.6609,
#    'high': 0.6614,
#    'low': 0.6604,
#    'close': 0.6609,
#    'volume': 395.0,
#    'indicators': {'kama_58': 0.6601752274021196,
#     'sma_102': 0.660029411764706}}},
#  Timestamp('2025-07-15 09:59:59.999000'): {'num': 111,
#   'time_open': Timestamp('2025-07-15 09:00:00'),
#   'time_close': Timestamp('2025-07-15 09:59:59.999000'),
#   'M6A/USD': {'open': 0.6608,
#    'high': 0.6613,
#    'low': 0.6606,
#    'close': 0.6609,
#    'volume': 151.0,
#    'indicators': {'kama_58': 0.6601839379965302,
#     'sma_102': 0.6600696078431373}}},
#  Timestamp('2025-07-15 10:59:59.999000'): {'num': 112,
#   'time_open': Timestamp('2025-07-15 10:00:00'),
#   'time_close': Timestamp('2025-07-15 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6609,
#    'high': 0.6613,
#    'low': 0.6609,
#    'close': 0.6612,
#    'volume': 103.0,
#    'indicators': {'kama_58': 0.6601971132712555,
#     'sma_102': 0.6601107843137255}}},
#  Timestamp('2025-07-15 11:59:59.999000'): {'num': 113,
#   'time_open': Timestamp('2025-07-15 11:00:00'),
#   'time_close': Timestamp('2025-07-15 11:59:59.999000'),
#   'M6A/USD': {'open': 0.6612,
#    'high': 0.6613,
#    'low': 0.6603,
#    'close': 0.6603,
#    'volume': 228.0,
#    'indicators': {'kama_58': 0.6601988444986139,
#     'sma_102': 0.6601382352941176}}},
#  Timestamp('2025-07-15 12:59:59.999000'): {'num': 114,
#   'time_open': Timestamp('2025-07-15 12:00:00'),
#   'time_close': Timestamp('2025-07-15 12:59:59.999000'),
#   'M6A/USD': {'open': 0.6603,
#    'high': 0.662,
#    'low': 0.6602,
#    'close': 0.6615,
#    'volume': 839.0,
#    'indicators': {'kama_58': 0.660205692152677,
#     'sma_102': 0.6601892156862745}}},
#  Timestamp('2025-07-15 13:59:59.999000'): {'num': 115,
#   'time_open': Timestamp('2025-07-15 13:00:00'),
#   'time_close': Timestamp('2025-07-15 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6614,
#    'high': 0.6615,
#    'low': 0.6585,
#    'close': 0.6585,
#    'volume': 919.0,
#    'indicators': {'kama_58': 0.6601687135571245,
#     'sma_102': 0.6602078431372549}}},
#  Timestamp('2025-07-15 14:59:59.999000'): {'num': 116,
#   'time_open': Timestamp('2025-07-15 14:00:00'),
#   'time_close': Timestamp('2025-07-15 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6585,
#    'high': 0.6585,
#    'low': 0.6559,
#    'close': 0.6563,
#    'volume': 1301.0,
#    'indicators': {'kama_58': 0.6600555964847937,
#     'sma_102': 0.6601911764705883}}},
#  Timestamp('2025-07-15 15:59:59.999000'): {'num': 117,
#   'time_open': Timestamp('2025-07-15 15:00:00'),
#   'time_close': Timestamp('2025-07-15 15:59:59.999000'),
#   'M6A/USD': {'open': 0.6563,
#    'high': 0.6564,
#    'low': 0.6551,
#    'close': 0.6563,
#    'volume': 711.0,
#    'indicators': {'kama_58': 0.6599218546526389,
#     'sma_102': 0.6601764705882354}}},
#  Timestamp('2025-07-15 16:59:59.999000'): {'num': 118,
#   'time_open': Timestamp('2025-07-15 16:00:00'),
#   'time_close': Timestamp('2025-07-15 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6563,
#    'high': 0.6565,
#    'low': 0.655,
#    'close': 0.6553,
#    'volume': 262.0,
#    'indicators': {'kama_58': 0.6597572642043039,
#     'sma_102': 0.660143137254902}}},
#  Timestamp('2025-07-15 17:59:59.999000'): {'num': 119,
#   'time_open': Timestamp('2025-07-15 17:00:00'),
#   'time_close': Timestamp('2025-07-15 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6553,
#    'high': 0.6558,
#    'low': 0.6552,
#    'close': 0.6557,
#    'volume': 233.0,
#    'indicators': {'kama_58': 0.6596127795797131,
#     'sma_102': 0.6601303921568626}}},
#  Timestamp('2025-07-15 18:59:59.999000'): {'num': 120,
#   'time_open': Timestamp('2025-07-15 18:00:00'),
#   'time_close': Timestamp('2025-07-15 18:59:59.999000'),
#   'M6A/USD': {'open': 0.6556,
#    'high': 0.6563,
#    'low': 0.6556,
#    'close': 0.656,
#    'volume': 115.0,
#    'indicators': {'kama_58': 0.6594810002352969,
#     'sma_102': 0.6601166666666667}}},
#  Timestamp('2025-07-15 19:59:59.999000'): {'num': 121,
#   'time_open': Timestamp('2025-07-15 19:00:00'),
#   'time_close': Timestamp('2025-07-15 19:59:59.999000'),
#   'M6A/USD': {'open': 0.656,
#    'high': 0.6561,
#    'low': 0.6557,
#    'close': 0.6558,
#    'volume': 168.0,
#    'indicators': {'kama_58': 0.6593359063295392,
#     'sma_102': 0.6600980392156863}}},
#  Timestamp('2025-07-15 20:59:59.999000'): {'num': 122,
#   'time_open': Timestamp('2025-07-15 20:00:00'),
#   'time_close': Timestamp('2025-07-15 20:59:59.999000'),
#   'M6A/USD': {'open': 0.6557,
#    'high': 0.6558,
#    'low': 0.6555,
#    'close': 0.6558,
#    'volume': 178.0,
#    'indicators': {'kama_58': 0.6592250683520392,
#     'sma_102': 0.6600901960784313}}},
#  Timestamp('2025-07-15 22:59:59.999000'): {'num': 123,
#   'time_open': Timestamp('2025-07-15 22:00:00'),
#   'time_close': Timestamp('2025-07-15 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6557,
#    'high': 0.6559,
#    'low': 0.6555,
#    'close': 0.6555,
#    'volume': 262.0,
#    'indicators': {'kama_58': 0.6590887687626, 'sma_102': 0.660085294117647}}},
#  Timestamp('2025-07-15 23:59:59.999000'): {'num': 124,
#   'time_open': Timestamp('2025-07-15 23:00:00'),
#   'time_close': Timestamp('2025-07-15 23:59:59.999000'),
#   'M6A/USD': {'open': 0.6556,
#    'high': 0.6565,
#    'low': 0.6556,
#    'close': 0.6561,
#    'volume': 424.0,
#    'indicators': {'kama_58': 0.6589680152093859,
#     'sma_102': 0.6600705882352942}}},
#  Timestamp('2025-07-16 00:59:59.999000'): {'num': 125,
#   'time_open': Timestamp('2025-07-16 00:00:00'),
#   'time_close': Timestamp('2025-07-16 00:59:59.999000'),
#   'M6A/USD': {'open': 0.6562,
#    'high': 0.6576,
#    'low': 0.6559,
#    'close': 0.657,
#    'volume': 708.0,
#    'indicators': {'kama_58': 0.6589112447138749,
#     'sma_102': 0.6600588235294118}}},
#  Timestamp('2025-07-16 01:59:59.999000'): {'num': 126,
#   'time_open': Timestamp('2025-07-16 01:00:00'),
#   'time_close': Timestamp('2025-07-16 01:59:59.999000'),
#   'M6A/USD': {'open': 0.657,
#    'high': 0.6575,
#    'low': 0.6569,
#    'close': 0.6572,
#    'volume': 231.0,
#    'indicators': {'kama_58': 0.658864541032766,
#     'sma_102': 0.6600549019607843}}},
#  Timestamp('2025-07-16 02:59:59.999000'): {'num': 127,
#   'time_open': Timestamp('2025-07-16 02:00:00'),
#   'time_close': Timestamp('2025-07-16 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6571,
#    'high': 0.6571,
#    'low': 0.6561,
#    'close': 0.6565,
#    'volume': 452.0,
#    'indicators': {'kama_58': 0.6587974299324109,
#     'sma_102': 0.6600460784313725}}},
#  Timestamp('2025-07-16 03:59:59.999000'): {'num': 128,
#   'time_open': Timestamp('2025-07-16 03:00:00'),
#   'time_close': Timestamp('2025-07-16 03:59:59.999000'),
#   'M6A/USD': {'open': 0.6565,
#    'high': 0.6571,
#    'low': 0.6564,
#    'close': 0.6566,
#    'volume': 232.0,
#    'indicators': {'kama_58': 0.6587379324741776,
#     'sma_102': 0.660035294117647}}},
#  Timestamp('2025-07-16 04:59:59.999000'): {'num': 129,
#   'time_open': Timestamp('2025-07-16 04:00:00'),
#   'time_close': Timestamp('2025-07-16 04:59:59.999000'),
#   'M6A/USD': {'open': 0.6566,
#    'high': 0.657,
#    'low': 0.6564,
#    'close': 0.6569,
#    'volume': 176.0,
#    'indicators': {'kama_58': 0.6586881687438283,
#     'sma_102': 0.6600245098039216}}},
#  Timestamp('2025-07-16 05:59:59.999000'): {'num': 130,
#   'time_open': Timestamp('2025-07-16 05:00:00'),
#   'time_close': Timestamp('2025-07-16 05:59:59.999000'),
#   'M6A/USD': {'open': 0.657,
#    'high': 0.6571,
#    'low': 0.6567,
#    'close': 0.6569,
#    'volume': 148.0,
#    'indicators': {'kama_58': 0.6586355887346741,
#     'sma_102': 0.6600137254901961}}},
#  Timestamp('2025-07-16 06:59:59.999000'): {'num': 131,
#   'time_open': Timestamp('2025-07-16 06:00:00'),
#   'time_close': Timestamp('2025-07-16 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6568,
#    'high': 0.6572,
#    'low': 0.6564,
#    'close': 0.657,
#    'volume': 242.0,
#    'indicators': {'kama_58': 0.6585874952474468,
#     'sma_102': 0.6599999999999999}}},
#  Timestamp('2025-07-16 07:59:59.999000'): {'num': 132,
#   'time_open': Timestamp('2025-07-16 07:00:00'),
#   'time_close': Timestamp('2025-07-16 07:59:59.999000'),
#   'M6A/USD': {'open': 0.657,
#    'high': 0.6572,
#    'low': 0.6564,
#    'close': 0.6568,
#    'volume': 116.0,
#    'indicators': {'kama_58': 0.6585329322292509,
#     'sma_102': 0.6599901960784313}}},
#  Timestamp('2025-07-16 08:59:59.999000'): {'num': 133,
#   'time_open': Timestamp('2025-07-16 08:00:00'),
#   'time_close': Timestamp('2025-07-16 08:59:59.999000'),
#   'M6A/USD': {'open': 0.6571,
#    'high': 0.6571,
#    'low': 0.6562,
#    'close': 0.6564,
#    'volume': 95.0,
#    'indicators': {'kama_58': 0.6584678248001815,
#     'sma_102': 0.6599735294117647}}},
#  Timestamp('2025-07-16 09:59:59.999000'): {'num': 134,
#   'time_open': Timestamp('2025-07-16 09:00:00'),
#   'time_close': Timestamp('2025-07-16 09:59:59.999000'),
#   'M6A/USD': {'open': 0.6564,
#    'high': 0.6565,
#    'low': 0.6559,
#    'close': 0.6565,
#    'volume': 272.0,
#    'indicators': {'kama_58': 0.6584104329509994,
#     'sma_102': 0.6599588235294118}}},
#  Timestamp('2025-07-16 10:59:59.999000'): {'num': 135,
#   'time_open': Timestamp('2025-07-16 10:00:00'),
#   'time_close': Timestamp('2025-07-16 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6565,
#    'high': 0.6567,
#    'low': 0.6562,
#    'close': 0.6565,
#    'volume': 171.0,
#    'indicators': {'kama_58': 0.6583620328413404,
#     'sma_102': 0.6599372549019609}}},
#  Timestamp('2025-07-16 11:59:59.999000'): {'num': 136,
#   'time_open': Timestamp('2025-07-16 11:00:00'),
#   'time_close': Timestamp('2025-07-16 11:59:59.999000'),
#   'M6A/USD': {'open': 0.6565,
#    'high': 0.6568,
#    'low': 0.6561,
#    'close': 0.6562,
#    'volume': 172.0,
#    'indicators': {'kama_58': 0.6582913089941009,
#     'sma_102': 0.6599127450980392}}},
#  Timestamp('2025-07-16 12:59:59.999000'): {'num': 137,
#   'time_open': Timestamp('2025-07-16 12:00:00'),
#   'time_close': Timestamp('2025-07-16 12:59:59.999000'),
#   'M6A/USD': {'open': 0.6563,
#    'high': 0.6571,
#    'low': 0.6558,
#    'close': 0.6561,
#    'volume': 650.0,
#    'indicators': {'kama_58': 0.6582102169294775,
#     'sma_102': 0.6598803921568627}}},
#  Timestamp('2025-07-16 13:59:59.999000'): {'num': 138,
#   'time_open': Timestamp('2025-07-16 13:00:00'),
#   'time_close': Timestamp('2025-07-16 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6562,
#    'high': 0.6564,
#    'low': 0.6539,
#    'close': 0.6543,
#    'volume': 1062.0,
#    'indicators': {'kama_58': 0.6580557115126994,
#     'sma_102': 0.6598362745098039}}},
#  Timestamp('2025-07-16 14:59:59.999000'): {'num': 139,
#   'time_open': Timestamp('2025-07-16 14:00:00'),
#   'time_close': Timestamp('2025-07-16 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6544,
#    'high': 0.6557,
#    'low': 0.6539,
#    'close': 0.6549,
#    'volume': 1200.0,
#    'indicators': {'kama_58': 0.6579542518138757,
#     'sma_102': 0.6597980392156862}}},
#  Timestamp('2025-07-16 15:59:59.999000'): {'num': 140,
#   'time_open': Timestamp('2025-07-16 15:00:00'),
#   'time_close': Timestamp('2025-07-16 15:59:59.999000'),
#   'M6A/USD': {'open': 0.655,
#    'high': 0.6597,
#    'low': 0.655,
#    'close': 0.6563,
#    'volume': 5253.0,
#    'indicators': {'kama_58': 0.6579115715523187,
#     'sma_102': 0.6597705882352941}}},
#  Timestamp('2025-07-16 16:59:59.999000'): {'num': 141,
#   'time_open': Timestamp('2025-07-16 16:00:00'),
#   'time_close': Timestamp('2025-07-16 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6564,
#    'high': 0.6575,
#    'low': 0.6556,
#    'close': 0.6568,
#    'volume': 656.0,
#    'indicators': {'kama_58': 0.6578905363652813,
#     'sma_102': 0.6597392156862745}}},
#  Timestamp('2025-07-16 17:59:59.999000'): {'num': 142,
#   'time_open': Timestamp('2025-07-16 17:00:00'),
#   'time_close': Timestamp('2025-07-16 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6571,
#    'high': 0.658,
#    'low': 0.6567,
#    'close': 0.657,
#    'volume': 321.0,
#    'indicators': {'kama_58': 0.657874744507081,
#     'sma_102': 0.6597117647058823}}},
#  Timestamp('2025-07-16 18:59:59.999000'): {'num': 143,
#   'time_open': Timestamp('2025-07-16 18:00:00'),
#   'time_close': Timestamp('2025-07-16 18:59:59.999000'),
#   'M6A/USD': {'open': 0.657,
#    'high': 0.657,
# ...
#     'sma_102': 0.657371568627451}}},
#  Timestamp('2025-09-04 02:59:59.999000'): {'num': 955,
#   'time_open': Timestamp('2025-09-04 02:00:00'),
#   'time_close': Timestamp('2025-09-04 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6575,
#    'high': 0.6577,
#    'low': 0.6572,
#    'close': 0.6574,
#    'volume': 230.0,
#    'indicators': {'kama_58': 0.6573131049082954,
#     'sma_102': 0.6573774509803921}}},
#  Timestamp('2025-09-04 03:59:59.999000'): {'num': 956,
#   'time_open': Timestamp('2025-09-04 03:00:00'),
#   'time_close': Timestamp('2025-09-04 03:59:59.999000'),
#   'M6A/USD': {'open': 0.6575,
#    'high': 0.6575,
#    'low': 0.6569,
#    'close': 0.657,
#    'volume': 113.0,
#    'indicators': {'kama_58': 0.6573088737873738,
#     'sma_102': 0.6573754901960784}}},
#  Timestamp('2025-09-04 04:59:59.999000'): {'num': 957,
#   'time_open': Timestamp('2025-09-04 04:00:00'),
#   'time_close': Timestamp('2025-09-04 04:59:59.999000'),
#   'M6A/USD': {'open': 0.6571,
#    'high': 0.6573,
#    'low': 0.6566,
#    'close': 0.6566,
#    'volume': 116.0,
#    'indicators': {'kama_58': 0.6572992944718374,
#     'sma_102': 0.6573686274509805}}},
#  Timestamp('2025-09-04 05:59:59.999000'): {'num': 958,
#   'time_open': Timestamp('2025-09-04 05:00:00'),
#   'time_close': Timestamp('2025-09-04 05:59:59.999000'),
#   'M6A/USD': {'open': 0.6566,
#    'high': 0.6566,
#    'low': 0.6561,
#    'close': 0.6562,
#    'volume': 317.0,
#    'indicators': {'kama_58': 0.6572824705287367,
#     'sma_102': 0.6573588235294118}}},
#  Timestamp('2025-09-04 06:59:59.999000'): {'num': 959,
#   'time_open': Timestamp('2025-09-04 06:00:00'),
#   'time_close': Timestamp('2025-09-04 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6563,
#    'high': 0.6566,
#    'low': 0.656,
#    'close': 0.6562,
#    'volume': 98.0,
#    'indicators': {'kama_58': 0.6572659040644723,
#     'sma_102': 0.6573509803921568}}},
#  Timestamp('2025-09-04 07:59:59.999000'): {'num': 960,
#   'time_open': Timestamp('2025-09-04 07:00:00'),
#   'time_close': Timestamp('2025-09-04 07:59:59.999000'),
#   'M6A/USD': {'open': 0.6561,
#    'high': 0.6563,
#    'low': 0.6558,
#    'close': 0.6561,
#    'volume': 140.0,
#    'indicators': {'kama_58': 0.6572475276420847,
#     'sma_102': 0.6573421568627451}}},
#  Timestamp('2025-09-04 08:59:59.999000'): {'num': 961,
#   'time_open': Timestamp('2025-09-04 08:00:00'),
#   'time_close': Timestamp('2025-09-04 08:59:59.999000'),
#   'M6A/USD': {'open': 0.6563,
#    'high': 0.6565,
#    'low': 0.6561,
#    'close': 0.6565,
#    'volume': 59.0,
#    'indicators': {'kama_58': 0.6572365660727383,
#     'sma_102': 0.6573401960784314}}},
#  Timestamp('2025-09-04 09:59:59.999000'): {'num': 962,
#   'time_open': Timestamp('2025-09-04 09:00:00'),
#   'time_close': Timestamp('2025-09-04 09:59:59.999000'),
#   'M6A/USD': {'open': 0.6565,
#    'high': 0.6565,
#    'low': 0.6555,
#    'close': 0.6556,
#    'volume': 233.0,
#    'indicators': {'kama_58': 0.6572065815355067,
#     'sma_102': 0.6573274509803921}}},
#  Timestamp('2025-09-04 10:59:59.999000'): {'num': 963,
#   'time_open': Timestamp('2025-09-04 10:00:00'),
#   'time_close': Timestamp('2025-09-04 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6555,
#    'high': 0.656,
#    'low': 0.6555,
#    'close': 0.6557,
#    'volume': 144.0,
#    'indicators': {'kama_58': 0.6571798653643278,
#     'sma_102': 0.6573107843137255}}},
#  Timestamp('2025-09-04 11:59:59.999000'): {'num': 964,
#   'time_open': Timestamp('2025-09-04 11:00:00'),
#   'time_close': Timestamp('2025-09-04 11:59:59.999000'),
#   'M6A/USD': {'open': 0.6555,
#    'high': 0.6556,
#    'low': 0.6552,
#    'close': 0.6553,
#    'volume': 57.0,
#    'indicators': {'kama_58': 0.6571406604884035,
#     'sma_102': 0.6572862745098038}}},
#  Timestamp('2025-09-04 12:59:59.999000'): {'num': 965,
#   'time_open': Timestamp('2025-09-04 12:00:00'),
#   'time_close': Timestamp('2025-09-04 12:59:59.999000'),
#   'M6A/USD': {'open': 0.6555,
#    'high': 0.6561,
#    'low': 0.6547,
#    'close': 0.6558,
#    'volume': 525.0,
#    'indicators': {'kama_58': 0.6571179562103802,
#     'sma_102': 0.6572696078431373}}},
#  Timestamp('2025-09-04 13:59:59.999000'): {'num': 966,
#   'time_open': Timestamp('2025-09-04 13:00:00'),
#   'time_close': Timestamp('2025-09-04 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6558,
#    'high': 0.6564,
#    'low': 0.6551,
#    'close': 0.6561,
#    'volume': 493.0,
#    'indicators': {'kama_58': 0.6571057220231299,
#     'sma_102': 0.6572558823529412}}},
#  Timestamp('2025-09-04 14:59:59.999000'): {'num': 967,
#   'time_open': Timestamp('2025-09-04 14:00:00'),
#   'time_close': Timestamp('2025-09-04 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6557,
#    'high': 0.6562,
#    'low': 0.6539,
#    'close': 0.6545,
#    'volume': 645.0,
#    'indicators': {'kama_58': 0.6570578256630394,
#     'sma_102': 0.6572245098039216}}},
#  Timestamp('2025-09-04 15:59:59.999000'): {'num': 968,
#   'time_open': Timestamp('2025-09-04 15:00:00'),
#   'time_close': Timestamp('2025-09-04 15:59:59.999000'),
#   'M6A/USD': {'open': 0.6546,
#    'high': 0.655,
#    'low': 0.6541,
#    'close': 0.6549,
#    'volume': 192.0,
#    'indicators': {'kama_58': 0.6570264325635313,
#     'sma_102': 0.6571980392156862}}},
#  Timestamp('2025-09-04 16:59:59.999000'): {'num': 969,
#   'time_open': Timestamp('2025-09-04 16:00:00'),
#   'time_close': Timestamp('2025-09-04 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6549,
#    'high': 0.655,
#    'low': 0.6544,
#    'close': 0.6548,
#    'volume': 163.0,
#    'indicators': {'kama_58': 0.6569949485355645,
#     'sma_102': 0.657177450980392}}},
#  Timestamp('2025-09-04 17:59:59.999000'): {'num': 970,
#   'time_open': Timestamp('2025-09-04 17:00:00'),
#   'time_close': Timestamp('2025-09-04 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6548,
#    'high': 0.6551,
#    'low': 0.6547,
#    'close': 0.6548,
#    'volume': 94.0,
#    'indicators': {'kama_58': 0.6569656765760419,
#     'sma_102': 0.6571490196078431}}},
#  Timestamp('2025-09-04 18:59:59.999000'): {'num': 971,
#   'time_open': Timestamp('2025-09-04 18:00:00'),
#   'time_close': Timestamp('2025-09-04 18:59:59.999000'),
#   'M6A/USD': {'open': 0.6549,
#    'high': 0.6553,
#    'low': 0.6549,
#    'close': 0.6551,
#    'volume': 52.0,
#    'indicators': {'kama_58': 0.6569389885438207,
#     'sma_102': 0.6571264705882354}}},
#  Timestamp('2025-09-04 19:59:59.999000'): {'num': 972,
#   'time_open': Timestamp('2025-09-04 19:00:00'),
#   'time_close': Timestamp('2025-09-04 19:59:59.999000'),
#   'M6A/USD': {'open': 0.6553,
#    'high': 0.6555,
#    'low': 0.6552,
#    'close': 0.6555,
#    'volume': 38.0,
#    'indicators': {'kama_58': 0.6569267620998688,
#     'sma_102': 0.657114705882353}}},
#  Timestamp('2025-09-04 20:59:59.999000'): {'num': 973,
#   'time_open': Timestamp('2025-09-04 20:00:00'),
#   'time_close': Timestamp('2025-09-04 20:59:59.999000'),
#   'M6A/USD': {'open': 0.6555,
#    'high': 0.6556,
#    'low': 0.6554,
#    'close': 0.6554,
#    'volume': 297.0,
#    'indicators': {'kama_58': 0.6569190472435259,
#     'sma_102': 0.6571029411764706}}},
#  Timestamp('2025-09-04 22:59:59.999000'): {'num': 974,
#   'time_open': Timestamp('2025-09-04 22:00:00'),
#   'time_close': Timestamp('2025-09-04 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6554,
#    'high': 0.6558,
#    'low': 0.6553,
#    'close': 0.6555,
#    'volume': 193.0,
#    'indicators': {'kama_58': 0.6569109659629079,
#     'sma_102': 0.6570931372549019}}},
#  Timestamp('2025-09-04 23:59:59.999000'): {'num': 975,
#   'time_open': Timestamp('2025-09-04 23:00:00'),
#   'time_close': Timestamp('2025-09-04 23:59:59.999000'),
#   'M6A/USD': {'open': 0.6556,
#    'high': 0.656,
#    'low': 0.6555,
#    'close': 0.6559,
#    'volume': 90.0,
#    'indicators': {'kama_58': 0.6569034581849809,
#     'sma_102': 0.657085294117647}}},
#  Timestamp('2025-09-05 00:59:59.999000'): {'num': 976,
#   'time_open': Timestamp('2025-09-05 00:00:00'),
#   'time_close': Timestamp('2025-09-05 00:59:59.999000'),
#   'M6A/USD': {'open': 0.656,
#    'high': 0.6564,
#    'low': 0.6558,
#    'close': 0.6563,
#    'volume': 223.0,
#    'indicators': {'kama_58': 0.6568975526813646,
#     'sma_102': 0.6570735294117647}}},
#  Timestamp('2025-09-05 01:59:59.999000'): {'num': 977,
#   'time_open': Timestamp('2025-09-05 01:00:00'),
#   'time_close': Timestamp('2025-09-05 01:59:59.999000'),
#   'M6A/USD': {'open': 0.6564,
#    'high': 0.6568,
#    'low': 0.6562,
#    'close': 0.6567,
#    'volume': 270.0,
#    'indicators': {'kama_58': 0.656892429114051,
#     'sma_102': 0.6570578431372549}}},
#  Timestamp('2025-09-05 02:59:59.999000'): {'num': 978,
#   'time_open': Timestamp('2025-09-05 02:00:00'),
#   'time_close': Timestamp('2025-09-05 02:59:59.999000'),
#   'M6A/USD': {'open': 0.6566,
#    'high': 0.6568,
#    'low': 0.6564,
#    'close': 0.6566,
#    'volume': 117.0,
#    'indicators': {'kama_58': 0.6568889114443752,
#     'sma_102': 0.6570411764705884}}},
#  Timestamp('2025-09-05 03:59:59.999000'): {'num': 979,
#   'time_open': Timestamp('2025-09-05 03:00:00'),
#   'time_close': Timestamp('2025-09-05 03:59:59.999000'),
#   'M6A/USD': {'open': 0.6566,
#    'high': 0.6568,
#    'low': 0.6565,
#    'close': 0.6567,
#    'volume': 62.0,
#    'indicators': {'kama_58': 0.6568876914386793,
#     'sma_102': 0.6570235294117648}}},
#  Timestamp('2025-09-05 04:59:59.999000'): {'num': 980,
#   'time_open': Timestamp('2025-09-05 04:00:00'),
#   'time_close': Timestamp('2025-09-05 04:59:59.999000'),
#   'M6A/USD': {'open': 0.6568,
#    'high': 0.6569,
#    'low': 0.6563,
#    'close': 0.6564,
#    'volume': 68.0,
#    'indicators': {'kama_58': 0.6568833621292505,
#     'sma_102': 0.6570058823529412}}},
#  Timestamp('2025-09-05 05:59:59.999000'): {'num': 981,
#   'time_open': Timestamp('2025-09-05 05:00:00'),
#   'time_close': Timestamp('2025-09-05 05:59:59.999000'),
#   'M6A/USD': {'open': 0.6565,
#    'high': 0.6574,
#    'low': 0.6565,
#    'close': 0.6573,
#    'volume': 136.0,
#    'indicators': {'kama_58': 0.6568878950253116,
#     'sma_102': 0.6569960784313726}}},
#  Timestamp('2025-09-05 06:59:59.999000'): {'num': 982,
#   'time_open': Timestamp('2025-09-05 06:00:00'),
#   'time_close': Timestamp('2025-09-05 06:59:59.999000'),
#   'M6A/USD': {'open': 0.6574,
#    'high': 0.6576,
#    'low': 0.6568,
#    'close': 0.657,
#    'volume': 160.0,
#    'indicators': {'kama_58': 0.656888926736235,
#     'sma_102': 0.6569843137254903}}},
#  Timestamp('2025-09-05 07:59:59.999000'): {'num': 983,
#   'time_open': Timestamp('2025-09-05 07:00:00'),
#   'time_close': Timestamp('2025-09-05 07:59:59.999000'),
#   'M6A/USD': {'open': 0.6571,
#    'high': 0.6581,
#    'low': 0.657,
#    'close': 0.6581,
#    'volume': 131.0,
#    'indicators': {'kama_58': 0.6569113128213716,
#     'sma_102': 0.6569872549019609}}},
#  Timestamp('2025-09-05 08:59:59.999000'): {'num': 984,
#   'time_open': Timestamp('2025-09-05 08:00:00'),
#   'time_close': Timestamp('2025-09-05 08:59:59.999000'),
#   'M6A/USD': {'open': 0.658,
#    'high': 0.6584,
#    'low': 0.6579,
#    'close': 0.6581,
#    'volume': 110.0,
#    'indicators': {'kama_58': 0.6569304270993463,
#     'sma_102': 0.6569892156862744}}},
#  Timestamp('2025-09-05 09:59:59.999000'): {'num': 985,
#   'time_open': Timestamp('2025-09-05 09:00:00'),
#   'time_close': Timestamp('2025-09-05 09:59:59.999000'),
#   'M6A/USD': {'open': 0.6581,
#    'high': 0.6583,
#    'low': 0.6579,
#    'close': 0.6581,
#    'volume': 119.0,
#    'indicators': {'kama_58': 0.6569492340167059,
#     'sma_102': 0.6569892156862746}}},
#  Timestamp('2025-09-05 10:59:59.999000'): {'num': 986,
#   'time_open': Timestamp('2025-09-05 10:00:00'),
#   'time_close': Timestamp('2025-09-05 10:59:59.999000'),
#   'M6A/USD': {'open': 0.6581,
#    'high': 0.6584,
#    'low': 0.658,
#    'close': 0.658,
#    'volume': 151.0,
#    'indicators': {'kama_58': 0.6569669057184104,
#     'sma_102': 0.6569833333333335}}},
#  Timestamp('2025-09-05 11:59:59.999000'): {'num': 987,
#   'time_open': Timestamp('2025-09-05 11:00:00'),
#   'time_close': Timestamp('2025-09-05 11:59:59.999000'),
#   'M6A/USD': {'open': 0.658,
#    'high': 0.6582,
#    'low': 0.6578,
#    'close': 0.6578,
#    'volume': 155.0,
#    'indicators': {'kama_58': 0.656979227682761,
#     'sma_102': 0.6569843137254903}}},
#  Timestamp('2025-09-05 12:59:59.999000'): {'num': 988,
#   'time_open': Timestamp('2025-09-05 12:00:00'),
#   'time_close': Timestamp('2025-09-05 12:59:59.999000'),
#   'M6A/USD': {'open': 0.6578,
#    'high': 0.6611,
#    'low': 0.6577,
#    'close': 0.6609,
#    'volume': 1060.0,
#    'indicators': {'kama_58': 0.6571358756137147,
#     'sma_102': 0.657006862745098}}},
#  Timestamp('2025-09-05 13:59:59.999000'): {'num': 989,
#   'time_open': Timestamp('2025-09-05 13:00:00'),
#   'time_close': Timestamp('2025-09-05 13:59:59.999000'),
#   'M6A/USD': {'open': 0.6609,
#    'high': 0.6626,
#    'low': 0.6607,
#    'close': 0.6626,
#    'volume': 675.0,
#    'indicators': {'kama_58': 0.6573819499429173,
#     'sma_102': 0.6570480392156863}}},
#  Timestamp('2025-09-05 14:59:59.999000'): {'num': 990,
#   'time_open': Timestamp('2025-09-05 14:00:00'),
#   'time_close': Timestamp('2025-09-05 14:59:59.999000'),
#   'M6A/USD': {'open': 0.6625,
#    'high': 0.6626,
#    'low': 0.6589,
#    'close': 0.6593,
#    'volume': 788.0,
#    'indicators': {'kama_58': 0.6574162272152746,
#     'sma_102': 0.6570598039215687}}},
#  Timestamp('2025-09-05 15:59:59.999000'): {'num': 991,
#   'time_open': Timestamp('2025-09-05 15:00:00'),
#   'time_close': Timestamp('2025-09-05 15:59:59.999000'),
#   'M6A/USD': {'open': 0.6596,
#    'high': 0.6606,
#    'low': 0.6591,
#    'close': 0.6605,
#    'volume': 230.0,
#    'indicators': {'kama_58': 0.6574987179093625,
#     'sma_102': 0.6570833333333334}}},
#  Timestamp('2025-09-05 16:59:59.999000'): {'num': 992,
#   'time_open': Timestamp('2025-09-05 16:00:00'),
#   'time_close': Timestamp('2025-09-05 16:59:59.999000'),
#   'M6A/USD': {'open': 0.6606,
#    'high': 0.6607,
#    'low': 0.6599,
#    'close': 0.6601,
#    'volume': 199.0,
#    'indicators': {'kama_58': 0.6575567868335099,
#     'sma_102': 0.6571019607843137}}},
#  Timestamp('2025-09-05 17:59:59.999000'): {'num': 993,
#   'time_open': Timestamp('2025-09-05 17:00:00'),
#   'time_close': Timestamp('2025-09-05 17:59:59.999000'),
#   'M6A/USD': {'open': 0.6601,
#    'high': 0.6601,
#    'low': 0.6592,
#    'close': 0.6592,
#    'volume': 135.0,
#    'indicators': {'kama_58': 0.657591303768987,
#     'sma_102': 0.6571078431372549}}},
#  Timestamp('2025-09-05 18:59:59.999000'): {'num': 994,
#   'time_open': Timestamp('2025-09-05 18:00:00'),
#   'time_close': Timestamp('2025-09-05 18:59:59.999000'),
#   'M6A/USD': {'open': 0.6593,
#    'high': 0.6593,
#    'low': 0.6587,
#    'close': 0.6589,
#    'volume': 136.0,
#    'indicators': {'kama_58': 0.6576187939232081,
#     'sma_102': 0.6571019607843138}}},
#  Timestamp('2025-09-05 19:59:59.999000'): {'num': 995,
#   'time_open': Timestamp('2025-09-05 19:00:00'),
#   'time_close': Timestamp('2025-09-05 19:59:59.999000'),
#   'M6A/USD': {'open': 0.659,
#    'high': 0.6592,
#    'low': 0.6588,
#    'close': 0.6589,
#    'volume': 120.0,
#    'indicators': {'kama_58': 0.6576384018978579,
#     'sma_102': 0.6570960784313726}}},
#  Timestamp('2025-09-05 20:59:59.999000'): {'num': 996,
#   'time_open': Timestamp('2025-09-05 20:00:00'),
#   'time_close': Timestamp('2025-09-05 20:59:59.999000'),
#   'M6A/USD': {'open': 0.659,
#    'high': 0.6595,
#    'low': 0.6589,
#    'close': 0.6594,
#    'volume': 180.0,
#    'indicators': {'kama_58': 0.6576677969653559,
#     'sma_102': 0.6570950980392157}}},
#  Timestamp('2025-09-07 22:59:59.999000'): {'num': 997,
#   'time_open': Timestamp('2025-09-07 22:00:00'),
#   'time_close': Timestamp('2025-09-07 22:59:59.999000'),
#   'M6A/USD': {'open': 0.6589,
#    'high': 0.6594,
#    'low': 0.6584,
#    'close': 0.6584,
#    'volume': 521.0,
#    'indicators': {'kama_58': 0.6576743389921107,
#     'sma_102': 0.6570872549019608}}},
#  Timestamp('2025-09-07 23:59:59.999000'): {'num': 998,
#   'time_open': Timestamp('2025-09-07 23:00:00'),
#   'time_close': Timestamp('2025-09-07 23:59:59.999000'),
#   'M6A/USD': {'open': 0.6586,
#    'high': 0.6592,
#    'low': 0.6586,
#    'close': 0.6592,
#    'volume': 107.0,
#    'indicators': {'kama_58': 0.6576940106706949,
#     'sma_102': 0.6570892156862745}}},
#  Timestamp('2025-09-08 00:59:59.999000'): {'num': 999,
#   'time_open': Timestamp('2025-09-08 00:00:00'),
#   'time_close': Timestamp('2025-09-08 00:59:59.999000'),
#   'M6A/USD': {'open': 0.6591,
#    'high': 0.6594,
#    'low': 0.6586,
#    'close': 0.6594,
#    'volume': 205.0,
#    'indicators': {'kama_58': 0.6577139435458139,
#     'sma_102': 0.657093137254902}}},
#  ...}

# %%
# single KAMA(fast)/SMA(slow) crossover strategy, full weight -- see
# M6A/step_1_find_best_indicators_and_parameters.ipynb for how these parameters were picked.
portfolio = Portfolio(weighted_strategies=[
    WeightedStrategy(
        weight=1.0,
        strategy=MaCrossoverStrategy(
            key=f"KAMA_{KAMA_FAST_LEN}_SMA_{KAMA_SMA_SLOW}_M6A",
            market=market,
            symbol=SYMBOL,
            direction=StrategyDirection.long,
            fast_indicator_key=f"{KAMA_INDICATOR_NAME}_{KAMA_FAST_LEN}",
            slow_indicator_key=f"{SMA_INDICATOR_NAME}_{KAMA_SMA_SLOW}",
            sl_percent=0.3,
            tp_percent=0.6,
            sl_enabled=True,
            tp_enabled=True,
        ),
    ),
], output_scale=1)

print("Portfolio is ready!")
# Out:
# Portfolio is ready!

# %%
# Tradovate per-symbol config: point value / tick size / min size-step / fees.
# M6A has a real tick_size and fee_per_contract_override set directly on
# TRADOVATE_FUTURES in exchange_config.py (see PROP_FIRM_PLAN.md for the research).
symbol_config_provider = TradovateSymbolConfigProvider(symbols=TRADOVATE_FUTURES, default_fee_per_contract=0.0)

# instantiate exchange -- futures, point-value/tick-based math via symbol_config_provider
# (slippage/maker_fee/taker_fee below are unused once symbol_config_provider is set, but
# still required constructor args).
exchange = Exchange(
            market=market,
            slippage=0.0,
            maker_fee=0.0,
            taker_fee=0.0,
            market_type=MarketType.future,
            max_leverage=10,  # NOTE: this system doesn't model Tradovate's real per-symbol
                               # exchange-set margin schedule yet -- max_leverage is a stand-in.
            margin_allocation_type=MarginAllocationType.cross,
            symbol_config_provider=symbol_config_provider,
        )

# %%
# instantiate reporter
# periods_per_year=252: real trading-days/year convention for futures (not 365,
# which is only correct for a 24/7 crypto market -- see PerformanceAnalyzer's own
# docstring). Using the wrong constant here previously inflated every Sharpe/
# Sortino/annualized-volatility number in this pipeline by sqrt(365/252) =~ 1.20
# (~20%) versus the correct figure -- CAGR/Calmar/max_drawdown/net_return are
# unaffected since they don't depend on periods_per_year.
reporter = PerformanceAnalyzer(market=market,
                    exchange=exchange,
                    portfolio=portfolio,
                    benchmark_symbols=[SYMBOL],
                    periods_per_year=252)

# %%
# run only one next step
market.reset()

# Tradeify Growth $50k account: $2,000 (4%) EOD-trailing drawdown, permanently halts
# trading (account_failed) once breached -- see middleware.py / PROP_FIRM_PLAN.md.
# Now also models Tradeify's real lock-once-reached mechanic: the trailing floor
# freezes permanently at initial_balance + $100 the first time EOD balance reaches
# initial_balance * (1 + drawdown_percent) + $100 (e.g. $52,100 for this account),
# rather than continuing to trail upward forever past that point.
drawdown_middleware = TradeifyDrawdownMiddleware(drawdown_percent=0.04)
# Tradeify's real $1,250/day soft daily-loss pause on a $50k account (2.5% of
# balance): flattens and halts for the rest of the trading day, then resumes
# normally the next day (unlike the drawdown middleware's permanent halt).
# Previously not modeled at all in this pipeline despite being a real,
# already-documented Tradeify rule (PROP_FIRM_PLAN.md).
daily_loss_middleware = MaxDailyLossMiddleware(max_loss_percent=0.025)

backtest = Backtester(
    market=market,
    portfolio=portfolio,
    exchange=exchange,
    reporter=reporter,
    middlewares=[daily_loss_middleware, drawdown_middleware],
)
# deposit prop-firm-sized funds so we can trade
backtest.exchange.transactions.add_deposit(asset="USD", volume=50000)
backtest.run_all()

# Print Report
print("Candles Processed: ", backtest.market.current['num'])
print("Account failed (drawdown breach): ", drawdown_middleware.account_failed)
print("Drawdown floor locked (reached profit buffer): ", drawdown_middleware.locked)
# formatted HTML table (description column + color-coded cells) instead of the raw
# numeric DataFrame -- see backtester.performance.report_html for the per-metric rules.
display(HTML(backtest.reporter.summary_html_table()))

if backtest.reporter.merged is not None:
    # Print a chart to compare the returns
    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__cumulative_returns",
        f"{SYMBOL}__cumulative_returns"
        ], figsize=(30,6))

    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__drawdown",
        f"{SYMBOL}__drawdown"
        ], figsize=(30,6))

    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__exchange_net_exposure",
        "algo__portfolio_net_exposure"
        ], figsize=(30,6))
# Out:
# Candles Processed:  5298
# Account failed (drawdown breach):  False
# Drawdown floor locked (reached profit buffer):  True
# <table style="border-collapse:collapse;font-family:sans-serif;font-size:13px;"><thead><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">metric</th><th style="border:1px solid #ddd;padding:4px 10px;">algo</th><th style="border:1px solid #ddd;padding:4px 10px;">M6A/USD</th><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">description</th></tr></thead><tbody><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">sharpe_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">1.3527</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">0.9459</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Return per unit of total volatility. &lt;0 bad, ~1 decent, &gt;2 great, &gt;3 excellent.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">sortino_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">2.1815</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">1.4314</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Like Sharpe but only penalizes downside volatility (upside swings aren&#x27;t &quot;risk&quot;). &gt;2 good, &gt;3 excellent.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">annualized_volatility_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">4.9180</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">7.1794</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">How much the equity curve swings per year. Lower = smoother.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">cagr_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">9.9218</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">9.9259</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Compound annual growth rate, the smoothed annual growth rate. Higher is generally better, but always weigh against volatility/drawdown.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">calmar_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#4caf50;color:#ffffff;border:2px solid #2e7d32;font-weight:600;">3.4739</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;">2.1521</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">CAGR ÷ max drawdown. &gt;1 decent, &gt;3 excellent, &lt;0.5 weak.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">recovery_factor</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">3.1066</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">1.9246</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Total net profit ÷ max drawdown. &gt;2 solid.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">max_drawdown_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">-2.8561</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;">-4.6122</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Largest peak-to-trough loss. Closer to 0 better; below -20% ...

# %%
# market.merged
pd.DataFrame(backtest.exchange.get_logs())
# Out:
#                       time                                            message
# 0  2025-07-08 14:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 1  2025-07-21 22:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 2  2025-07-28 13:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 3  2025-08-05 20:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 4  2025-08-12 03:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 5  2025-08-25 07:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 6  2025-09-03 19:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 7  2025-09-05 12:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 8  2025-09-17 06:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 9  2025-09-24 20:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 10 2025-09-25 17:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 11 2025-09-30 08:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 12 2025-10-06 12:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 13 2025-10-07 03:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 14 2025-10-08 01:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 15 2025-10-17 16:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 16 2025-10-21 00:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 17 2025-10-21 15:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 18 2025-10-23 18:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 19 2025-10-27 00:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 20 2025-11-03 01:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 21 2025-11-10 01:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 22 2025-11-14 06:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 23 2025-11-25 00:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 24 2025-12-15 03:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 25 2025-12-22 07:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 26 2025-12-31 09:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 27 2026-01-05 20:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 28 2026-01-09 08:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 29 2026-01-14 05:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 30 2026-01-15 04:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 31 2026-01-19 04:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 32 2026-02-06 15:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 33 2026-02-09 15:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 34 2026-02-17 01:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 35 2026-02-18 07:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 36 2026-03-02 18:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 37 2026-03-06 14:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 38 2026-03-13 15:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 39 2026-03-19 17:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 40 2026-03-20 19:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 41 2026-04-01 12:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 42 2026-04-06 14:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 43 2026-04-07 20:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 44 2026-04-30 00:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 45 2026-05-04 03:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 46 2026-05-06 05:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 47 2026-05-06 08:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 48 2026-05-06 15:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 49 2026-05-07 03:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 50 2026-05-11 16:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 51 2026-05-22 18:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 52 2026-05-27 17:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 53 2026-06-01 12:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...

# %%
# get dataframe with all the trades that were executed
def _trade_to_dict(trade):
    d = trade.__dict__.copy()
    for k, v in d.items():
        if hasattr(v, "value"):
            d[k] = v.value
    return d

pd.DataFrame([_trade_to_dict(t) for t in backtest.reporter.trades])
# Out:
#      symbol  side            time_open           time_close  open_price  \
# 0   M6A/USD  long  1753138799999000000  1753711199999000000      0.6566
# 1   M6A/USD  long  1754427599999000000  1754971199999000000      0.6514
# 2   M6A/USD  long  1756108799999000000  1756929599999000000      0.6526
# 3   M6A/USD  long  1757077199999000000  1758092399999000000      0.6609
# 4   M6A/USD  long  1758747599999000000  1758823199999000000      0.6598
# 5   M6A/USD  long  1759222799999000000  1759755599999000000      0.6623
# 6   M6A/USD  long  1759809599999000000  1759888799999000000      0.6633
# 7   M6A/USD  long  1760720399999000000  1761008399999000000      0.6498
# 8   M6A/USD  long  1761062399999000000  1761245999999000000      0.6510
# 9   M6A/USD  long  1761526799999000000  1762135199999000000      0.6542
# 10  M6A/USD  long  1762739999999000000  1763103599999000000      0.6527
# 11  M6A/USD  long  1764032399999000000  1765771199999000000      0.6471
# 12  M6A/USD  long  1766390399999000000  1767175199999000000      0.6666
# 13  M6A/USD  long  1767646799999000000  1767949199999000000      0.6743
# 14  M6A/USD  long  1768370399999000000  1768453199999000000      0.6720
# 15  M6A/USD  long  1768798799999000000  1770393599999000000      0.6719
# 16  M6A/USD  long  1770652799999000000  1771293599999000000      0.7114
# 17  M6A/USD  long  1771401599999000000  1772477999999000000      0.7096
# 18  M6A/USD  long  1772809199999000000  1773417599999000000      0.7017
# 19  M6A/USD  long  1773943199999000000  1774036799999000000      0.7036
# 20  M6A/USD  long  1775048399999000000  1775487599999000000      0.6922
# 21  M6A/USD  long  1775595599999000000  1777510799999000000      0.6959
# 22  M6A/USD  long  1777867199999000000  1778047199999000000      0.7196
# 23  M6A/USD  long  1778057999999000000  1778083199999000000      0.7244
# 24  M6A/USD  long  1778126399999000000  1778518799999000000      0.7225
# 25  M6A/USD  long  1779476399999000000  1779904799999000000      0.7124
#
#     close_price close_reason       pnl  result    holding_period  risk_percent
# 0        0.6560       signal -0.000914   loser   572400000000000           0.3
# 1        0.6559       signal  0.006908  winner   543600000000000           0.3
# 2        0.6578       signal  0.007968  winner   820800000000000           0.3
# 3        0.6690       signal  0.012256  winner  1015200000000000           0.3
# 4        0.6548       signal -0.007578   loser    75600000000000           0.3
# 5        0.6624       signal  0.000151  winner   532800000000000           0.3
# 6        0.6578       signal -0.008292   loser    79200000000000           0.3
# 7        0.6536       signal  0.005848  winner   288000000000000           0.3
# 8        0.6529       signal  0.002919  winner   183600000000000           0.3
# 9        0.6555       signal  0.001987  winner   608400000000000           0.3
# 10       0.6543       signal  0.002451  winner   363600000000000           0.3
# 11       0.6649       signal  0.027507  winner  1738800000000000           0.3
# 12       0.6711       signal  0.006751  winner   784800000000000           0.3
# 13       0.6709       signal -0.005042   loser   302400000000000           0.3
# 14       0.6701       signal -0.002827   loser    82800000000000           0.3
# 15       0.7032       signal  0.046584  winner  1594800000000000           0.3
# 16       0.7084       signal -0.004217   loser   640800000000000           0.3
# 17       0.7109       signal  0.001832  winner  1076400000000000           0.3
# 18       0.7032       signal  0.002138  winner   608400000000000           0.3
# 19       0.6998       signal -0.005401   loser    93600000000000           0.3
# 20       0.6904       signal -0.002600   loser   439200000000000           0.3
# 21       0.7105       signal  0.020980  winner  1915200000000000           0.3
# 22       0.7230       signal  0.004725  winner   180000000000000           0.3
# 23       0.7218       signal -0.003589   loser    25200000000000           0.3
# 24       0.7234       signal  0.001246  winner   392400000000000           0.3
# 25       0.7122       signal -0.000281   loser   428400000000000           0.3
