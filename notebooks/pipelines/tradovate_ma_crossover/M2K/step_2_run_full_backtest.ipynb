# %% [markdown]
# # M2K (Micro E-mini Russell 2000) — MA crossover, Tradovate exchange
#
# Mirrors `MES/step_2_run_full_backtest.ipynb`'s MA-crossover setup, applied to **Micro E-mini Russell 2000 futures** (M2K) instead of MES: real 1h OHLC pulled from this repo's Mongo/Timescale store (via the shared `data_aggregator.mongo_timescale_aggregator` module), whole-contract position sizing, tick-based slippage + per-contract fees, and a Tradeify-style EOD-trailing drawdown risk middleware.
#
# **Strategy**: a single crossover -- the winner of the four-way indicator-family comparison (KAMA, EMA, HMA, DEMA, each fast-line paired against a plain SMA slow line) run in `M2K/step_1_find_best_indicators_and_parameters.ipynb`, selected by a trade-level Sharpe lower bound rather than raw return (see that notebook's "Methodology" and "Final pick" cells for the full reasoning + honest caveats about how much confidence that pick actually supports). Only 2 indicators feed a single strategy here, run through the full event-driven engine: real order fills, margin, whole-contract sizing, and the drawdown middleware, none of which the vectorized notebook models. Same `DATE_FROM`/`DATE_TO` window as that notebook so the two are comparable. Results here will still differ from the vectorized numbers -- that's expected, not a bug, since whole-contract sizing/margin are modeled for real here instead of as a frictionless percentage-return approximation.
#
# **Costs, now researched** (`PROP_FIRM_PLAN.md`, `OPTIMIZATION_RESEARCH_PLAN.md`): M2K tick_size=0.10 index points ($0.50/tick, CME spec) and a $0.91/side commission are set directly on `TRADOVATE_FUTURES["M2K"]` in `exchange_config.py`. M2K commission: Tradeify's fee source confirms $1.82 round-turn for "micro contracts like MES and MNQ" but doesn't separately name M2K -- this assumes the same standard-micro rate (-> $0.91/side), not a M2K-specific citation (see `PROP_FIRM_PLAN.md`). The drawdown middleware below uses Tradeify's real $50k-Growth-account number (4%, not this middleware's generic 5% default) and models the real lock-once-reached trail-freeze mechanic.

# %%
import json
import os

import pandas as pd
from IPython.display import HTML, display

from backtester.backtest_runner import Backtester
from backtester.exchange import Exchange, MarginAllocationType, MarketType, TradovateSymbolConfigProvider
from backtester.exchange_config import TRADOVATE_FUTURES
from backtester.indicators import Indicators
from backtester.market import Market
from backtester.middleware import MaxDailyLossMiddleware, TradeifyDrawdownMiddleware
from backtester.performance import PerformanceAnalyzer
from backtester.portfolio import Portfolio, WeightedStrategy
from backtester.strategies import MaCrossoverStrategy, StrategyDirection
from data_aggregator.mongo_timescale_aggregator import fetch_market_data

cwd = os.getcwd()
print(cwd)
# Out:
# /Users/nick/Documents/www/alphakit/notebooks/pipelines/tradovate_ma_crossover/M2K

# %%
# Instantiate markets class
market = Market()

# ALL INTERVALS SHOULD BE THE SAME!!
INTERVAL = 1
UNIT_OF_TIME = "hour"

DISPLAY_SYMBOL = "M2K"       # bare symbol, as registered in Mongo `instruments`
SYMBOL = "M2K/USD"           # backtester-internal symbol (asset/quote)
SOURCE = "ib"                # Interactive Brokers continuous futures contract
RESOLUTION = "1_hour"

# Same window as notebooks/vectorized_backtest_mes_tradovate.ipynb, for comparability.
DATE_FROM = "2019-10-01"
DATE_TO = "2026-06-01"

# Winner of the 4-indicator-family comparison in step_1 (unlike MES, EMA/SMA won here,
# not KAMA/SMA): EMA(fast)/SMA(slow), long_len=12, short_len=2 -- a very short/fast
# pair; see step_1's "Final pick" cell for the full reasoning + caveats.
EMA_FAST_LEN = 2
EMA_SMA_SLOW = 12

ohlc = fetch_market_data(source=SOURCE, display_symbol=DISPLAY_SYMBOL, resolution=RESOLUTION)
ohlc = ohlc.loc[DATE_FROM:DATE_TO]

market.add_market(
    symbol=SYMBOL,
    df=ohlc
    )

# --- EMA(fast)/SMA(slow) crossover indicators -- only 2, one per side of the crossover.
EMA_INDICATOR_NAME = 'ema'
SMA_INDICATOR_NAME = 'sma'
market.add_indicator(
    symbol=SYMBOL,
    interval=INTERVAL,
    unit_of_time=UNIT_OF_TIME,
    indicator_name=f"{EMA_INDICATOR_NAME}_{EMA_FAST_LEN}",
    df=Indicators.ema(ohlc, length=EMA_FAST_LEN)
)
market.add_indicator(
    symbol=SYMBOL,
    interval=INTERVAL,
    unit_of_time=UNIT_OF_TIME,
    indicator_name=f"{SMA_INDICATOR_NAME}_{EMA_SMA_SLOW}",
    df=Indicators.sma(ohlc, EMA_SMA_SLOW)
)

market.compile()
# Out:
# {Timestamp('2025-07-08 14:47:05.999000'): {'num': 0,
#   'time_open': Timestamp('2025-07-08 13:47:06'),
#   'time_close': Timestamp('2025-07-08 14:47:05.999000'),
#   'M2K/USD': {'open': 2308.5,
#    'high': 2311.0,
#    'low': 2305.0,
#    'close': 2308.1,
#    'volume': 2569.0,
#    'indicators': {'ema_2': nan, 'sma_12': nan}}},
#  Timestamp('2025-07-08 14:59:59.999000'): {'num': 1,
#   'time_open': Timestamp('2025-07-08 14:00:00'),
#   'time_close': Timestamp('2025-07-08 14:59:59.999000'),
#   'M2K/USD': {'open': 2308.3,
#    'high': 2311.8,
#    'low': 2299.5,
#    'close': 2307.8,
#    'volume': 10304.0,
#    'indicators': {'ema_2': 2307.95, 'sma_12': nan}}},
#  Timestamp('2025-07-08 15:59:59.999000'): {'num': 2,
#   'time_open': Timestamp('2025-07-08 15:00:00'),
#   'time_close': Timestamp('2025-07-08 15:59:59.999000'),
#   'M2K/USD': {'open': 2308.1,
#    'high': 2315.2,
#    'low': 2305.8,
#    'close': 2313.5,
#    'volume': 5211.0,
#    'indicators': {'ema_2': 2311.65, 'sma_12': nan}}},
#  Timestamp('2025-07-08 16:59:59.999000'): {'num': 3,
#   'time_open': Timestamp('2025-07-08 16:00:00'),
#   'time_close': Timestamp('2025-07-08 16:59:59.999000'),
#   'M2K/USD': {'open': 2313.7,
#    'high': 2319.8,
#    'low': 2308.0,
#    'close': 2313.0,
#    'volume': 6059.0,
#    'indicators': {'ema_2': 2312.55, 'sma_12': nan}}},
#  Timestamp('2025-07-08 17:59:59.999000'): {'num': 4,
#   'time_open': Timestamp('2025-07-08 17:00:00'),
#   'time_close': Timestamp('2025-07-08 17:59:59.999000'),
#   'M2K/USD': {'open': 2312.9,
#    'high': 2316.7,
#    'low': 2308.4,
#    'close': 2315.6,
#    'volume': 2918.0,
#    'indicators': {'ema_2': 2314.5833333333335, 'sma_12': nan}}},
#  Timestamp('2025-07-08 18:59:59.999000'): {'num': 5,
#   'time_open': Timestamp('2025-07-08 18:00:00'),
#   'time_close': Timestamp('2025-07-08 18:59:59.999000'),
#   'M2K/USD': {'open': 2315.4,
#    'high': 2316.9,
#    'low': 2310.1,
#    'close': 2311.9,
#    'volume': 2552.0,
#    'indicators': {'ema_2': 2312.7944444444447, 'sma_12': nan}}},
#  Timestamp('2025-07-08 19:59:59.999000'): {'num': 6,
#   'time_open': Timestamp('2025-07-08 19:00:00'),
#   'time_close': Timestamp('2025-07-08 19:59:59.999000'),
#   'M2K/USD': {'open': 2311.7,
#    'high': 2313.1,
#    'low': 2307.0,
#    'close': 2309.0,
#    'volume': 3083.0,
#    'indicators': {'ema_2': 2310.264814814815, 'sma_12': nan}}},
#  Timestamp('2025-07-08 20:59:59.999000'): {'num': 7,
#   'time_open': Timestamp('2025-07-08 20:00:00'),
#   'time_close': Timestamp('2025-07-08 20:59:59.999000'),
#   'M2K/USD': {'open': 2309.1,
#    'high': 2311.2,
#    'low': 2308.3,
#    'close': 2309.8,
#    'volume': 888.0,
#    'indicators': {'ema_2': 2309.9549382716054, 'sma_12': nan}}},
#  Timestamp('2025-07-08 22:59:59.999000'): {'num': 8,
#   'time_open': Timestamp('2025-07-08 22:00:00'),
#   'time_close': Timestamp('2025-07-08 22:59:59.999000'),
#   'M2K/USD': {'open': 2311.4,
#    'high': 2312.1,
#    'low': 2308.6,
#    'close': 2309.8,
#    'volume': 394.0,
#    'indicators': {'ema_2': 2309.8516460905353, 'sma_12': nan}}},
#  Timestamp('2025-07-08 23:59:59.999000'): {'num': 9,
#   'time_open': Timestamp('2025-07-08 23:00:00'),
#   'time_close': Timestamp('2025-07-08 23:59:59.999000'),
#   'M2K/USD': {'open': 2310.1,
#    'high': 2311.2,
#    'low': 2303.8,
#    'close': 2304.3,
#    'volume': 770.0,
#    'indicators': {'ema_2': 2306.1505486968454, 'sma_12': nan}}},
#  Timestamp('2025-07-09 00:59:59.999000'): {'num': 10,
#   'time_open': Timestamp('2025-07-09 00:00:00'),
#   'time_close': Timestamp('2025-07-09 00:59:59.999000'),
#   'M2K/USD': {'open': 2304.1,
#    'high': 2304.5,
#    'low': 2300.1,
#    'close': 2300.5,
#    'volume': 816.0,
#    'indicators': {'ema_2': 2302.3835162322816, 'sma_12': nan}}},
#  Timestamp('2025-07-09 01:59:59.999000'): {'num': 11,
#   'time_open': Timestamp('2025-07-09 01:00:00'),
#   'time_close': Timestamp('2025-07-09 01:59:59.999000'),
#   'M2K/USD': {'open': 2300.5,
#    'high': 2303.9,
#    'low': 2297.6,
#    'close': 2303.5,
#    'volume': 827.0,
#    'indicators': {'ema_2': 2303.127838744094, 'sma_12': 2308.8999999999996}}},
#  Timestamp('2025-07-09 02:59:59.999000'): {'num': 12,
#   'time_open': Timestamp('2025-07-09 02:00:00'),
#   'time_close': Timestamp('2025-07-09 02:59:59.999000'),
#   'M2K/USD': {'open': 2303.6,
#    'high': 2304.4,
#    'low': 2301.8,
#    'close': 2302.3,
#    'volume': 395.0,
#    'indicators': {'ema_2': 2302.5759462480314, 'sma_12': 2308.4166666666665}}},
#  Timestamp('2025-07-09 03:59:59.999000'): {'num': 13,
#   'time_open': Timestamp('2025-07-09 03:00:00'),
#   'time_close': Timestamp('2025-07-09 03:59:59.999000'),
#   'M2K/USD': {'open': 2302.4,
#    'high': 2303.0,
#    'low': 2301.6,
#    'close': 2301.9,
#    'volume': 164.0,
#    'indicators': {'ema_2': 2302.1253154160104, 'sma_12': 2307.9249999999997}}},
#  Timestamp('2025-07-09 04:59:59.999000'): {'num': 14,
#   'time_open': Timestamp('2025-07-09 04:00:00'),
#   'time_close': Timestamp('2025-07-09 04:59:59.999000'),
#   'M2K/USD': {'open': 2302.1,
#    'high': 2304.3,
#    'low': 2301.7,
#    'close': 2303.1,
#    'volume': 279.0,
#    'indicators': {'ema_2': 2302.77510513867, 'sma_12': 2307.058333333333}}},
#  Timestamp('2025-07-09 05:59:59.999000'): {'num': 15,
#   'time_open': Timestamp('2025-07-09 05:00:00'),
#   'time_close': Timestamp('2025-07-09 05:59:59.999000'),
#   'M2K/USD': {'open': 2302.9,
#    'high': 2303.2,
#    'low': 2300.3,
#    'close': 2302.8,
#    'volume': 244.0,
#    'indicators': {'ema_2': 2302.7917017128902, 'sma_12': 2306.208333333333}}},
#  Timestamp('2025-07-09 06:59:59.999000'): {'num': 16,
#   'time_open': Timestamp('2025-07-09 06:00:00'),
#   'time_close': Timestamp('2025-07-09 06:59:59.999000'),
#   'M2K/USD': {'open': 2302.5,
#    'high': 2306.6,
#    'low': 2300.5,
#    'close': 2306.2,
#    'volume': 512.0,
#    'indicators': {'ema_2': 2305.063900570963, 'sma_12': 2305.4249999999997}}},
#  Timestamp('2025-07-09 07:59:59.999000'): {'num': 17,
#   'time_open': Timestamp('2025-07-09 07:00:00'),
#   'time_close': Timestamp('2025-07-09 07:59:59.999000'),
#   'M2K/USD': {'open': 2306.3,
#    'high': 2309.6,
#    'low': 2304.0,
#    'close': 2307.6,
#    'volume': 635.0,
#    'indicators': {'ema_2': 2306.7546335236543, 'sma_12': 2305.0666666666666}}},
#  Timestamp('2025-07-09 08:59:59.999000'): {'num': 18,
#   'time_open': Timestamp('2025-07-09 08:00:00'),
#   'time_close': Timestamp('2025-07-09 08:59:59.999000'),
#   'M2K/USD': {'open': 2307.3,
#    'high': 2309.9,
#    'low': 2305.1,
#    'close': 2305.7,
#    'volume': 451.0,
#    'indicators': {'ema_2': 2306.051544507885, 'sma_12': 2304.7916666666665}}},
#  Timestamp('2025-07-09 09:59:59.999000'): {'num': 19,
#   'time_open': Timestamp('2025-07-09 09:00:00'),
#   'time_close': Timestamp('2025-07-09 09:59:59.999000'),
#   'M2K/USD': {'open': 2305.7,
#    'high': 2312.4,
#    'low': 2305.6,
#    'close': 2310.2,
#    'volume': 707.0,
#    'indicators': {'ema_2': 2308.8171815026285, 'sma_12': 2304.825}}},
#  Timestamp('2025-07-09 10:59:59.999000'): {'num': 20,
#   'time_open': Timestamp('2025-07-09 10:00:00'),
#   'time_close': Timestamp('2025-07-09 10:59:59.999000'),
#   'M2K/USD': {'open': 2310.2,
#    'high': 2312.0,
#    'low': 2308.3,
#    'close': 2309.3,
#    'volume': 619.0,
#    'indicators': {'ema_2': 2309.1390605008764, 'sma_12': 2304.7833333333333}}},
#  Timestamp('2025-07-09 11:59:59.999000'): {'num': 21,
#   'time_open': Timestamp('2025-07-09 11:00:00'),
#   'time_close': Timestamp('2025-07-09 11:59:59.999000'),
#   'M2K/USD': {'open': 2309.2,
#    'high': 2316.2,
#    'low': 2308.4,
#    'close': 2314.9,
#    'volume': 938.0,
#    'indicators': {'ema_2': 2312.9796868336257, 'sma_12': 2305.6666666666665}}},
#  Timestamp('2025-07-09 12:59:59.999000'): {'num': 22,
#   'time_open': Timestamp('2025-07-09 12:00:00'),
#   'time_close': Timestamp('2025-07-09 12:59:59.999000'),
#   'M2K/USD': {'open': 2314.5,
#    'high': 2315.4,
#    'low': 2311.8,
#    'close': 2313.5,
#    'volume': 1092.0,
#    'indicators': {'ema_2': 2313.3265622778754, 'sma_12': 2306.75}}},
#  Timestamp('2025-07-09 13:59:59.999000'): {'num': 23,
#   'time_open': Timestamp('2025-07-09 13:00:00'),
#   'time_close': Timestamp('2025-07-09 13:59:59.999000'),
#   'M2K/USD': {'open': 2313.8,
#    'high': 2328.2,
#    'low': 2313.7,
#    'close': 2321.1,
#    'volume': 11519.0,
#    'indicators': {'ema_2': 2318.508854092625, 'sma_12': 2308.2166666666667}}},
#  Timestamp('2025-07-09 14:59:59.999000'): {'num': 24,
#   'time_open': Timestamp('2025-07-09 14:00:00'),
#   'time_close': Timestamp('2025-07-09 14:59:59.999000'),
#   'M2K/USD': {'open': 2321.1,
#    'high': 2323.0,
#    'low': 2307.6,
#    'close': 2310.4,
#    'volume': 9847.0,
#    'indicators': {'ema_2': 2313.1029513642084, 'sma_12': 2308.8916666666664}}},
#  Timestamp('2025-07-09 15:59:59.999000'): {'num': 25,
#   'time_open': Timestamp('2025-07-09 15:00:00'),
#   'time_close': Timestamp('2025-07-09 15:59:59.999000'),
#   'M2K/USD': {'open': 2310.3,
#    'high': 2318.2,
#    'low': 2306.8,
#    'close': 2317.5,
#    'volume': 5914.0,
#    'indicators': {'ema_2': 2316.034317121403, 'sma_12': 2310.1916666666666}}},
#  Timestamp('2025-07-09 16:59:59.999000'): {'num': 26,
#   'time_open': Timestamp('2025-07-09 16:00:00'),
#   'time_close': Timestamp('2025-07-09 16:59:59.999000'),
#   'M2K/USD': {'open': 2317.2,
#    'high': 2320.9,
#    'low': 2315.9,
#    'close': 2319.5,
#    'volume': 3586.0,
#    'indicators': {'ema_2': 2318.344772373801, 'sma_12': 2311.5583333333334}}},
#  Timestamp('2025-07-09 17:59:59.999000'): {'num': 27,
#   'time_open': Timestamp('2025-07-09 17:00:00'),
#   'time_close': Timestamp('2025-07-09 17:59:59.999000'),
#   'M2K/USD': {'open': 2319.4,
#    'high': 2327.0,
#    'low': 2318.5,
#    'close': 2325.5,
#    'volume': 3923.0,
#    'indicators': {'ema_2': 2323.1149241246003, 'sma_12': 2313.45}}},
#  Timestamp('2025-07-09 18:59:59.999000'): {'num': 28,
#   'time_open': Timestamp('2025-07-09 18:00:00'),
#   'time_close': Timestamp('2025-07-09 18:59:59.999000'),
#   'M2K/USD': {'open': 2325.4,
#    'high': 2331.0,
#    'low': 2323.0,
#    'close': 2326.1,
#    'volume': 3790.0,
#    'indicators': {'ema_2': 2325.1049747082, 'sma_12': 2315.108333333333}}},
#  Timestamp('2025-07-09 19:59:59.999000'): {'num': 29,
#   'time_open': Timestamp('2025-07-09 19:00:00'),
#   'time_close': Timestamp('2025-07-09 19:59:59.999000'),
#   'M2K/USD': {'open': 2326.1,
#    'high': 2334.2,
#    'low': 2324.0,
#    'close': 2333.7,
#    'volume': 4711.0,
#    'indicators': {'ema_2': 2330.8349915694, 'sma_12': 2317.283333333333}}},
#  Timestamp('2025-07-09 20:59:59.999000'): {'num': 30,
#   'time_open': Timestamp('2025-07-09 20:00:00'),
#   'time_close': Timestamp('2025-07-09 20:59:59.999000'),
#   'M2K/USD': {'open': 2333.5,
#    'high': 2335.8,
#    'low': 2331.8,
#    'close': 2333.5,
#    'volume': 1379.0,
#    'indicators': {'ema_2': 2332.6116638564667, 'sma_12': 2319.5999999999995}}},
#  Timestamp('2025-07-09 22:59:59.999000'): {'num': 31,
#   'time_open': Timestamp('2025-07-09 22:00:00'),
#   'time_close': Timestamp('2025-07-09 22:59:59.999000'),
#   'M2K/USD': {'open': 2334.6,
#    'high': 2337.0,
#    'low': 2332.0,
#    'close': 2334.9,
#    'volume': 606.0,
#    'indicators': {'ema_2': 2334.137221285489, 'sma_12': 2321.658333333333}}},
#  Timestamp('2025-07-09 23:59:59.999000'): {'num': 32,
#   'time_open': Timestamp('2025-07-09 23:00:00'),
#   'time_close': Timestamp('2025-07-09 23:59:59.999000'),
#   'M2K/USD': {'open': 2334.9,
#    'high': 2335.2,
#    'low': 2331.5,
#    'close': 2332.6,
#    'volume': 380.0,
#    'indicators': {'ema_2': 2333.1124070951632, 'sma_12': 2323.6}}},
#  Timestamp('2025-07-10 00:59:59.999000'): {'num': 33,
#   'time_open': Timestamp('2025-07-10 00:00:00'),
#   'time_close': Timestamp('2025-07-10 00:59:59.999000'),
#   'M2K/USD': {'open': 2331.9,
#    'high': 2332.0,
#    'low': 2327.5,
#    'close': 2328.8,
#    'volume': 494.0,
#    'indicators': {'ema_2': 2330.237469031721, 'sma_12': 2324.758333333333}}},
#  Timestamp('2025-07-10 01:59:59.999000'): {'num': 34,
#   'time_open': Timestamp('2025-07-10 01:00:00'),
#   'time_close': Timestamp('2025-07-10 01:59:59.999000'),
#   'M2K/USD': {'open': 2328.8,
#    'high': 2329.8,
#    'low': 2326.3,
#    'close': 2326.3,
#    'volume': 474.0,
#    'indicators': {'ema_2': 2327.612489677241, 'sma_12': 2325.825}}},
#  Timestamp('2025-07-10 02:59:59.999000'): {'num': 35,
#   'time_open': Timestamp('2025-07-10 02:00:00'),
#   'time_close': Timestamp('2025-07-10 02:59:59.999000'),
#   'M2K/USD': {'open': 2326.8,
#    'high': 2330.1,
#    'low': 2326.8,
#    'close': 2329.2,
#    'volume': 344.0,
#    'indicators': {'ema_2': 2328.6708298924136, 'sma_12': 2326.5}}},
#  Timestamp('2025-07-10 03:59:59.999000'): {'num': 36,
#   'time_open': Timestamp('2025-07-10 03:00:00'),
#   'time_close': Timestamp('2025-07-10 03:59:59.999000'),
#   'M2K/USD': {'open': 2329.0,
#    'high': 2329.0,
#    'low': 2325.1,
#    'close': 2326.2,
#    'volume': 394.0,
#    'indicators': {'ema_2': 2327.023609964138, 'sma_12': 2327.8166666666666}}},
#  Timestamp('2025-07-10 04:59:59.999000'): {'num': 37,
#   'time_open': Timestamp('2025-07-10 04:00:00'),
#   'time_close': Timestamp('2025-07-10 04:59:59.999000'),
#   'M2K/USD': {'open': 2326.1,
#    'high': 2327.2,
#    'low': 2325.6,
#    'close': 2326.2,
#    'volume': 226.0,
#    'indicators': {'ema_2': 2326.4745366547127, 'sma_12': 2328.5416666666665}}},
#  Timestamp('2025-07-10 05:59:59.999000'): {'num': 38,
#   'time_open': Timestamp('2025-07-10 05:00:00'),
#   'time_close': Timestamp('2025-07-10 05:59:59.999000'),
#   'M2K/USD': {'open': 2326.3,
#    'high': 2328.0,
#    'low': 2325.6,
#    'close': 2327.8,
#    'volume': 261.0,
#    'indicators': {'ema_2': 2327.3581788849046, 'sma_12': 2329.233333333333}}},
#  Timestamp('2025-07-10 06:59:59.999000'): {'num': 39,
#   'time_open': Timestamp('2025-07-10 06:00:00'),
#   'time_close': Timestamp('2025-07-10 06:59:59.999000'),
#   'M2K/USD': {'open': 2328.1,
#    'high': 2328.4,
#    'low': 2325.4,
#    'close': 2326.5,
#    'volume': 374.0,
#    'indicators': {'ema_2': 2326.7860596283017, 'sma_12': 2329.3166666666666}}},
#  Timestamp('2025-07-10 07:59:59.999000'): {'num': 40,
#   'time_open': Timestamp('2025-07-10 07:00:00'),
#   'time_close': Timestamp('2025-07-10 07:59:59.999000'),
#   'M2K/USD': {'open': 2326.3,
#    'high': 2329.3,
#    'low': 2325.4,
#    'close': 2327.1,
#    'volume': 406.0,
#    'indicators': {'ema_2': 2326.9953532094337, 'sma_12': 2329.3999999999996}}},
#  Timestamp('2025-07-10 08:59:59.999000'): {'num': 41,
#   'time_open': Timestamp('2025-07-10 08:00:00'),
#   'time_close': Timestamp('2025-07-10 08:59:59.999000'),
#   'M2K/USD': {'open': 2327.0,
#    'high': 2331.2,
#    'low': 2326.8,
#    'close': 2330.6,
#    'volume': 436.0,
#    'indicators': {'ema_2': 2329.398451069811, 'sma_12': 2329.1416666666664}}},
#  Timestamp('2025-07-10 09:59:59.999000'): {'num': 42,
#   'time_open': Timestamp('2025-07-10 09:00:00'),
#   'time_close': Timestamp('2025-07-10 09:59:59.999000'),
#   'M2K/USD': {'open': 2330.5,
#    'high': 2332.0,
#    'low': 2329.6,
#    'close': 2331.9,
#    'volume': 454.0,
#    'indicators': {'ema_2': 2331.066150356604, 'sma_12': 2329.008333333333}}},
#  Timestamp('2025-07-10 10:59:59.999000'): {'num': 43,
#   'time_open': Timestamp('2025-07-10 10:00:00'),
#   'time_close': Timestamp('2025-07-10 10:59:59.999000'),
#   'M2K/USD': {'open': 2331.6,
#    'high': 2335.4,
#    'low': 2330.5,
#    'close': 2333.8,
#    'volume': 977.0,
#    'indicators': {'ema_2': 2332.888716785535, 'sma_12': 2328.9166666666665}}},
#  Timestamp('2025-07-10 11:59:59.999000'): {'num': 44,
#   'time_open': Timestamp('2025-07-10 11:00:00'),
#   'time_close': Timestamp('2025-07-10 11:59:59.999000'),
#   'M2K/USD': {'open': 2333.9,
#    'high': 2338.6,
#    'low': 2332.8,
#    'close': 2337.3,
#    'volume': 971.0,
#    'indicators': {'ema_2': 2335.829572261845, 'sma_12': 2329.3083333333334}}},
#  Timestamp('2025-07-10 12:59:59.999000'): {'num': 45,
#   'time_open': Timestamp('2025-07-10 12:00:00'),
#   'time_close': Timestamp('2025-07-10 12:59:59.999000'),
#   'M2K/USD': {'open': 2337.1,
#    'high': 2339.0,
#    'low': 2329.2,
#    'close': 2329.7,
#    'volume': 1887.0,
#    'indicators': {'ema_2': 2331.7431907539485, 'sma_12': 2329.383333333333}}},
#  Timestamp('2025-07-10 13:59:59.999000'): {'num': 46,
#   'time_open': Timestamp('2025-07-10 13:00:00'),
#   'time_close': Timestamp('2025-07-10 13:59:59.999000'),
#   'M2K/USD': {'open': 2329.7,
#    'high': 2334.3,
#    'low': 2325.1,
#    'close': 2331.8,
#    'volume': 8525.0,
#    'indicators': {'ema_2': 2331.7810635846495, 'sma_12': 2329.8416666666662}}},
#  Timestamp('2025-07-10 14:59:59.999000'): {'num': 47,
#   'time_open': Timestamp('2025-07-10 14:00:00'),
#   'time_close': Timestamp('2025-07-10 14:59:59.999000'),
#   'M2K/USD': {'open': 2332.2,
#    'high': 2345.0,
#    'low': 2331.2,
#    'close': 2344.1,
#    'volume': 9577.0,
#    'indicators': {'ema_2': 2339.99368786155, 'sma_12': 2331.083333333333}}},
#  Timestamp('2025-07-10 15:59:59.999000'): {'num': 48,
#   'time_open': Timestamp('2025-07-10 15:00:00'),
#   'time_close': Timestamp('2025-07-10 15:59:59.999000'),
#   'M2K/USD': {'open': 2344.1,
#    'high': 2348.8,
#    'low': 2343.0,
#    'close': 2348.3,
#    'volume': 6644.0,
#    'indicators': {'ema_2': 2345.5312292871836, 'sma_12': 2332.9249999999997}}},
#  Timestamp('2025-07-10 16:59:59.999000'): {'num': 49,
#   'time_open': Timestamp('2025-07-10 16:00:00'),
#   'time_close': Timestamp('2025-07-10 16:59:59.999000'),
#   'M2K/USD': {'open': 2348.2,
#    'high': 2352.7,
#    'low': 2347.5,
#    'close': 2349.2,
#    'volume': 4436.0,
#    'indicators': {'ema_2': 2347.977076429061, 'sma_12': 2334.8416666666662}}},
#  Timestamp('2025-07-10 17:59:59.999000'): {'num': 50,
#   'time_open': Timestamp('2025-07-10 17:00:00'),
#   'time_close': Timestamp('2025-07-10 17:59:59.999000'),
#   'M2K/USD': {'open': 2349.4,
#    'high': 2358.3,
#    'low': 2349.4,
#    'close': 2355.5,
#    'volume': 3702.0,
#    'indicators': {'ema_2': 2352.992358809687, 'sma_12': 2337.1499999999996}}},
#  Timestamp('2025-07-10 18:59:59.999000'): {'num': 51,
#   'time_open': Timestamp('2025-07-10 18:00:00'),
#   'time_close': Timestamp('2025-07-10 18:59:59.999000'),
#   'M2K/USD': {'open': 2355.5,
#    'high': 2355.5,
#    'low': 2348.2,
#    'close': 2349.0,
#    'volume': 3901.0,
#    'indicators': {'ema_2': 2350.3307862698957, 'sma_12': 2339.0249999999996}}},
#  Timestamp('2025-07-10 19:59:59.999000'): {'num': 52,
#   'time_open': Timestamp('2025-07-10 19:00:00'),
#   'time_close': Timestamp('2025-07-10 19:59:59.999000'),
#   'M2K/USD': {'open': 2349.0,
#    'high': 2353.9,
#    'low': 2343.7,
#    'close': 2345.1,
#    'volume': 5633.0,
#    'indicators': {'ema_2': 2346.8435954232987, 'sma_12': 2340.5249999999996}}},
#  Timestamp('2025-07-10 20:59:59.999000'): {'num': 53,
#   'time_open': Timestamp('2025-07-10 20:00:00'),
#   'time_close': Timestamp('2025-07-10 20:59:59.999000'),
#   'M2K/USD': {'open': 2345.1,
#    'high': 2347.1,
#    'low': 2343.7,
#    'close': 2344.7,
#    'volume': 1346.0,
#    'indicators': {'ema_2': 2345.4145318077663, 'sma_12': 2341.7}}},
#  Timestamp('2025-07-10 22:59:59.999000'): {'num': 54,
#   'time_open': Timestamp('2025-07-10 22:00:00'),
#   'time_close': Timestamp('2025-07-10 22:59:59.999000'),
#   'M2K/USD': {'open': 2346.0,
#    'high': 2348.6,
#    'low': 2344.8,
#    'close': 2348.2,
#    'volume': 547.0,
#    'indicators': {'ema_2': 2347.2715106025885, 'sma_12': 2343.0583333333334}}},
#  Timestamp('2025-07-10 23:59:59.999000'): {'num': 55,
#   'time_open': Timestamp('2025-07-10 23:00:00'),
#   'time_close': Timestamp('2025-07-10 23:59:59.999000'),
#   'M2K/USD': {'open': 2348.2,
#    'high': 2349.7,
#    'low': 2347.4,
#    'close': 2349.1,
#    'volume': 331.0,
#    'indicators': {'ema_2': 2348.4905035341963, 'sma_12': 2344.3333333333335}}},
#  Timestamp('2025-07-11 00:59:59.999000'): {'num': 56,
#   'time_open': Timestamp('2025-07-11 00:00:00'),
#   'time_close': Timestamp('2025-07-11 00:59:59.999000'),
#   'M2K/USD': {'open': 2348.9,
#    'high': 2348.9,
#    'low': 2326.3,
#    'close': 2329.3,
#    'volume': 3952.0,
#    'indicators': {'ema_2': 2335.696834511399, 'sma_12': 2343.6666666666665}}},
#  Timestamp('2025-07-11 01:59:59.999000'): {'num': 57,
#   'time_open': Timestamp('2025-07-11 01:00:00'),
#   'time_close': Timestamp('2025-07-11 01:59:59.999000'),
#   'M2K/USD': {'open': 2329.6,
#    'high': 2333.5,
#    'low': 2327.3,
#    'close': 2331.1,
#    'volume': 1263.0,
#    'indicators': {'ema_2': 2332.6322781704666, 'sma_12': 2343.783333333333}}},
#  Timestamp('2025-07-11 02:59:59.999000'): {'num': 58,
#   'time_open': Timestamp('2025-07-11 02:00:00'),
#   'time_close': Timestamp('2025-07-11 02:59:59.999000'),
#   'M2K/USD': {'open': 2331.1,
#    'high': 2333.2,
#    'low': 2330.6,
#    'close': 2332.6,
#    'volume': 727.0,
#    'indicators': {'ema_2': 2332.6107593901556, 'sma_12': 2343.85}}},
#  Timestamp('2025-07-11 03:59:59.999000'): {'num': 59,
#   'time_open': Timestamp('2025-07-11 03:00:00'),
#   'time_close': Timestamp('2025-07-11 03:59:59.999000'),
#   'M2K/USD': {'open': 2332.5,
#    'high': 2336.9,
#    'low': 2332.5,
#    'close': 2336.6,
#    'volume': 530.0,
#    'indicators': {'ema_2': 2335.270253130052, 'sma_12': 2343.2249999999995}}},
#  Timestamp('2025-07-11 04:59:59.999000'): {'num': 60,
#   'time_open': Timestamp('2025-07-11 04:00:00'),
#   'time_close': Timestamp('2025-07-11 04:59:59.999000'),
#   'M2K/USD': {'open': 2336.7,
#    'high': 2338.2,
#    'low': 2335.5,
#    'close': 2336.6,
#    'volume': 413.0,
#    'indicators': {'ema_2': 2336.1567510433506, 'sma_12': 2342.2499999999995}}},
#  Timestamp('2025-07-11 05:59:59.999000'): {'num': 61,
#   'time_open': Timestamp('2025-07-11 05:00:00'),
#   'time_close': Timestamp('2025-07-11 05:59:59.999000'),
#   'M2K/USD': {'open': 2336.5,
#    'high': 2336.9,
#    'low': 2333.6,
#    'close': 2333.6,
#    'volume': 325.0,
#    'indicators': {'ema_2': 2334.4522503477833, 'sma_12': 2340.95}}},
#  Timestamp('2025-07-11 06:59:59.999000'): {'num': 62,
#   'time_open': Timestamp('2025-07-11 06:00:00'),
#   'time_close': Timestamp('2025-07-11 06:59:59.999000'),
#   'M2K/USD': {'open': 2333.8,
#    'high': 2336.9,
#    'low': 2333.7,
#    'close': 2335.1,
#    'volume': 331.0,
#    'indicators': {'ema_2': 2334.884083449261, 'sma_12': 2339.25}}},
#  Timestamp('2025-07-11 07:59:59.999000'): {'num': 63,
#   'time_open': Timestamp('2025-07-11 07:00:00'),
#   'time_close': Timestamp('2025-07-11 07:59:59.999000'),
#   'M2K/USD': {'open': 2335.0,
#    'high': 2336.6,
#    'low': 2327.9,
#    'close': 2327.9,
#    'volume': 1288.0,
#    'indicators': {'ema_2': 2330.2280278164208, 'sma_12': 2337.491666666667}}},
#  Timestamp('2025-07-11 08:59:59.999000'): {'num': 64,
#   'time_open': Timestamp('2025-07-11 08:00:00'),
#   'time_close': Timestamp('2025-07-11 08:59:59.999000'),
#   'M2K/USD': {'open': 2327.9,
#    'high': 2330.3,
#    'low': 2323.4,
#    'close': 2326.9,
#    'volume': 1196.0,
#    'indicators': {'ema_2': 2328.0093426054736, 'sma_12': 2335.975}}},
#  Timestamp('2025-07-11 09:59:59.999000'): {'num': 65,
#   'time_open': Timestamp('2025-07-11 09:00:00'),
#   'time_close': Timestamp('2025-07-11 09:59:59.999000'),
#   'M2K/USD': {'open': 2326.9,
#    'high': 2328.3,
#    'low': 2316.7,
#    'close': 2316.9,
#    'volume': 1227.0,
#    'indicators': {'ema_2': 2320.6031142018246, 'sma_12': 2333.6583333333333}}},
#  Timestamp('2025-07-11 10:59:59.999000'): {'num': 66,
#   'time_open': Timestamp('2025-07-11 10:00:00'),
#   'time_close': Timestamp('2025-07-11 10:59:59.999000'),
#   'M2K/USD': {'open': 2317.2,
#    'high': 2322.3,
#    'low': 2315.7,
#    'close': 2318.8,
#    'volume': 1354.0,
#    'indicators': {'ema_2': 2319.4010380672753, 'sma_12': 2331.208333333333}}},
#  Timestamp('2025-07-11 11:59:59.999000'): {'num': 67,
#   'time_open': Timestamp('2025-07-11 11:00:00'),
#   'time_close': Timestamp('2025-07-11 11:59:59.999000'),
#   'M2K/USD': {'open': 2319.1,
#    'high': 2328.0,
#    'low': 2319.1,
#    'close': 2325.3,
#    'volume': 1137.0,
#    'indicators': {'ema_2': 2323.3336793557587, 'sma_12': 2329.225}}},
#  Timestamp('2025-07-11 12:59:59.999000'): {'num': 68,
#   'time_open': Timestamp('2025-07-11 12:00:00'),
#   'time_close': Timestamp('2025-07-11 12:59:59.999000'),
#   'M2K/USD': {'open': 2325.3,
#    'high': 2328.3,
#    'low': 2323.2,
#    'close': 2326.5,
#    'volume': 1081.0,
#    'indicators': {'ema_2': 2325.444559785253, 'sma_12': 2328.991666666667}}},
#  Timestamp('2025-07-11 13:59:59.999000'): {'num': 69,
#   'time_open': Timestamp('2025-07-11 13:00:00'),
#   'time_close': Timestamp('2025-07-11 13:59:59.999000'),
#   'M2K/USD': {'open': 2326.2,
#    'high': 2331.3,
#    'low': 2317.4,
#    'close': 2324.3,
#    'volume': 7182.0,
#    'indicators': {'ema_2': 2324.681519928418, 'sma_12': 2328.4249999999997}}},
#  Timestamp('2025-07-11 14:59:59.999000'): {'num': 70,
#   'time_open': Timestamp('2025-07-11 14:00:00'),
#   'time_close': Timestamp('2025-07-11 14:59:59.999000'),
#   'M2K/USD': {'open': 2324.5,
#    'high': 2328.0,
#    'low': 2315.8,
#    'close': 2321.1,
#    'volume': 8290.0,
#    'indicators': {'ema_2': 2322.293839976139, 'sma_12': 2327.4666666666662}}},
#  Timestamp('2025-07-11 15:59:59.999000'): {'num': 71,
#   'time_open': Timestamp('2025-07-11 15:00:00'),
#   'time_close': Timestamp('2025-07-11 15:59:59.999000'),
#   'M2K/USD': {'open': 2321.4,
#    'high': 2322.7,
#    'low': 2315.5,
#    'close': 2316.5,
#    'volume': 5279.0,
#    'indicators': {'ema_2': 2318.4312799920463, 'sma_12': 2325.791666666667}}},
#  Timestamp('2025-07-11 16:59:59.999000'): {'num': 72,
#   'time_open': Timestamp('2025-07-11 16:00:00'),
#   'time_close': Timestamp('2025-07-11 16:59:59.999000'),
#   'M2K/USD': {'open': 2316.3,
#    'high': 2321.1,
#    'low': 2312.3,
#    'close': 2320.3,
#    'volume': 4814.0,
#    'indicators': {'ema_2': 2319.6770933306825, 'sma_12': 2324.4333333333334}}},
#  Timestamp('2025-07-11 17:59:59.999000'): {'num': 73,
#   'time_open': Timestamp('2025-07-11 17:00:00'),
#   'time_close': Timestamp('2025-07-11 17:59:59.999000'),
#   'M2K/USD': {'open': 2320.3,
#    'high': 2322.1,
#    'low': 2314.9,
#    'close': 2319.7,
#    'volume': 3285.0,
#    'indicators': {'ema_2': 2319.6923644435606, 'sma_12': 2323.2749999999996}}},
#  Timestamp('2025-07-11 18:59:59.999000'): {'num': 74,
#   'time_open': Timestamp('2025-07-11 18:00:00'),
#   'time_close': Timestamp('2025-07-11 18:59:59.999000'),
#   'M2K/USD': {'open': 2319.6,
#    'high': 2322.9,
#    'low': 2316.8,
#    'close': 2319.8,
#    'volume': 3087.0,
#    'indicators': {'ema_2': 2319.764121481187, 'sma_12': 2322.0}}},
#  Timestamp('2025-07-11 19:59:59.999000'): {'num': 75,
#   'time_open': Timestamp('2025-07-11 19:00:00'),
#   'time_close': Timestamp('2025-07-11 19:59:59.999000'),
#   'M2K/USD': {'open': 2319.5,
#    'high': 2319.8,
#    'low': 2310.6,
#    'close': 2311.6,
#    'volume': 6699.0,
#    'indicators': {'ema_2': 2314.3213738270624, 'sma_12': 2320.6416666666664}}},
#  Timestamp('2025-07-11 20:59:59.999000'): {'num': 76,
#   'time_open': Timestamp('2025-07-11 20:00:00'),
#   'time_close': Timestamp('2025-07-11 20:59:59.999000'),
#   'M2K/USD': {'open': 2311.7,
#    'high': 2313.0,
#    'low': 2308.2,
#    'close': 2309.2,
#    'volume': 1584.0,
#    'indicators': {'ema_2': 2310.9071246090207, 'sma_12': 2319.1666666666665}}},
#  Timestamp('2025-07-13 22:59:59.999000'): {'num': 77,
#   'time_open': Timestamp('2025-07-13 22:00:00'),
#   'time_close': Timestamp('2025-07-13 22:59:59.999000'),
#   'M2K/USD': {'open': 2301.6,
#    'high': 2302.1,
#    'low': 2291.2,
#    'close': 2298.9,
#    'volume': 1788.0,
#    'indicators': {'ema_2': 2302.9023748696736, 'sma_12': 2317.666666666667}}},
#  Timestamp('2025-07-13 23:59:59.999000'): {'num': 78,
#   'time_open': Timestamp('2025-07-13 23:00:00'),
#   'time_close': Timestamp('2025-07-13 23:59:59.999000'),
#   'M2K/USD': {'open': 2299.2,
#    'high': 2299.2,
#    'low': 2293.9,
#    'close': 2297.4,
#    'volume': 975.0,
#    'indicators': {'ema_2': 2299.234124956558, 'sma_12': 2315.883333333333}}},
#  Timestamp('2025-07-14 00:59:59.999000'): {'num': 79,
#   'time_open': Timestamp('2025-07-14 00:00:00'),
#   'time_close': Timestamp('2025-07-14 00:59:59.999000'),
#   'M2K/USD': {'open': 2297.7,
#    'high': 2299.3,
#    'low': 2296.3,
#    'close': 2296.4,
#    'volume': 881.0,
#    'indicators': {'ema_2': 2297.344708318853, 'sma_12': 2313.475}}},
#  Timestamp('2025-07-14 01:59:59.999000'): {'num': 80,
#   'time_open': Timestamp('2025-07-14 01:00:00'),
#   'time_close': Timestamp('2025-07-14 01:59:59.999000'),
#   'M2K/USD': {'open': 2297.2,
#    'high': 2297.9,
#    'low': 2295.5,
#    'close': 2297.4,
#    'volume': 587.0,
#    'indicators': {'ema_2': 2297.3815694396176, 'sma_12': 2311.05}}},
#  Timestamp('2025-07-14 02:59:59.999000'): {'num': 81,
#   'time_open': Timestamp('2025-07-14 02:00:00'),
#   'time_close': Timestamp('2025-07-14 02:59:59.999000'),
#   'M2K/USD': {'open': 2297.4,
#    'high': 2298.4,
#    'low': 2296.4,
#    'close': 2296.6,
#    'volume': 316.0,
#    'indicators': {'ema_2': 2296.8605231465394, 'sma_12': 2308.741666666667}}},
#  Timestamp('2025-07-14 03:59:59.999000'): {'num': 82,
#   'time_open': Timestamp('2025-07-14 03:00:00'),
#   'time_close': Timestamp('2025-07-14 03:59:59.999000'),
#   'M2K/USD': {'open': 2296.5,
#    'high': 2298.4,
#    'low': 2295.5,
#    'close': 2297.8,
#    'volume': 329.0,
#    'indicators': {'ema_2': 2297.4868410488466, 'sma_12': 2306.8}}},
#  Timestamp('2025-07-14 04:59:59.999000'): {'num': 83,
#   'time_open': Timestamp('2025-07-14 04:00:00'),
#   'time_close': Timestamp('2025-07-14 04:59:59.999000'),
#   'M2K/USD': {'open': 2297.9,
#    'high': 2297.9,
#    'low': 2296.3,
#    'close': 2296.7,
#    'volume': 256.0,
#    'indicators': {'ema_2': 2296.9622803496154, 'sma_12': 2305.15}}},
#  Timestamp('2025-07-14 05:59:59.999000'): {'num': 84,
#   'time_open': Timestamp('2025-07-14 05:00:00'),
#   'time_close': Timestamp('2025-07-14 05:59:59.999000'),
#   'M2K/USD': {'open': 2296.6,
#    'high': 2297.9,
#    'low': 2291.7,
#    'close': 2292.5,
#    'volume': 468.0,
#    'indicators': {'ema_2': 2293.987426783205, 'sma_12': 2302.833333333333}}},
#  Timestamp('2025-07-14 06:59:59.999000'): {'num': 85,
#   'time_open': Timestamp('2025-07-14 06:00:00'),
#   'time_close': Timestamp('2025-07-14 06:59:59.999000'),
#   'M2K/USD': {'open': 2292.8,
#    'high': 2294.1,
#    'low': 2289.3,
#    'close': 2293.0,
#    'volume': 685.0,
#    'indicators': {'ema_2': 2293.3291422610682, 'sma_12': 2300.608333333333}}},
#  Timestamp('2025-07-14 07:59:59.999000'): {'num': 86,
#   'time_open': Timestamp('2025-07-14 07:00:00'),
#   'time_close': Timestamp('2025-07-14 07:59:59.999000'),
#   'M2K/USD': {'open': 2293.0,
#    'high': 2300.4,
#    'low': 2289.2,
#    'close': 2299.2,
#    'volume': 1000.0,
#    'indicators': {'ema_2': 2297.243047420356, 'sma_12': 2298.8916666666664}}},
#  Timestamp('2025-07-14 08:59:59.999000'): {'num': 87,
#   'time_open': Timestamp('2025-07-14 08:00:00'),
#   'time_close': Timestamp('2025-07-14 08:59:59.999000'),
#   'M2K/USD': {'open': 2299.3,
#    'high': 2303.0,
#    'low': 2296.4,
#    'close': 2302.7,
#    'volume': 938.0,
#    'indicators': {'ema_2': 2300.8810158067854, 'sma_12': 2298.1499999999996}}},
#  Timestamp('2025-07-14 09:59:59.999000'): {'num': 88,
#   'time_open': Timestamp('2025-07-14 09:00:00'),
#   'time_close': Timestamp('2025-07-14 09:59:59.999000'),
#   'M2K/USD': {'open': 2302.7,
#    'high': 2305.5,
#    'low': 2301.3,
#    'close': 2303.7,
#    'volume': 1039.0,
#    'indicators': {'ema_2': 2302.7603386022615, 'sma_12': 2297.6916666666666}}},
#  Timestamp('2025-07-14 10:59:59.999000'): {'num': 89,
#   'time_open': Timestamp('2025-07-14 10:00:00'),
#   'time_close': Timestamp('2025-07-14 10:59:59.999000'),
#   'M2K/USD': {'open': 2303.7,
#    'high': 2305.8,
#    'low': 2302.7,
#    'close': 2304.4,
#    'volume': 604.0,
#    'indicators': {'ema_2': 2303.8534462007538, 'sma_12': 2298.1499999999996}}},
#  Timestamp('2025-07-14 11:59:59.999000'): {'num': 90,
#   'time_open': Timestamp('2025-07-14 11:00:00'),
#   'time_close': Timestamp('2025-07-14 11:59:59.999000'),
#   'M2K/USD': {'open': 2304.8,
#    'high': 2306.8,
#    'low': 2301.7,
#    'close': 2304.8,
#    'volume': 1307.0,
#    'indicators': {'ema_2': 2304.484482066918, 'sma_12': 2298.7666666666664}}},
#  Timestamp('2025-07-14 12:59:59.999000'): {'num': 91,
#   'time_open': Timestamp('2025-07-14 12:00:00'),
#   'time_close': Timestamp('2025-07-14 12:59:59.999000'),
#   'M2K/USD': {'open': 2304.4,
#    'high': 2306.0,
#    'low': 2300.4,
#    'close': 2302.0,
#    'volume': 1203.0,
#    'indicators': {'ema_2': 2302.8281606889727, 'sma_12': 2299.233333333333}}},
#  Timestamp('2025-07-14 13:59:59.999000'): {'num': 92,
#   'time_open': Timestamp('2025-07-14 13:00:00'),
#   'time_close': Timestamp('2025-07-14 13:59:59.999000'),
#   'M2K/USD': {'open': 2301.8,
#    'high': 2321.4,
#    'low': 2300.1,
#    'close': 2311.8,
#    'volume': 9098.0,
#    'indicators': {'ema_2': 2308.809386896324, 'sma_12': 2300.4333333333334}}},
#  Timestamp('2025-07-14 14:59:59.999000'): {'num': 93,
#   'time_open': Timestamp('2025-07-14 14:00:00'),
#   'time_close': Timestamp('2025-07-14 14:59:59.999000'),
#   'M2K/USD': {'open': 2311.8,
#    'high': 2321.4,
#    'low': 2310.4,
#    'close': 2316.4,
#    'volume': 7958.0,
#    'indicators': {'ema_2': 2313.869795632108, 'sma_12': 2302.083333333333}}},
#  Timestamp('2025-07-14 15:59:59.999000'): {'num': 94,
#   'time_open': Timestamp('2025-07-14 15:00:00'),
#   'time_close': Timestamp('2025-07-14 15:59:59.999000'),
#   'M2K/USD': {'open': 2316.2,
#    'high': 2319.7,
#    'low': 2310.8,
#    'close': 2317.0,
#    'volume': 4940.0,
#    'indicators': {'ema_2': 2315.956598544036, 'sma_12': 2303.683333333333}}},
#  Timestamp('2025-07-14 16:59:59.999000'): {'num': 95,
#   'time_open': Timestamp('2025-07-14 16:00:00'),
#   'time_close': Timestamp('2025-07-14 16:59:59.999000'),
#   'M2K/USD': {'open': 2317.0,
#    'high': 2322.9,
#    'low': 2313.1,
#    'close': 2322.1,
#    'volume': 3329.0,
#    'indicators': {'ema_2': 2320.0521995146787, 'sma_12': 2305.7999999999997}}},
#  Timestamp('2025-07-14 17:59:59.999000'): {'num': 96,
#   'time_open': Timestamp('2025-07-14 17:00:00'),
#   'time_close': Timestamp('2025-07-14 17:59:59.999000'),
#   'M2K/USD': {'open': 2322.0,
#    'high': 2324.7,
#    'low': 2319.6,
#    'close': 2321.5,
#    'volume': 2613.0,
#    'indicators': {'ema_2': 2321.017399838226, 'sma_12': 2308.2166666666662}}},
#  Timestamp('2025-07-14 18:59:59.999000'): {'num': 97,
#   'time_open': Timestamp('2025-07-14 18:00:00'),
#   'time_close': Timestamp('2025-07-14 18:59:59.999000'),
#   'M2K/USD': {'open': 2321.6,
#    'high': 2326.1,
#    'low': 2321.5,
#    'close': 2323.2,
#    'volume': 2019.0,
#    'indicators': {'ema_2': 2322.4724666127418, 'sma_12': 2310.733333333333}}},
#  Timestamp('2025-07-14 19:59:59.999000'): {'num': 98,
#   'time_open': Timestamp('2025-07-14 19:00:00'),
#   'time_close': Timestamp('2025-07-14 19:59:59.999000'),
#   'M2K/USD': {'open': 2323.4,
#    'high': 2328.7,
#    'low': 2321.9,
#    'close': 2327.2,
#    'volume': 3559.0,
#    'indicators': {'ema_2': 2325.6241555375805, 'sma_12': 2313.0666666666666}}},
#  Timestamp('2025-07-14 20:59:59.999000'): {'num': 99,
#   'time_open': Timestamp('2025-07-14 20:00:00'),
#   'time_close': Timestamp('2025-07-14 20:59:59.999000'),
#   'M2K/USD': {'open': 2327.2,
#    'high': 2328.0,
#    'low': 2324.5,
#    'close': 2325.9,
#    'volume': 1253.0,
#    'indicators': {'ema_2': 2325.80805184586, 'sma_12': 2315.0}}},
#  Timestamp('2025-07-14 22:59:59.999000'): {'num': 100,
#   'time_open': Timestamp('2025-07-14 22:00:00'),
#   'time_close': Timestamp('2025-07-14 22:59:59.999000'),
#   'M2K/USD': {'open': 2325.4,
#    'high': 2325.8,
#    'low': 2322.1,
#    'close': 2322.6,
#    'volume': 558.0,
#    'indicators': {'ema_2': 2323.6693506152865, 'sma_12': 2316.575}}},
#  Timestamp('2025-07-14 23:59:59.999000'): {'num': 101,
#   'time_open': Timestamp('2025-07-14 23:00:00'),
#   'time_close': Timestamp('2025-07-14 23:59:59.999000'),
#   'M2K/USD': {'open': 2322.7,
#    'high': 2324.2,
#    'low': 2321.2,
#    'close': 2323.5,
#    'volume': 392.0,
#    'indicators': {'ema_2': 2323.5564502050956, 'sma_12': 2318.166666666666}}},
#  Timestamp('2025-07-15 00:59:59.999000'): {'num': 102,
#   'time_open': Timestamp('2025-07-15 00:00:00'),
#   'time_close': Timestamp('2025-07-15 00:59:59.999000'),
#   'M2K/USD': {'open': 2323.5,
#    'high': 2325.5,
#    'low': 2322.1,
#    'close': 2324.1,
#    'volume': 391.0,
#    'indicators': {'ema_2': 2323.9188167350317, 'sma_12': 2319.7749999999996}}},
#  Timestamp('2025-07-15 01:59:59.999000'): {'num': 103,
#   'time_open': Timestamp('2025-07-15 01:00:00'),
#   'time_close': Timestamp('2025-07-15 01:59:59.999000'),
#   'M2K/USD': {'open': 2323.3,
#    'high': 2336.6,
#    'low': 2323.0,
#    'close': 2331.1,
#    'volume': 1496.0,
#    'indicators': {'ema_2': 2328.7062722450105, 'sma_12': 2322.2}}},
#  Timestamp('2025-07-15 02:59:59.999000'): {'num': 104,
#   'time_open': Timestamp('2025-07-15 02:00:00'),
#   'time_close': Timestamp('2025-07-15 02:59:59.999000'),
#   'M2K/USD': {'open': 2331.4,
#    'high': 2332.4,
#    'low': 2320.7,
#    'close': 2322.0,
#    'volume': 1355.0,
#    'indicators': {'ema_2': 2324.2354240816703, 'sma_12': 2323.0499999999997}}},
#  Timestamp('2025-07-15 03:59:59.999000'): {'num': 105,
#   'time_open': Timestamp('2025-07-15 03:00:00'),
#   'time_close': Timestamp('2025-07-15 03:59:59.999000'),
#   'M2K/USD': {'open': 2321.6,
#    'high': 2325.7,
#    'low': 2321.0,
#    'close': 2322.9,
#    'volume': 622.0,
#    'indicators': {'ema_2': 2323.3451413605567, 'sma_12': 2323.5916666666662}}},
#  Timestamp('2025-07-15 04:59:59.999000'): {'num': 106,
#   'time_open': Timestamp('2025-07-15 04:00:00'),
#   'time_close': Timestamp('2025-07-15 04:59:59.999000'),
#   'M2K/USD': {'open': 2322.9,
#    'high': 2330.2,
#    'low': 2322.5,
#    'close': 2327.3,
#    'volume': 896.0,
#    'indicators': {'ema_2': 2325.981713786852, 'sma_12': 2324.45}}},
#  Timestamp('2025-07-15 05:59:59.999000'): {'num': 107,
#   'time_open': Timestamp('2025-07-15 05:00:00'),
#   'time_close': Timestamp('2025-07-15 05:59:59.999000'),
#   'M2K/USD': {'open': 2327.2,
#    'high': 2331.1,
#    'low': 2326.9,
#    'close': 2329.9,
#    'volume': 610.0,
#    'indicators': {'ema_2': 2328.5939045956175, 'sma_12': 2325.1}}},
#  Timestamp('2025-07-15 06:59:59.999000'): {'num': 108,
#   'time_open': Timestamp('2025-07-15 06:00:00'),
#   'time_close': Timestamp('2025-07-15 06:59:59.999000'),
#   'M2K/USD': {'open': 2330.0,
#    'high': 2331.6,
#    'low': 2327.5,
#    'close': 2328.6,
#    'volume': 540.0,
#    'indicators': {'ema_2': 2328.597968198539, 'sma_12': 2325.6916666666666}}},
#  Timestamp('2025-07-15 07:59:59.999000'): {'num': 109,
#   'time_open': Timestamp('2025-07-15 07:00:00'),
#   'time_close': Timestamp('2025-07-15 07:59:59.999000'),
#   'M2K/USD': {'open': 2329.1,
#    'high': 2331.2,
#    'low': 2327.2,
#    'close': 2330.6,
#    'volume': 521.0,
#    'indicators': {'ema_2': 2329.93265606618, 'sma_12': 2326.3083333333334}}},
#  Timestamp('2025-07-15 08:59:59.999000'): {'num': 110,
#   'time_open': Timestamp('2025-07-15 08:00:00'),
#   'time_close': Timestamp('2025-07-15 08:59:59.999000'),
#   'M2K/USD': {'open': 2330.2,
#    'high': 2330.8,
#    'low': 2326.7,
#    'close': 2328.6,
#    'volume': 701.0,
#    'indicators': {'ema_2': 2329.0442186887267, 'sma_12': 2326.4249999999997}}},
#  Timestamp('2025-07-15 09:59:59.999000'): {'num': 111,
#   'time_open': Timestamp('2025-07-15 09:00:00'),
#   'time_close': Timestamp('2025-07-15 09:59:59.999000'),
#   'M2K/USD': {'open': 2328.2,
#    'high': 2330.8,
#    'low': 2328.2,
#    'close': 2330.3,
#    'volume': 464.0,
#    'indicators': {'ema_2': 2329.8814062295755, 'sma_12': 2326.7916666666665}}},
#  Timestamp('2025-07-15 10:59:59.999000'): {'num': 112,
#   'time_open': Timestamp('2025-07-15 10:00:00'),
#   'time_close': Timestamp('2025-07-15 10:59:59.999000'),
#   'M2K/USD': {'open': 2329.7,
#    'high': 2332.4,
#    'low': 2328.4,
#    'close': 2330.0,
#    'volume': 982.0,
#    'indicators': {'ema_2': 2329.960468743192, 'sma_12': 2327.4083333333333}}},
#  Timestamp('2025-07-15 11:59:59.999000'): {'num': 113,
#   'time_open': Timestamp('2025-07-15 11:00:00'),
#   'time_close': Timestamp('2025-07-15 11:59:59.999000'),
#   'M2K/USD': {'open': 2329.8,
#    'high': 2332.8,
#    'low': 2327.3,
#    'close': 2328.7,
#    'volume': 1359.0,
#    'indicators': {'ema_2': 2329.1201562477304, 'sma_12': 2327.8416666666662}}},
#  Timestamp('2025-07-15 12:59:59.999000'): {'num': 114,
#   'time_open': Timestamp('2025-07-15 12:00:00'),
#   'time_close': Timestamp('2025-07-15 12:59:59.999000'),
#   'M2K/USD': {'open': 2328.4,
#    'high': 2337.8,
#    'low': 2322.9,
#    'close': 2330.7,
#    'volume': 4215.0,
#    'indicators': {'ema_2': 2330.17338541591, 'sma_12': 2328.3916666666664}}},
#  Timestamp('2025-07-15 13:59:59.999000'): {'num': 115,
#   'time_open': Timestamp('2025-07-15 13:00:00'),
#   'time_close': Timestamp('2025-07-15 13:59:59.999000'),
#   'M2K/USD': {'open': 2330.9,
#    'high': 2338.4,
#    'low': 2315.2,
#    'close': 2315.7,
#    'volume': 10532.0,
#    'indicators': {'ema_2': 2320.5244618053034, 'sma_12': 2327.1083333333327}}},
#  Timestamp('2025-07-15 14:59:59.999000'): {'num': 116,
#   'time_open': Timestamp('2025-07-15 14:00:00'),
#   'time_close': Timestamp('2025-07-15 14:59:59.999000'),
#   'M2K/USD': {'open': 2316.0,
#    'high': 2321.0,
#    'low': 2302.6,
#    'close': 2304.0,
#    'volume': 10292.0,
#    'indicators': {'ema_2': 2309.5081539351013, 'sma_12': 2325.608333333333}}},
#  Timestamp('2025-07-15 15:59:59.999000'): {'num': 117,
#   'time_open': Timestamp('2025-07-15 15:00:00'),
#   'time_close': Timestamp('2025-07-15 15:59:59.999000'),
#   'M2K/USD': {'open': 2304.3,
#    'high': 2311.6,
#    'low': 2300.7,
#    'close': 2303.8,
#    'volume': 5604.0,
#    'indicators': {'ema_2': 2305.702717978367, 'sma_12': 2324.0166666666664}}},
#  Timestamp('2025-07-15 16:59:59.999000'): {'num': 118,
#   'time_open': Timestamp('2025-07-15 16:00:00'),
#   'time_close': Timestamp('2025-07-15 16:59:59.999000'),
#   'M2K/USD': {'open': 2303.7,
#    'high': 2307.7,
#    'low': 2292.0,
#    'close': 2292.2,
#    'volume': 5548.0,
#    'indicators': {'ema_2': 2296.700905992789, 'sma_12': 2321.0916666666662}}},
#  Timestamp('2025-07-15 17:59:59.999000'): {'num': 119,
#   'time_open': Timestamp('2025-07-15 17:00:00'),
#   'time_close': Timestamp('2025-07-15 17:59:59.999000'),
#   'M2K/USD': {'open': 2292.1,
#    'high': 2300.2,
#    'low': 2290.0,
#    'close': 2297.6,
#    'volume': 4639.0,
#    'indicators': {'ema_2': 2297.3003019975963, 'sma_12': 2318.3999999999996}}},
#  Timestamp('2025-07-15 18:59:59.999000'): {'num': 120,
#   'time_open': Timestamp('2025-07-15 18:00:00'),
#   'time_close': Timestamp('2025-07-15 18:59:59.999000'),
#   'M2K/USD': {'open': 2297.6,
#    'high': 2301.0,
#    'low': 2290.1,
#    'close': 2290.1,
#    'volume': 3682.0,
#    'indicators': {'ema_2': 2292.5001006658654, 'sma_12': 2315.191666666666}}},
#  Timestamp('2025-07-15 19:59:59.999000'): {'num': 121,
#   'time_open': Timestamp('2025-07-15 19:00:00'),
#   'time_close': Timestamp('2025-07-15 19:59:59.999000'),
#   'M2K/USD': {'open': 2290.0,
#    'high': 2294.4,
#    'low': 2281.0,
#    'close': 2281.7,
#    'volume': 5381.0,
#    'indicators': {'ema_2': 2285.3000335552883, 'sma_12': 2311.1166666666663}}},
#  Timestamp('2025-07-15 20:59:59.999000'): {'num': 122,
#   'time_open': Timestamp('2025-07-15 20:00:00'),
#   'time_close': Timestamp('2025-07-15 20:59:59.999000'),
#   'M2K/USD': {'open': 2281.5,
#    'high': 2282.5,
#    'low': 2275.5,
#    'close': 2276.4,
#    'volume': 2146.0,
#    'indicators': {'ema_2': 2279.3666778517627, 'sma_12': 2306.7666666666664}}},
#  Timestamp('2025-07-15 22:59:59.999000'): {'num': 123,
#   'time_open': Timestamp('2025-07-15 22:00:00'),
#   'time_close': Timestamp('2025-07-15 22:59:59.999000'),
#   'M2K/USD': {'open': 2278.3,
#    'high': 2279.0,
#    'low': 2272.3,
#    'close': 2274.9,
#    'volume': 1062.0,
#    'indicators': {'ema_2': 2276.3888926172544, 'sma_12': 2302.1499999999996}}},
#  Timestamp('2025-07-15 23:59:59.999000'): {'num': 124,
#   'time_open': Timestamp('2025-07-15 23:00:00'),
#   'time_close': Timestamp('2025-07-15 23:59:59.999000'),
#   'M2K/USD': {'open': 2274.5,
#    'high': 2276.8,
#    'low': 2272.6,
#    'close': 2275.5,
#    'volume': 752.0,
#    'indicators': {'ema_2': 2275.796297539085, 'sma_12': 2297.6083333333336}}},
#  Timestamp('2025-07-16 00:59:59.999000'): {'num': 125,
#   'time_open': Timestamp('2025-07-16 00:00:00'),
#   'time_close': Timestamp('2025-07-16 00:59:59.999000'),
#   'M2K/USD': {'open': 2275.4,
#    'high': 2279.2,
#    'low': 2272.1,
#    'close': 2278.4,
#    'volume': 924.0,
#    'indicators': {'ema_2': 2277.5320991796953, 'sma_12': 2293.4166666666665}}},
#  Timestamp('2025-07-16 01:59:59.999000'): {'num': 126,
#   'time_open': Timestamp('2025-07-16 01:00:00'),
#   'time_close': Timestamp('2025-07-16 01:59:59.999000'),
#   'M2K/USD': {'open': 2278.4,
#    'high': 2279.9,
#    'low': 2277.0,
#    'close': 2278.0,
#    'volume': 589.0,
#    'indicators': {'ema_2': 2277.8440330598983, 'sma_12': 2289.0249999999996}}},
#  Timestamp('2025-07-16 02:59:59.999000'): {'num': 127,
#   'time_open': Timestamp('2025-07-16 02:00:00'),
#   'time_close': Timestamp('2025-07-16 02:59:59.999000'),
#   'M2K/USD': {'open': 2278.4,
#    'high': 2279.3,
#    'low': 2276.5,
#    'close': 2278.3,
#    'volume': 335.0,
#    'indicators': {'ema_2': 2278.1480110199664, 'sma_12': 2285.9083333333333}}},
#  Timestamp('2025-07-16 03:59:59.999000'): {'num': 128,
#   'time_open': Timestamp('2025-07-16 03:00:00'),
#   'time_close': Timestamp('2025-07-16 03:59:59.999000'),
#   'M2K/USD': {'open': 2278.5,
#    'high': 2279.3,
#    'low': 2276.9,
#    'close': 2276.9,
#    'volume': 298.0,
#    'indicators': {'ema_2': 2277.3160036733225, 'sma_12': 2283.6499999999996}}},
#  Timestamp('2025-07-16 04:59:59.999000'): {'num': 129,
#   'time_open': Timestamp('2025-07-16 04:00:00'),
#   'time_close': Timestamp('2025-07-16 04:59:59.999000'),
#   'M2K/USD': {'open': 2276.9,
#    'high': 2279.6,
#    'low': 2276.7,
#    'close': 2277.3,
#    'volume': 242.0,
#    'indicators': {'ema_2': 2277.305334557774, 'sma_12': 2281.4416666666666}}},
#  Timestamp('2025-07-16 05:59:59.999000'): {'num': 130,
#   'time_open': Timestamp('2025-07-16 05:00:00'),
#   'time_close': Timestamp('2025-07-16 05:59:59.999000'),
#   'M2K/USD': {'open': 2277.5,
#    'high': 2279.9,
#    'low': 2274.5,
#    'close': 2276.0,
#    'volume': 627.0,
#    'indicators': {'ema_2': 2276.435111519258, 'sma_12': 2280.0916666666662}}},
#  Timestamp('2025-07-16 06:59:59.999000'): {'num': 131,
#   'time_open': Timestamp('2025-07-16 06:00:00'),
#   'time_close': Timestamp('2025-07-16 06:59:59.999000'),
#   'M2K/USD': {'open': 2275.7,
#    'high': 2276.3,
#    'low': 2271.5,
#    'close': 2271.8,
#    'volume': 947.0,
#    'indicators': {'ema_2': 2273.345037173086, 'sma_12': 2277.9416666666666}}},
#  Timestamp('2025-07-16 07:59:59.999000'): {'num': 132,
#   'time_open': Timestamp('2025-07-16 07:00:00'),
#   'time_close': Timestamp('2025-07-16 07:59:59.999000'),
#   'M2K/USD': {'open': 2271.7,
#    'high': 2278.4,
#    'low': 2268.4,
#    'close': 2277.9,
#    'volume': 1252.0,
#    'indicators': {'ema_2': 2276.3816790576952, 'sma_12': 2276.9249999999997}}},
#  Timestamp('2025-07-16 08:59:59.999000'): {'num': 133,
#   'time_open': Timestamp('2025-07-16 08:00:00'),
#   'time_close': Timestamp('2025-07-16 08:59:59.999000'),
#   'M2K/USD': {'open': 2277.9,
#    'high': 2284.0,
#    'low': 2277.3,
#    'close': 2283.0,
#    'volume': 1019.0,
#    'indicators': {'ema_2': 2280.7938930192317, 'sma_12': 2277.033333333333}}},
#  Timestamp('2025-07-16 09:59:59.999000'): {'num': 134,
#   'time_open': Timestamp('2025-07-16 09:00:00'),
#   'time_close': Timestamp('2025-07-16 09:59:59.999000'),
#   'M2K/USD': {'open': 2283.0,
#    'high': 2284.4,
#    'low': 2280.6,
#    'close': 2284.2,
#    'volume': 776.0,
#    'indicators': {'ema_2': 2283.0646310064103, 'sma_12': 2277.6833333333334}}},
#  Timestamp('2025-07-16 10:59:59.999000'): {'num': 135,
#   'time_open': Timestamp('2025-07-16 10:00:00'),
#   'time_close': Timestamp('2025-07-16 10:59:59.999000'),
#   'M2K/USD': {'open': 2284.3,
#    'high': 2285.8,
#    'low': 2282.5,
#    'close': 2284.5,
#    'volume': 609.0,
#    'indicators': {'ema_2': 2284.0215436688036, 'sma_12': 2278.483333333333}}},
#  Timestamp('2025-07-16 11:59:59.999000'): {'num': 136,
#   'time_open': Timestamp('2025-07-16 11:00:00'),
#   'time_close': Timestamp('2025-07-16 11:59:59.999000'),
#   'M2K/USD': {'open': 2284.6,
#    'high': 2288.1,
#    'low': 2283.4,
#    'close': 2288.0,
#    'volume': 1237.0,
#    'indicators': {'ema_2': 2286.6738478896013, 'sma_12': 2279.5249999999996}}},
#  Timestamp('2025-07-16 12:59:59.999000'): {'num': 137,
#   'time_open': Timestamp('2025-07-16 12:00:00'),
#   'time_close': Timestamp('2025-07-16 12:59:59.999000'),
#   'M2K/USD': {'open': 2288.1,
#    'high': 2303.2,
#    'low': 2286.6,
#    'close': 2294.7,
#    'volume': 6620.0,
#    'indicators': {'ema_2': 2292.0246159632, 'sma_12': 2280.883333333333}}},
#  Timestamp('2025-07-16 13:59:59.999000'): {'num': 138,
#   'time_open': Timestamp('2025-07-16 13:00:00'),
#   'time_close': Timestamp('2025-07-16 13:59:59.999000'),
#   'M2K/USD': {'open': 2294.7,
#    'high': 2300.1,
#    'low': 2283.8,
#    'close': 2287.0,
#    'volume': 9021.0,
#    'indicators': {'ema_2': 2288.6748719877332, 'sma_12': 2281.633333333333}}},
#  Timestamp('2025-07-16 14:59:59.999000'): {'num': 139,
#   'time_open': Timestamp('2025-07-16 14:00:00'),
#   'time_close': Timestamp('2025-07-16 14:59:59.999000'),
#   'M2K/USD': {'open': 2287.2,
#    'high': 2299.6,
# ...
#  Timestamp('2025-09-04 05:59:59.999000'): {'num': 954,
#   'time_open': Timestamp('2025-09-04 05:00:00'),
#   'time_close': Timestamp('2025-09-04 05:59:59.999000'),
#   'M2K/USD': {'open': 2428.4,
#    'high': 2429.8,
#    'low': 2425.8,
#    'close': 2427.0,
#    'volume': 513.0,
#    'indicators': {'ema_2': 2427.266719298646, 'sma_12': 2423.766666666667}}},
#  Timestamp('2025-09-04 06:59:59.999000'): {'num': 955,
#   'time_open': Timestamp('2025-09-04 06:00:00'),
#   'time_close': Timestamp('2025-09-04 06:59:59.999000'),
#   'M2K/USD': {'open': 2427.2,
#    'high': 2429.1,
#    'low': 2424.6,
#    'close': 2424.7,
#    'volume': 505.0,
#    'indicators': {'ema_2': 2425.5555730995484, 'sma_12': 2424.883333333333}}},
#  Timestamp('2025-09-04 07:59:59.999000'): {'num': 956,
#   'time_open': Timestamp('2025-09-04 07:00:00'),
#   'time_close': Timestamp('2025-09-04 07:59:59.999000'),
#   'M2K/USD': {'open': 2424.7,
#    'high': 2429.2,
#    'low': 2423.9,
#    'close': 2426.6,
#    'volume': 594.0,
#    'indicators': {'ema_2': 2426.2518576998496, 'sma_12': 2425.9333333333334}}},
#  Timestamp('2025-09-04 08:59:59.999000'): {'num': 957,
#   'time_open': Timestamp('2025-09-04 08:00:00'),
#   'time_close': Timestamp('2025-09-04 08:59:59.999000'),
#   'M2K/USD': {'open': 2426.4,
#    'high': 2427.1,
#    'low': 2422.2,
#    'close': 2423.2,
#    'volume': 579.0,
#    'indicators': {'ema_2': 2424.2172858999497, 'sma_12': 2426.041666666667}}},
#  Timestamp('2025-09-04 09:59:59.999000'): {'num': 958,
#   'time_open': Timestamp('2025-09-04 09:00:00'),
#   'time_close': Timestamp('2025-09-04 09:59:59.999000'),
#   'M2K/USD': {'open': 2423.3,
#    'high': 2426.7,
#    'low': 2422.7,
#    'close': 2426.7,
#    'volume': 471.0,
#    'indicators': {'ema_2': 2425.8724286333163, 'sma_12': 2426.125}}},
#  Timestamp('2025-09-04 10:59:59.999000'): {'num': 959,
#   'time_open': Timestamp('2025-09-04 10:00:00'),
#   'time_close': Timestamp('2025-09-04 10:59:59.999000'),
#   'M2K/USD': {'open': 2426.5,
#    'high': 2430.2,
#    'low': 2426.0,
#    'close': 2428.1,
#    'volume': 702.0,
#    'indicators': {'ema_2': 2427.357476211105, 'sma_12': 2426.608333333333}}},
#  Timestamp('2025-09-04 11:59:59.999000'): {'num': 960,
#   'time_open': Timestamp('2025-09-04 11:00:00'),
#   'time_close': Timestamp('2025-09-04 11:59:59.999000'),
#   'M2K/USD': {'open': 2428.2,
#    'high': 2430.2,
#    'low': 2424.9,
#    'close': 2427.0,
#    'volume': 817.0,
#    'indicators': {'ema_2': 2427.1191587370354, 'sma_12': 2426.8999999999996}}},
#  Timestamp('2025-09-04 12:59:59.999000'): {'num': 961,
#   'time_open': Timestamp('2025-09-04 12:00:00'),
#   'time_close': Timestamp('2025-09-04 12:59:59.999000'),
#   'M2K/USD': {'open': 2427.2,
#    'high': 2431.0,
#    'low': 2424.0,
#    'close': 2427.5,
#    'volume': 2061.0,
#    'indicators': {'ema_2': 2427.373052912345, 'sma_12': 2426.708333333333}}},
#  Timestamp('2025-09-04 13:59:59.999000'): {'num': 962,
#   'time_open': Timestamp('2025-09-04 13:00:00'),
#   'time_close': Timestamp('2025-09-04 13:59:59.999000'),
#   'M2K/USD': {'open': 2427.4,
#    'high': 2432.5,
#    'low': 2420.3,
#    'close': 2429.3,
#    'volume': 8250.0,
#    'indicators': {'ema_2': 2428.6576843041153, 'sma_12': 2426.7749999999996}}},
#  Timestamp('2025-09-04 14:59:59.999000'): {'num': 963,
#   'time_open': Timestamp('2025-09-04 14:00:00'),
#   'time_close': Timestamp('2025-09-04 14:59:59.999000'),
#   'M2K/USD': {'open': 2428.8,
#    'high': 2432.4,
#    'low': 2421.2,
#    'close': 2428.7,
#    'volume': 7405.0,
#    'indicators': {'ema_2': 2428.6858947680385, 'sma_12': 2426.9166666666665}}},
#  Timestamp('2025-09-04 15:59:59.999000'): {'num': 964,
#   'time_open': Timestamp('2025-09-04 15:00:00'),
#   'time_close': Timestamp('2025-09-04 15:59:59.999000'),
#   'M2K/USD': {'open': 2428.5,
#    'high': 2435.9,
#    'low': 2427.0,
#    'close': 2433.5,
#    'volume': 4050.0,
#    'indicators': {'ema_2': 2431.8952982560127, 'sma_12': 2427.575}}},
#  Timestamp('2025-09-04 16:59:59.999000'): {'num': 965,
#   'time_open': Timestamp('2025-09-04 16:00:00'),
#   'time_close': Timestamp('2025-09-04 16:59:59.999000'),
#   'M2K/USD': {'open': 2433.2,
#    'high': 2435.6,
#    'low': 2429.7,
#    'close': 2430.9,
#    'volume': 2399.0,
#    'indicators': {'ema_2': 2431.2317660853378, 'sma_12': 2427.7666666666664}}},
#  Timestamp('2025-09-04 17:59:59.999000'): {'num': 966,
#   'time_open': Timestamp('2025-09-04 17:00:00'),
#   'time_close': Timestamp('2025-09-04 17:59:59.999000'),
#   'M2K/USD': {'open': 2430.9,
#    'high': 2439.1,
#    'low': 2430.6,
#    'close': 2438.6,
#    'volume': 2557.0,
#    'indicators': {'ema_2': 2436.143922028446, 'sma_12': 2428.733333333333}}},
#  Timestamp('2025-09-04 18:59:59.999000'): {'num': 967,
#   'time_open': Timestamp('2025-09-04 18:00:00'),
#   'time_close': Timestamp('2025-09-04 18:59:59.999000'),
#   'M2K/USD': {'open': 2438.7,
#    'high': 2441.5,
#    'low': 2438.4,
#    'close': 2440.0,
#    'volume': 1855.0,
#    'indicators': {'ema_2': 2438.7146406761485, 'sma_12': 2430.0083333333328}}},
#  Timestamp('2025-09-04 19:59:59.999000'): {'num': 968,
#   'time_open': Timestamp('2025-09-04 19:00:00'),
#   'time_close': Timestamp('2025-09-04 19:59:59.999000'),
#   'M2K/USD': {'open': 2440.0,
#    'high': 2452.4,
#    'low': 2439.6,
#    'close': 2451.6,
#    'volume': 4967.0,
#    'indicators': {'ema_2': 2447.304880225383, 'sma_12': 2432.0916666666662}}},
#  Timestamp('2025-09-04 20:59:59.999000'): {'num': 969,
#   'time_open': Timestamp('2025-09-04 20:00:00'),
#   'time_close': Timestamp('2025-09-04 20:59:59.999000'),
#   'M2K/USD': {'open': 2451.6,
#    'high': 2453.4,
#    'low': 2450.1,
#    'close': 2451.4,
#    'volume': 1720.0,
#    'indicators': {'ema_2': 2450.034960075128, 'sma_12': 2434.4416666666666}}},
#  Timestamp('2025-09-04 22:59:59.999000'): {'num': 970,
#   'time_open': Timestamp('2025-09-04 22:00:00'),
#   'time_close': Timestamp('2025-09-04 22:59:59.999000'),
#   'M2K/USD': {'open': 2451.8,
#    'high': 2451.8,
#    'low': 2449.5,
#    'close': 2451.0,
#    'volume': 449.0,
#    'indicators': {'ema_2': 2450.678320025043, 'sma_12': 2436.4666666666667}}},
#  Timestamp('2025-09-04 23:59:59.999000'): {'num': 971,
#   'time_open': Timestamp('2025-09-04 23:00:00'),
#   'time_close': Timestamp('2025-09-04 23:59:59.999000'),
#   'M2K/USD': {'open': 2450.8,
#    'high': 2452.1,
#    'low': 2449.7,
#    'close': 2450.0,
#    'volume': 581.0,
#    'indicators': {'ema_2': 2450.2261066750143, 'sma_12': 2438.2916666666665}}},
#  Timestamp('2025-09-05 00:59:59.999000'): {'num': 972,
#   'time_open': Timestamp('2025-09-05 00:00:00'),
#   'time_close': Timestamp('2025-09-05 00:59:59.999000'),
#   'M2K/USD': {'open': 2450.0,
#    'high': 2452.3,
#    'low': 2449.5,
#    'close': 2450.7,
#    'volume': 458.0,
#    'indicators': {'ema_2': 2450.542035558338, 'sma_12': 2440.2666666666664}}},
#  Timestamp('2025-09-05 01:59:59.999000'): {'num': 973,
#   'time_open': Timestamp('2025-09-05 01:00:00'),
#   'time_close': Timestamp('2025-09-05 01:59:59.999000'),
#   'M2K/USD': {'open': 2450.9,
#    'high': 2451.8,
#    'low': 2450.2,
#    'close': 2451.8,
#    'volume': 266.0,
#    'indicators': {'ema_2': 2451.380678519446, 'sma_12': 2442.2916666666665}}},
#  Timestamp('2025-09-05 02:59:59.999000'): {'num': 974,
#   'time_open': Timestamp('2025-09-05 02:00:00'),
#   'time_close': Timestamp('2025-09-05 02:59:59.999000'),
#   'M2K/USD': {'open': 2451.8,
#    'high': 2451.8,
#    'low': 2450.8,
#    'close': 2451.2,
#    'volume': 206.0,
#    'indicators': {'ema_2': 2451.2602261731486, 'sma_12': 2444.1166666666663}}},
#  Timestamp('2025-09-05 03:59:59.999000'): {'num': 975,
#   'time_open': Timestamp('2025-09-05 03:00:00'),
#   'time_close': Timestamp('2025-09-05 03:59:59.999000'),
#   'M2K/USD': {'open': 2451.1,
#    'high': 2451.1,
#    'low': 2449.8,
#    'close': 2451.1,
#    'volume': 172.0,
#    'indicators': {'ema_2': 2451.153408724383, 'sma_12': 2445.983333333333}}},
#  Timestamp('2025-09-05 04:59:59.999000'): {'num': 976,
#   'time_open': Timestamp('2025-09-05 04:00:00'),
#   'time_close': Timestamp('2025-09-05 04:59:59.999000'),
#   'M2K/USD': {'open': 2451.2,
#    'high': 2452.6,
#    'low': 2450.9,
#    'close': 2451.2,
#    'volume': 152.0,
#    'indicators': {'ema_2': 2451.1844695747945, 'sma_12': 2447.458333333333}}},
#  Timestamp('2025-09-05 05:59:59.999000'): {'num': 977,
#   'time_open': Timestamp('2025-09-05 05:00:00'),
#   'time_close': Timestamp('2025-09-05 05:59:59.999000'),
#   'M2K/USD': {'open': 2451.3,
#    'high': 2455.4,
#    'low': 2450.8,
#    'close': 2454.3,
#    'volume': 508.0,
#    'indicators': {'ema_2': 2453.261489858265, 'sma_12': 2449.408333333333}}},
#  Timestamp('2025-09-05 06:59:59.999000'): {'num': 978,
#   'time_open': Timestamp('2025-09-05 06:00:00'),
#   'time_close': Timestamp('2025-09-05 06:59:59.999000'),
#   'M2K/USD': {'open': 2454.3,
#    'high': 2456.7,
#    'low': 2453.9,
#    'close': 2454.4,
#    'volume': 572.0,
#    'indicators': {'ema_2': 2454.020496619422, 'sma_12': 2450.7249999999995}}},
#  Timestamp('2025-09-05 07:59:59.999000'): {'num': 979,
#   'time_open': Timestamp('2025-09-05 07:00:00'),
#   'time_close': Timestamp('2025-09-05 07:59:59.999000'),
#   'M2K/USD': {'open': 2454.4,
#    'high': 2455.9,
#    'low': 2451.7,
#    'close': 2454.1,
#    'volume': 541.0,
#    'indicators': {'ema_2': 2454.0734988731406, 'sma_12': 2451.8999999999996}}},
#  Timestamp('2025-09-05 08:59:59.999000'): {'num': 980,
#   'time_open': Timestamp('2025-09-05 08:00:00'),
#   'time_close': Timestamp('2025-09-05 08:59:59.999000'),
#   'M2K/USD': {'open': 2454.0,
#    'high': 2454.5,
#    'low': 2452.9,
#    'close': 2454.1,
#    'volume': 255.0,
#    'indicators': {'ema_2': 2454.091166291047, 'sma_12': 2452.1083333333327}}},
#  Timestamp('2025-09-05 09:59:59.999000'): {'num': 981,
#   'time_open': Timestamp('2025-09-05 09:00:00'),
#   'time_close': Timestamp('2025-09-05 09:59:59.999000'),
#   'M2K/USD': {'open': 2454.1,
#    'high': 2455.6,
#    'low': 2454.0,
#    'close': 2455.0,
#    'volume': 389.0,
#    'indicators': {'ema_2': 2454.697055430349, 'sma_12': 2452.408333333333}}},
#  Timestamp('2025-09-05 10:59:59.999000'): {'num': 982,
#   'time_open': Timestamp('2025-09-05 10:00:00'),
#   'time_close': Timestamp('2025-09-05 10:59:59.999000'),
#   'M2K/USD': {'open': 2455.1,
#    'high': 2456.7,
#    'low': 2454.5,
#    'close': 2456.1,
#    'volume': 307.0,
#    'indicators': {'ema_2': 2455.6323518101162, 'sma_12': 2452.833333333333}}},
#  Timestamp('2025-09-05 11:59:59.999000'): {'num': 983,
#   'time_open': Timestamp('2025-09-05 11:00:00'),
#   'time_close': Timestamp('2025-09-05 11:59:59.999000'),
#   'M2K/USD': {'open': 2456.4,
#    'high': 2458.0,
#    'low': 2452.6,
#    'close': 2452.6,
#    'volume': 773.0,
#    'indicators': {'ema_2': 2453.6107839367055, 'sma_12': 2453.0499999999997}}},
#  Timestamp('2025-09-05 12:59:59.999000'): {'num': 984,
#   'time_open': Timestamp('2025-09-05 12:00:00'),
#   'time_close': Timestamp('2025-09-05 12:59:59.999000'),
#   'M2K/USD': {'open': 2453.0,
#    'high': 2471.3,
#    'low': 2436.6,
#    'close': 2462.4,
#    'volume': 9080.0,
#    'indicators': {'ema_2': 2459.4702613122354, 'sma_12': 2454.0249999999996}}},
#  Timestamp('2025-09-05 13:59:59.999000'): {'num': 985,
#   'time_open': Timestamp('2025-09-05 13:00:00'),
#   'time_close': Timestamp('2025-09-05 13:59:59.999000'),
#   'M2K/USD': {'open': 2462.5,
#    'high': 2482.7,
#    'low': 2460.7,
#    'close': 2477.4,
#    'volume': 13516.0,
#    'indicators': {'ema_2': 2471.423420437412, 'sma_12': 2456.1583333333333}}},
#  Timestamp('2025-09-05 14:59:59.999000'): {'num': 986,
#   'time_open': Timestamp('2025-09-05 14:00:00'),
#   'time_close': Timestamp('2025-09-05 14:59:59.999000'),
#   'M2K/USD': {'open': 2477.0,
#    'high': 2477.6,
#    'low': 2433.4,
#    'close': 2434.8,
#    'volume': 15544.0,
#    'indicators': {'ema_2': 2447.007806812471, 'sma_12': 2454.791666666667}}},
#  Timestamp('2025-09-05 15:59:59.999000'): {'num': 987,
#   'time_open': Timestamp('2025-09-05 15:00:00'),
#   'time_close': Timestamp('2025-09-05 15:59:59.999000'),
#   'M2K/USD': {'open': 2435.0,
#    'high': 2457.2,
#    'low': 2434.6,
#    'close': 2452.2,
#    'volume': 8437.0,
#    'indicators': {'ema_2': 2450.46926893749, 'sma_12': 2454.883333333333}}},
#  Timestamp('2025-09-05 16:59:59.999000'): {'num': 988,
#   'time_open': Timestamp('2025-09-05 16:00:00'),
#   'time_close': Timestamp('2025-09-05 16:59:59.999000'),
#   'M2K/USD': {'open': 2452.6,
#    'high': 2459.0,
#    'low': 2450.9,
#    'close': 2457.4,
#    'volume': 3856.0,
#    'indicators': {'ema_2': 2455.089756312497, 'sma_12': 2455.3999999999996}}},
#  Timestamp('2025-09-05 17:59:59.999000'): {'num': 989,
#   'time_open': Timestamp('2025-09-05 17:00:00'),
#   'time_close': Timestamp('2025-09-05 17:59:59.999000'),
#   'M2K/USD': {'open': 2457.4,
#    'high': 2458.0,
#    'low': 2445.9,
#    'close': 2448.4,
#    'volume': 3481.0,
#    'indicators': {'ema_2': 2450.6299187708323, 'sma_12': 2454.9083333333333}}},
#  Timestamp('2025-09-05 18:59:59.999000'): {'num': 990,
#   'time_open': Timestamp('2025-09-05 18:00:00'),
#   'time_close': Timestamp('2025-09-05 18:59:59.999000'),
#   'M2K/USD': {'open': 2448.4,
#    'high': 2456.8,
#    'low': 2447.7,
#    'close': 2456.8,
#    'volume': 2539.0,
#    'indicators': {'ema_2': 2454.7433062569444, 'sma_12': 2455.1083333333336}}},
#  Timestamp('2025-09-05 19:59:59.999000'): {'num': 991,
#   'time_open': Timestamp('2025-09-05 19:00:00'),
#   'time_close': Timestamp('2025-09-05 19:59:59.999000'),
#   'M2K/USD': {'open': 2456.7,
#    'high': 2463.9,
#    'low': 2454.9,
#    'close': 2462.3,
#    'volume': 6704.0,
#    'indicators': {'ema_2': 2459.7811020856484, 'sma_12': 2455.7916666666665}}},
#  Timestamp('2025-09-05 20:59:59.999000'): {'num': 992,
#   'time_open': Timestamp('2025-09-05 20:00:00'),
#   'time_close': Timestamp('2025-09-05 20:59:59.999000'),
#   'M2K/USD': {'open': 2462.4,
#    'high': 2463.6,
#    'low': 2461.0,
#    'close': 2462.5,
#    'volume': 1606.0,
#    'indicators': {'ema_2': 2461.5937006952163, 'sma_12': 2456.491666666667}}},
#  Timestamp('2025-09-07 22:59:59.999000'): {'num': 993,
#   'time_open': Timestamp('2025-09-07 22:00:00'),
#   'time_close': Timestamp('2025-09-07 22:59:59.999000'),
#   'M2K/USD': {'open': 2459.5,
#    'high': 2463.6,
#    'low': 2456.3,
#    'close': 2461.7,
#    'volume': 1216.0,
#    'indicators': {'ema_2': 2461.6645668984056, 'sma_12': 2457.0499999999997}}},
#  Timestamp('2025-09-07 23:59:59.999000'): {'num': 994,
#   'time_open': Timestamp('2025-09-07 23:00:00'),
#   'time_close': Timestamp('2025-09-07 23:59:59.999000'),
#   'M2K/USD': {'open': 2462.0,
#    'high': 2465.3,
#    'low': 2460.9,
#    'close': 2463.7,
#    'volume': 640.0,
#    'indicators': {'ema_2': 2463.0215222994684, 'sma_12': 2457.683333333333}}},
#  Timestamp('2025-09-08 00:59:59.999000'): {'num': 995,
#   'time_open': Timestamp('2025-09-08 00:00:00'),
#   'time_close': Timestamp('2025-09-08 00:59:59.999000'),
#   'M2K/USD': {'open': 2463.7,
#    'high': 2466.9,
#    'low': 2462.7,
#    'close': 2462.8,
#    'volume': 683.0,
#    'indicators': {'ema_2': 2462.8738407664896, 'sma_12': 2458.533333333333}}},
#  Timestamp('2025-09-08 01:59:59.999000'): {'num': 996,
#   'time_open': Timestamp('2025-09-08 01:00:00'),
#   'time_close': Timestamp('2025-09-08 01:59:59.999000'),
#   'M2K/USD': {'open': 2462.9,
#    'high': 2465.6,
#    'low': 2462.7,
#    'close': 2464.1,
#    'volume': 468.0,
#    'indicators': {'ema_2': 2463.6912802554966, 'sma_12': 2458.6749999999997}}},
#  Timestamp('2025-09-08 02:59:59.999000'): {'num': 997,
#   'time_open': Timestamp('2025-09-08 02:00:00'),
#   'time_close': Timestamp('2025-09-08 02:59:59.999000'),
#   'M2K/USD': {'open': 2464.3,
#    'high': 2464.3,
#    'low': 2460.4,
#    'close': 2462.5,
#    'volume': 522.0,
#    'indicators': {'ema_2': 2462.897093418499, 'sma_12': 2457.4333333333334}}},
#  Timestamp('2025-09-08 03:59:59.999000'): {'num': 998,
#   'time_open': Timestamp('2025-09-08 03:00:00'),
#   'time_close': Timestamp('2025-09-08 03:59:59.999000'),
#   'M2K/USD': {'open': 2462.7,
#    'high': 2465.0,
#    'low': 2462.4,
#    'close': 2463.9,
#    'volume': 369.0,
#    'indicators': {'ema_2': 2463.5656978061666, 'sma_12': 2459.8583333333336}}},
#  Timestamp('2025-09-08 04:59:59.999000'): {'num': 999,
#   'time_open': Timestamp('2025-09-08 04:00:00'),
#   'time_close': Timestamp('2025-09-08 04:59:59.999000'),
#   'M2K/USD': {'open': 2463.9,
#    'high': 2464.1,
#    'low': 2461.4,
#    'close': 2462.1,
#    'volume': 295.0,
#    'indicators': {'ema_2': 2462.588565935389, 'sma_12': 2460.6833333333334}}},
#  ...}

# %%
# single EMA(fast)/SMA(slow) crossover strategy, full weight -- see
# M2K/step_1_find_best_indicators_and_parameters.ipynb for how these parameters were picked.
portfolio = Portfolio(weighted_strategies=[
    WeightedStrategy(
        weight=1.0,
        strategy=MaCrossoverStrategy(
            key=f"EMA_{EMA_FAST_LEN}_SMA_{EMA_SMA_SLOW}_M2K",
            market=market,
            symbol=SYMBOL,
            direction=StrategyDirection.long,
            fast_indicator_key=f"{EMA_INDICATOR_NAME}_{EMA_FAST_LEN}",
            slow_indicator_key=f"{SMA_INDICATOR_NAME}_{EMA_SMA_SLOW}",
            sl_percent=0.3,
            tp_percent=0.6,
            sl_enabled=True,
            tp_enabled=True,
        ),
    ),
], output_scale=1)

print("Portfolio is ready!")
# Out:
# Portfolio is ready!

# %%
# Tradovate per-symbol config: point value / tick size / min size-step / fees.
# M2K has a real tick_size and fee_per_contract_override set directly on
# TRADOVATE_FUTURES in exchange_config.py (see PROP_FIRM_PLAN.md for the research).
symbol_config_provider = TradovateSymbolConfigProvider(symbols=TRADOVATE_FUTURES, default_fee_per_contract=0.0)

# instantiate exchange -- futures, point-value/tick-based math via symbol_config_provider
# (slippage/maker_fee/taker_fee below are unused once symbol_config_provider is set, but
# still required constructor args).
exchange = Exchange(
            market=market,
            slippage=0.0,
            maker_fee=0.0,
            taker_fee=0.0,
            market_type=MarketType.future,
            max_leverage=10,  # NOTE: this system doesn't model Tradovate's real per-symbol
                               # exchange-set margin schedule yet -- max_leverage is a stand-in.
            margin_allocation_type=MarginAllocationType.cross,
            symbol_config_provider=symbol_config_provider,
        )

# %%
# instantiate reporter
# periods_per_year=252: real trading-days/year convention for futures (not 365,
# which is only correct for a 24/7 crypto market -- see PerformanceAnalyzer's own
# docstring). Using the wrong constant here previously inflated every Sharpe/
# Sortino/annualized-volatility number in this pipeline by sqrt(365/252) =~ 1.20
# (~20%) versus the correct figure -- CAGR/Calmar/max_drawdown/net_return are
# unaffected since they don't depend on periods_per_year.
reporter = PerformanceAnalyzer(market=market,
                    exchange=exchange,
                    portfolio=portfolio,
                    benchmark_symbols=[SYMBOL],
                    periods_per_year=252)

# %%
# run only one next step
market.reset()

# Tradeify Growth $50k account: $2,000 (4%) EOD-trailing drawdown, permanently halts
# trading (account_failed) once breached -- see middleware.py / PROP_FIRM_PLAN.md.
# Now also models Tradeify's real lock-once-reached mechanic: the trailing floor
# freezes permanently at initial_balance + $100 the first time EOD balance reaches
# initial_balance * (1 + drawdown_percent) + $100 (e.g. $52,100 for this account),
# rather than continuing to trail upward forever past that point.
drawdown_middleware = TradeifyDrawdownMiddleware(drawdown_percent=0.04)
# Tradeify's real $1,250/day soft daily-loss pause on a $50k account (2.5% of
# balance): flattens and halts for the rest of the trading day, then resumes
# normally the next day (unlike the drawdown middleware's permanent halt).
# Previously not modeled at all in this pipeline despite being a real,
# already-documented Tradeify rule (PROP_FIRM_PLAN.md).
daily_loss_middleware = MaxDailyLossMiddleware(max_loss_percent=0.025)

backtest = Backtester(
    market=market,
    portfolio=portfolio,
    exchange=exchange,
    reporter=reporter,
    middlewares=[daily_loss_middleware, drawdown_middleware],
)
# deposit prop-firm-sized funds so we can trade
backtest.exchange.transactions.add_deposit(asset="USD", volume=50000)
backtest.run_all()

# Print Report
print("Candles Processed: ", backtest.market.current['num'])
print("Account failed (drawdown breach): ", drawdown_middleware.account_failed)
print("Drawdown floor locked (reached profit buffer): ", drawdown_middleware.locked)
# formatted HTML table (description column + color-coded cells) instead of the raw
# numeric DataFrame -- see backtester.performance.report_html for the per-metric rules.
display(HTML(backtest.reporter.summary_html_table()))

if backtest.reporter.merged is not None:
    # Print a chart to compare the returns
    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__cumulative_returns",
        f"{SYMBOL}__cumulative_returns"
        ], figsize=(30,6))

    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__drawdown",
        f"{SYMBOL}__drawdown"
        ], figsize=(30,6))

    backtest.reporter.merged.plot(x="time_close", y=[
        "algo__exchange_net_exposure",
        "algo__portfolio_net_exposure"
        ], figsize=(30,6))
# Out:
# Candles Processed:  5312
# Account failed (drawdown breach):  False
# Drawdown floor locked (reached profit buffer):  True
# <table style="border-collapse:collapse;font-family:sans-serif;font-size:13px;"><thead><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">metric</th><th style="border:1px solid #ddd;padding:4px 10px;">algo</th><th style="border:1px solid #ddd;padding:4px 10px;">M2K/USD</th><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">description</th></tr></thead><tbody><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">sharpe_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">1.3390</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">1.0983</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Return per unit of total volatility. &lt;0 bad, ~1 decent, &gt;2 great, &gt;3 excellent.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">sortino_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">2.4171</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">1.7024</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Like Sharpe but only penalizes downside volatility (upside swings aren&#x27;t &quot;risk&quot;). &gt;2 good, &gt;3 excellent.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">annualized_volatility_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">11.4030</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">18.0309</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">How much the equity curve swings per year. Lower = smoother.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">cagr_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">23.5836</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">30.1255</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Compound annual growth rate, the smoothed annual growth rate. Higher is generally better, but always weigh against volatility/drawdown.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">calmar_ratio</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">2.9144</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;">2.5210</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">CAGR ÷ max drawdown. &gt;1 decent, &gt;3 excellent, &lt;0.5 weak.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">recovery_factor</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;border:2px solid #2e7d32;font-weight:600;">2.5901</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;background-color:#c6f6c6;">2.2342</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Total net profit ÷ max drawdown. &gt;2 solid.</td></tr><tr><th style="border:1px solid #ddd;padding:4px 10px;text-align:left;">max_drawdown_percent</th><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;border:2px solid #2e7d32;font-weight:600;background-color:#c6f6c6;">-8.0921</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:right;">-11.9498</td><td style="border:1px solid #ddd;padding:4px 10px;text-align:left;color:#555;max-width:420px;">Largest peak-to-trough loss. Closer to 0 better; below -20% starts g ...

# %%
# market.merged
pd.DataFrame(backtest.exchange.get_logs())
# Out:
#                        time                                            message
# 0   2025-07-08 14:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 1   2025-07-09 07:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 2   2025-07-10 03:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 3   2025-07-10 08:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 4   2025-07-11 00:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# ..                      ...                                                ...
# 608 2026-05-29 13:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 609 2026-05-31 23:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 610 2026-06-01 07:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
# 611 2026-06-01 17:59:59.999  Rebalanced: Portfolio Exposure 1.0 | Exchange ...
# 612 2026-06-01 20:59:59.999  Rebalanced: Portfolio Exposure 0.0 | Exchange ...
#
# [613 rows x 2 columns]

# %%
# get dataframe with all the trades that were executed
def _trade_to_dict(trade):
    d = trade.__dict__.copy()
    for k, v in d.items():
        if hasattr(v, "value"):
            d[k] = v.value
    return d

pd.DataFrame([_trade_to_dict(t) for t in backtest.reporter.trades])
# Out:
#       symbol  side            time_open           time_close  open_price  \
# 0    M2K/USD  long  1752047999999000000  1752119999999000000      2307.6
# 1    M2K/USD  long  1752137999999000000  1752195599999000000      2330.6
# 2    M2K/USD  long  1752483599999000000  1752551999999000000      2302.7
# 3    M2K/USD  long  1752555599999000000  1752587999999000000      2327.3
# 4    M2K/USD  long  1752656399999000000  1752728399999000000      2283.0
# ..       ...   ...                  ...                  ...         ...
# 301  M2K/USD  long  1779980399999000000  1780019999999000000      2944.3
# 302  M2K/USD  long  1780037999999000000  1780045199999000000      2958.1
# 303  M2K/USD  long  1780048799999000000  1780063199999000000      2958.7
# 304  M2K/USD  long  1780271999999000000  1780300799999000000      2947.1
# 305  M2K/USD  long  1780336799999000000  1780347599999000000      2938.8
#
#      close_price close_reason       pnl  result  holding_period  risk_percent
# 0         2326.2       signal  0.008060  winner  72000000000000           0.3
# 1         2329.3       signal -0.000558   loser  57600000000000           0.3
# 2         2322.9       signal  0.008772  winner  68400000000000           0.3
# 3         2315.7       signal -0.004984   loser  32400000000000           0.3
# 4         2298.3       signal  0.006702  winner  72000000000000           0.3
# ..           ...          ...       ...     ...             ...           ...
# 301       2954.7       signal  0.003532  winner  39600000000000           0.3
# 302       2954.6       signal -0.001183   loser   7200000000000           0.3
# 303       2944.1       signal -0.004935   loser  14400000000000           0.3
# 304       2944.8       signal -0.000780   loser  28800000000000           0.3
# 305       2923.2       signal -0.005308   loser  10800000000000           0.3
#
# [306 rows x 11 columns]
